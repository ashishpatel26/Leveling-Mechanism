# %%
# Not re-inventing the wheel.
# Copied from edison project.

# %%
import os
import spacy

from spacy import displacy

# %%
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ## Objective
#
# Take something like:
#
# 1. Learn Computer Science With JavaScript: Part 4, Functions
# 1. Create Interactive Charts Using Plotly.js, Part 1: Getting Started
#
# And come out with keywords:
#
# 1. Computer Science
# 1. JavaScript
# 1. Functions
# 1. Interactive Charts
# 1. Plotly.js

# %% [markdown]
# ## Acceptance Criteria
#
# It is okay for the extractor to extract things that are not exactly concepts. For example, in the case above, it might also come up with:
#
# 1. Getting Started
#
# Another classifier can use Word2Vec to exclude generic terms, but it's not in the scope of this extractor, because we're only looking at the grammatical structure.

# %% [markdown]
# ## Core idea
#
# Encode every token inside a title as:
#
# 1. The tag of the parent
# 1. The dependency to the parent
# 1. ...

# %% [markdown]
# ### Exploration

# %%
doc = nlp('Create Interactive Charts Using Plotly.js, Part 1: Getting Started')
displacy.render(doc, jupyter=True)
# Out:
# /Users/kavitakanojiya/anaconda2/envs/levelling36/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /Users/kavitakanojiya/anaconda2/envs/levelling36/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1625" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Create</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Interactive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Charts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NNS</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VBG</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Plotly.js,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">1:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Getting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VBG</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Started</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VBN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,354.0 L398.0,342.0 382.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,354.0 L568.0,342.0 552.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M420,352.0 C420,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,354.0 L928.0,342.0 912.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,354.0 L1093.0,342.0 1077.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M70,352.0 C70,2.0 1450.0,2.0 1450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,354.0 L1458.0,342.0 1442.0,342.0" fill="currentColor"/>
# </g>
# </svg>

# %%
def test_features(token):
    print("Token:", token)
    print("Token tag:", token.tag_)
    print("Token parent dep:", token.dep_)
    print("Token parent tag:", token.head.tag_)
    print("Children:")

# %%
test_features(doc[1])
# Out:
# Token: Interactive
# Token tag: NNP
# Token parent dep: compound
# Token parent tag: NNS
# Children:

# %%
test_features(doc[2])
# Out:
# Token: Charts
# Token tag: NNS
# Token parent dep: dobj
# Token parent tag: VB

# %% [markdown]
# #### ---------------- Here, it ends the concept extraction login ---------------- ####

# %% [markdown]
# ### Following is the logic to extract concepts from all the html files ------

# %%
for np in doc.noun_chunks:
    print(np.text, np.root.dep_, np.root.head.text)
# Out:
# Interactive Charts dobj Create
# Plotly.js dobj Using
# Part appos Charts

# %%
import os
### Step 1: Import necessary packages here ###

import csv
import pandas
import numpy

# feedparser helps to xml to hash
# Install: conda install feedparser
import feedparser

# BeautifulSoup helps to grab text out of html
# Install: conda install beautifulsoup4
from bs4 import BeautifulSoup

import json
import urllib3

from collections import Counter

import newspaper
from newspaper import Article
from pandas import read_csv
from lxml import html
import requests

# %%
def clean_me(html):
    soup = BeautifulSoup(html, "lxml")
    for s in soup(['script', 'style']):
        s.decompose()
    return ' '.join(soup.stripped_strings)

# %%
html_files = os.listdir("Machine Learning Mastery articles")
html_file  = html_files[0]

html_file

keywords = list()

with open("Machine Learning Mastery articles/" + html_file) as f:
    html = f.read()
    scrubbed_content = clean_me(html)
    current_doc = nlp(scrubbed_content)

    for np in current_doc.noun_chunks:
        if np.root.dep_ in ['pobj', 'nsubj','compound'] and np.root.tag_ == 'NNP' and np.root.pos_ == 'PROPN':
            keywords.append(np.text)

#         if np.root.dep_ == 'nsubj' and np.root.tag_ == 'NNP' and np.root.pos_ == 'PROPN':
#             keywords.append(np.text)
#         if np.root.dep_ == 'compound' and np.root.tag_ == 'NNP' and np.root.pos_ == 'PROPN':
#             keywords.append(np.text)
#         if np.root.dep_ == 'dobj' and np.root.tag_ == 'NN' and np.root.pos_ == 'NOUN':
#             keywords.append(np.text)
        print(np.text + " dep: " + np.root.dep_ + " with tag: " + np.root.tag_ + " root.head.text: " + np.root.head.text + " POS: " + np.root.pos_)
# Out:
# Introduction dep: ROOT with tag: NN root.head.text: Introduction POS: NOUN
# the Python Deep Learning Library TensorFlow - Machine Learning Mastery Navigation Machine Learning Mastery dep: pobj with tag: NNP root.head.text: to POS: PROPN
# developers dep: nsubj with tag: NNS root.head.text: awesome POS: NOUN
# Blog Books dep: nsubj with tag: NNP root.head.text: Need POS: PROPN
# Contact dep: pobj with tag: NNP root.head.text: About POS: PROPN
# help dep: dobj with tag: NN root.head.text: Need POS: NOUN
# Deep Learning dep: pobj with tag: NNP root.head.text: with POS: PROPN
# the FREE Mini-Course Home Empty Menu Return dep: dobj with tag: NNP root.head.text: Take POS: PROPN
# Content Introduction dep: pobj with tag: NNP root.head.text: to POS: PROPN
# the Python Deep Learning Library TensorFlow dep: pobj with tag: NNP root.head.text: to POS: PROPN
# Jason Brownlee dep: pobj with tag: NNP root.head.text: By POS: PROPN
# May dep: pobj with tag: NNP root.head.text: on POS: PROPN
# Deep Learning Share dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Twitter Tweet Share dep: pobj with tag: NNP root.head.text: on POS: PROPN
# Facebook Share Share dep: pobj with tag: NN root.head.text: on POS: NOUN
# LinkedIn Share Share dep: pobj with tag: NN root.head.text: on POS: NOUN
# Google Plus Share TensorFlow dep: pobj with tag: NNP root.head.text: on POS: PROPN
# a Python library dep: attr with tag: NN root.head.text: is POS: NOUN
# fast numerical computing dep: pobj with tag: NN root.head.text: for POS: NOUN
# Google dep: pobj with tag: NNP root.head.text: by POS: PROPN
# It dep: nsubj with tag: PRP root.head.text: is POS: PRON
# a foundation library dep: attr with tag: NN root.head.text: is POS: NOUN
# Deep Learning models dep: dobj with tag: NNS root.head.text: create POS: NOUN
# wrapper libraries dep: dobj with tag: NNS root.head.text: using POS: NOUN
# the process dep: dobj with tag: NN root.head.text: simplify POS: NOUN
# top dep: pobj with tag: NN root.head.text: on POS: NOUN
# TensorFlow dep: pobj with tag: NNP root.head.text: of POS: PROPN
# this post dep: pobj with tag: NN root.head.text: In POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: discover POS: PRON
# the TensorFlow library dep: dobj with tag: NN root.head.text: discover POS: NOUN
# Deep Learning dep: pobj with tag: NNP root.head.text: for POS: PROPN
# ’s dep: nsubjpass with tag: PRP root.head.text: started POS: PRON
# the Python Deep Learning Library TensorFlow Photo dep: pobj with tag: NNP root.head.text: to POS: PROPN
# Nicolas Raymond dep: pobj with tag: NNP root.head.text: by POS: PROPN
# some rights dep: nsubj with tag: NNS root.head.text: reserved POS: NOUN
# What dep: attr with tag: WP root.head.text: is POS: NOUN
# TensorFlow dep: nsubj with tag: NNP root.head.text: is POS: PROPN
# TensorFlow dep: nsubj with tag: NNP root.head.text: is POS: PROPN
# an open source library dep: attr with tag: NN root.head.text: is POS: NOUN
# fast numerical computing dep: pobj with tag: NN root.head.text: for POS: NOUN
# It dep: nsubjpass with tag: PRP root.head.text: created POS: PRON
# Google dep: pobj with tag: NNP root.head.text: by POS: PROPN
# the Apache 2.0 open source license dep: pobj with tag: NN root.head.text: under POS: NOUN
# The API dep: nsubj with tag: NN root.head.text: is POS: NOUN
# the Python programming language dep: pobj with tag: NN root.head.text: for POS: NOUN
# access dep: attr with tag: NN root.head.text: is POS: NOUN
# the underlying C++ API dep: pobj with tag: NN root.head.text: to POS: NOUN
# other numerical libraries dep: pobj with tag: NNS root.head.text: Unlike POS: NOUN
# use dep: pobj with tag: NN root.head.text: for POS: NOUN
# Deep Learning dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Theano dep: pobj with tag: NNP root.head.text: like POS: PROPN
# TensorFlow dep: nsubjpass with tag: NNP root.head.text: designed POS: PROPN
# use dep: pobj with tag: NN root.head.text: for POS: NOUN
# research dep: pobj with tag: NN root.head.text: in POS: NOUN
# development dep: conj with tag: NN root.head.text: research POS: NOUN
# production systems dep: pobj with tag: NNS root.head.text: in POS: NOUN
# not least RankBrain dep: appos with tag: NN root.head.text: use POS: NOUN
# Google search dep: pobj with tag: NN root.head.text: in POS: NOUN
# the fun DeepDream project dep: conj with tag: NN root.head.text: RankBrain POS: NOUN
# It dep: nsubj with tag: PRP root.head.text: run POS: PRON
# single CPU systems dep: pobj with tag: NNS root.head.text: on POS: NOUN
# hundreds dep: pobj with tag: NNS root.head.text: of POS: NOUN
# machines dep: pobj with tag: NNS root.head.text: of POS: NOUN
# Install TensorFlow Installation dep: nsubj with tag: NNP root.head.text: is POS: PROPN
# TensorFlow dep: pobj with tag: NNP root.head.text: of POS: PROPN
# you dep: nsubj with tag: PRP root.head.text: have POS: PRON
# a Python SciPy environment dep: dobj with tag: NN root.head.text: have POS: NOUN
# TensorFlow dep: nsubj with tag: NNP root.head.text: works POS: PROPN
# Python dep: pobj with tag: NNP root.head.text: with POS: PROPN
# Python dep: conj with tag: NNP root.head.text: Python POS: PROPN
# You dep: nsubj with tag: PRP root.head.text: follow POS: PRON
# the Download and Setup instructions dep: dobj with tag: NNS root.head.text: follow POS: NOUN
# the TensorFlow website dep: pobj with tag: NN root.head.text: on POS: NOUN
# Installation dep: nsubj with tag: NNP root.head.text: is POS: PROPN
# PyPI and specific instructions dep: pobj with tag: NNS root.head.text: via POS: NOUN
# the pip command dep: pobj with tag: NN root.head.text: of POS: NOUN
# your Linux or Mac OS X platform dep: pobj with tag: NN root.head.text: for POS: NOUN
# the Download dep: pobj with tag: NNP root.head.text: on POS: PROPN
# Setup dep: conj with tag: NNP root.head.text: Download POS: PROPN
# virtualenv dep: attr with tag: NN root.head.text: are POS: NOUN
# docker images dep: conj with tag: NNS root.head.text: virtualenv POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: use POS: PRON
# you dep: nsubj with tag: PRP root.head.text: prefer POS: PRON
# use dep: dobj with tag: NN root.head.text: make POS: NOUN
# the GPU dep: pobj with tag: NNP root.head.text: of POS: PROPN
# only Linux dep: nsubjpass with tag: NNP root.head.text: supported POS: PROPN
# it dep: nsubj with tag: PRP root.head.text: requires POS: PRON
# the Cuda Toolkit dep: dobj with tag: NNP root.head.text: requires POS: PROPN
# Your First Examples dep: nsubjpass with tag: NNPS root.head.text: described POS: PROPN
# TensorFlow Computation dep: pobj with tag: NNP root.head.text: in POS: PROPN
# terms dep: pobj with tag: NNS root.head.text: in POS: NOUN
# data flow dep: pobj with tag: NN root.head.text: of POS: NOUN
# operations dep: conj with tag: NNS root.head.text: flow POS: NOUN
# the structure dep: pobj with tag: NN root.head.text: in POS: NOUN
# a directed graph dep: pobj with tag: NN root.head.text: of POS: NOUN
# Nodes dep: nsubj with tag: NNS root.head.text: perform POS: NOUN
# computation dep: dobj with tag: NN root.head.text: perform POS: NOUN
# zero or more inputs dep: dobj with tag: NNS root.head.text: have POS: NOUN
# outputs dep: conj with tag: NNS root.head.text: inputs POS: NOUN
# Data dep: nsubjpass with tag: NNS root.head.text: known POS: NOUN
# nodes dep: pobj with tag: NNS root.head.text: between POS: NOUN
# tensors dep: pobj with tag: NNS root.head.text: as POS: NOUN
# multi-dimensional arrays dep: attr with tag: NNS root.head.text: are POS: NOUN
# real values dep: pobj with tag: NNS root.head.text: of POS: NOUN
# Edges dep: ROOT with tag: NNS root.head.text: Edges POS: NOUN
# The graph dep: nsubj with tag: NN root.head.text: defines POS: NOUN
# the flow dep: dobj with tag: NN root.head.text: defines POS: NOUN
# data dep: pobj with tag: NNS root.head.text: of POS: NOUN
# Special edges dep: nsubjpass with tag: NNS root.head.text: used POS: NOUN
# behavior dep: dobj with tag: NN root.head.text: synchronize POS: NOUN
# the graph dep: pobj with tag: NN root.head.text: within POS: NOUN
# example dep: pobj with tag: NN root.head.text: for POS: NOUN
# computation dep: pobj with tag: NN root.head.text: for POS: NOUN
# a number dep: pobj with tag: NN root.head.text: on POS: NOUN
# inputs dep: pobj with tag: NNS root.head.text: of POS: NOUN
# An operation dep: nsubj with tag: NN root.head.text: is POS: NOUN
# a named abstract computation dep: attr with tag: NN root.head.text: is POS: NOUN
# input attributes dep: dobj with tag: NNS root.head.text: take POS: NOUN
# output attributes dep: dobj with tag: NNS root.head.text: produce POS: NOUN
# example dep: pobj with tag: NN root.head.text: For POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: define POS: PRON
# an add dep: dobj with tag: NN root.head.text: define POS: NOUN
# operation dep: dobj with tag: NN root.head.text: multiply POS: NOUN
# Computation dep: ROOT with tag: NN root.head.text: Computation POS: NOUN
# TensorFlow dep: pobj with tag: NNP root.head.text: with POS: PROPN
# This first example dep: nsubj with tag: NN root.head.text: is POS: NOUN
# a modified version dep: attr with tag: NN root.head.text: is POS: NOUN
# the example dep: pobj with tag: NN root.head.text: of POS: NOUN
# the TensorFlow website dep: pobj with tag: NN root.head.text: on POS: NOUN
# It dep: nsubj with tag: PRP root.head.text: shows POS: PRON
# you dep: nsubj with tag: PRP root.head.text: create POS: PRON
# a session dep: dobj with tag: NN root.head.text: create POS: NOUN
# constants dep: dobj with tag: NNS root.head.text: define POS: NOUN
# computation dep: dobj with tag: NN root.head.text: perform POS: NOUN
# those constants dep: pobj with tag: NNS root.head.text: with POS: NOUN
# the session dep: dobj with tag: NN root.head.text: using POS: NOUN
# import tensorflow dep: ROOT with tag: NN root.head.text: tensorflow POS: NOUN
# tf dep: pobj with tag: NNP root.head.text: as POS: PROPN
# sess dep: appos with tag: NN root.head.text: tf POS: NOUN
# = tf dep: appos with tag: NN root.head.text: sess POS: NOUN
# Session dep: ROOT with tag: NN root.head.text: Session POS: NOUN
# b = tf.constant(32)
# print(sess.run(a+b dep: appos with tag: NN root.head.text: tf.constant(10 POS: NOUN
# 1 2 3 4 5 import tensorflow dep: ROOT with tag: NN root.head.text: tensorflow POS: NOUN
# tf sess dep: pobj with tag: NN root.head.text: as POS: NOUN
# = tf dep: appos with tag: NN root.head.text: sess POS: NOUN
# ( ) a = tf dep: appos with tag: NN root.head.text: Session POS: NOUN
# constant ( 32 ) print dep: ROOT with tag: NN root.head.text: print POS: NOUN
# sess dep: appos with tag: NN root.head.text: print POS: NOUN
# b dep: conj with tag: NN root.head.text: a POS: NOUN
# this example dep: dobj with tag: NN root.head.text: Running POS: NOUN
# 42 1 42 Linear Regression dep: dobj with tag: NNP root.head.text: displays POS: PROPN
# TensorFlow dep: pobj with tag: NNP root.head.text: with POS: PROPN
# This next example dep: nsubj with tag: NN root.head.text: comes POS: NOUN
# the introduction dep: pobj with tag: NN root.head.text: from POS: NOUN
# the TensorFlow tutorial dep: pobj with tag: NN root.head.text: on POS: NOUN
# This examples dep: nsubj with tag: NNS root.head.text: shows POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: define POS: PRON
# variables dep: dobj with tag: NNS root.head.text: define POS: NOUN
# e.g. W dep: appos with tag: NN root.head.text: variables POS: NOUN
# variables dep: conj with tag: NNS root.head.text: variables POS: NOUN
# the result dep: attr with tag: NN root.head.text: are POS: NOUN
# computation dep: pobj with tag: NN root.head.text: of POS: NOUN
# y dep: appos with tag: NN root.head.text: computation POS: NOUN
# We dep: nsubj with tag: PRP root.head.text: get POS: PRON
# some sense dep: dobj with tag: NN root.head.text: get POS: NOUN
# TensorFlow dep: pobj with tag: NNP root.head.text: of POS: PROPN
# the definition dep: dobj with tag: NN root.head.text: separates POS: NOUN
# declaration dep: conj with tag: NN root.head.text: definition POS: NOUN
# the computation dep: pobj with tag: NN root.head.text: of POS: NOUN
# the execution dep: pobj with tag: NN root.head.text: from POS: NOUN
# the session dep: pobj with tag: NN root.head.text: in POS: NOUN
# the calls dep: conj with tag: NNS root.head.text: definition POS: NOUN
# import tensorflow dep: ROOT with tag: NN root.head.text: tensorflow POS: NOUN
# tf dep: pobj with tag: NNP root.head.text: as POS: PROPN
# import numpy dep: appos with tag: NN root.head.text: tf POS: NOUN
# np dep: pobj with tag: NNP root.head.text: as POS: PROPN
# y dep: nsubj with tag: PRP root.head.text: points POS: PRON
# NumPy dep: pobj with tag: NNP root.head.text: in POS: PROPN
# y dep: appos with tag: PRP root.head.text: NumPy POS: PRON
# = x * 0.1 + 0.3
# x_data = np.random.rand(100).astype(np.float32 dep: ROOT with tag: NNP root.head.text: np.random.rand(100).astype(np.float32 POS: PROPN
# x_data dep: ROOT with tag: NNP root.head.text: x_data POS: PROPN
# values dep: dobj with tag: NNS root.head.text: find POS: NOUN
# W dep: pobj with tag: NN root.head.text: for POS: NOUN
# y_data dep: dobj with tag: NNP root.head.text: compute POS: PROPN
# = W dep: ROOT with tag: NN root.head.text: W POS: NOUN
# * x_data dep: ROOT with tag: NN root.head.text: x_data POS: NOUN
# b
# # dep: conj with tag: NN root.head.text: x_data POS: NOUN
# We dep: nsubj with tag: PRP root.head.text: know POS: PRON
# W dep: nsubj with tag: NNP root.head.text: be POS: PROPN
# Tensorflow dep: nsubj with tag: NNP root.head.text: figure POS: PROPN
# us dep: pobj with tag: PRP root.head.text: for POS: PRON
# W = tf dep: ROOT with tag: NN root.head.text: tf POS: NOUN
# Variable(tf.random_uniform([1 dep: ROOT with tag: NNP root.head.text: Variable(tf.random_uniform([1 POS: PROPN
# b = tf dep: ROOT with tag: NN root.head.text: tf POS: NOUN
# Variable(tf.zeros([1 dep: ROOT with tag: NNP root.head.text: Variable(tf.zeros([1 POS: PROPN
# y dep: ROOT with tag: NNP root.head.text: y POS: PROPN
# = W dep: appos with tag: NN root.head.text: y POS: NOUN
# * x_data dep: ROOT with tag: NN root.head.text: x_data POS: NOUN
# the mean squared errors dep: dobj with tag: NNS root.head.text: Minimize POS: NOUN
# loss dep: ROOT with tag: NN root.head.text: loss POS: NOUN
# = tf.reduce_mean(tf.square(y - y_data dep: appos with tag: NNP root.head.text: loss POS: PROPN
# optimizer dep: nsubj with tag: NN root.head.text: train POS: NOUN
# tf.train.GradientDescentOptimizer(0.5 dep: appos with tag: NNP root.head.text: optimizer POS: PROPN
# optimizer.minimize(loss dep: appos with tag: NN root.head.text: train POS: NOUN
# the variables dep: dobj with tag: NNS root.head.text: initialize POS: NOUN
# We dep: nsubj with tag: PRP root.head.text: run POS: PRON
# init dep: ROOT with tag: NN root.head.text: init POS: NOUN
# tf.initialize_all_variables dep: appos with tag: NNS root.head.text: init POS: NOUN
# the graph dep: dobj with tag: NN root.head.text: Launch POS: NOUN
# sess dep: ROOT with tag: NN root.head.text: sess POS: NOUN
# = tf dep: appos with tag: NN root.head.text: sess POS: NOUN
# Session dep: ROOT with tag: NN root.head.text: Session POS: NOUN
# sess.run(init dep: appos with tag: NNP root.head.text: Session POS: PROPN
# the line dep: dobj with tag: NN root.head.text: Fit POS: NOUN
# step dep: pobj with tag: NN root.head.text: for POS: NOUN
# xrange(201 dep: pobj with tag: NNP root.head.text: in POS: PROPN
# sess.run(train dep: ROOT with tag: NNP root.head.text: sess.run(train POS: PROPN
# if step % dep: ROOT with tag: NN root.head.text: % POS: NOUN
# W dep: attr with tag: NN root.head.text: is POS: NOUN
# 29 30 31 32 33 import tensorflow dep: ROOT with tag: NN root.head.text: tensorflow POS: NOUN
# tf dep: nsubj with tag: NN root.head.text: import POS: NOUN
# numpy dep: dobj with tag: NN root.head.text: import POS: NOUN
# np # dep: nsubj with tag: NN root.head.text: Create POS: NOUN
# x, y data points dep: ROOT with tag: NNS root.head.text: points POS: NOUN
# NumPy dep: pobj with tag: NNP root.head.text: in POS: PROPN
# y dep: appos with tag: PRP root.head.text: NumPy POS: PRON
# x_data = np dep: appos with tag: NN root.head.text: 0.1 POS: NOUN
# rand dep: ROOT with tag: NN root.head.text: rand POS: NOUN
# ( np dep: appos with tag: NNP root.head.text: astype POS: PROPN
# values dep: dobj with tag: NNS root.head.text: find POS: NOUN
# W dep: pobj with tag: NN root.head.text: for POS: NOUN
# y_data dep: dobj with tag: NNP root.head.text: compute POS: PROPN
# = W dep: ROOT with tag: NN root.head.text: W POS: NOUN
# * x_data dep: ROOT with tag: NN root.head.text: x_data POS: NOUN
# b # dep: conj with tag: NN root.head.text: x_data POS: NOUN
# We dep: nsubj with tag: PRP root.head.text: know POS: PRON
# W dep: nsubj with tag: NNP root.head.text: be POS: PROPN
# Tensorflow dep: nsubj with tag: NNP root.head.text: figure POS: PROPN
# us dep: pobj with tag: PRP root.head.text: for POS: PRON
# W = tf dep: ROOT with tag: NN root.head.text: tf POS: NOUN
# Variable dep: ROOT with tag: NNP root.head.text: Variable POS: PROPN
# ( tf dep: appos with tag: NN root.head.text: Variable POS: NOUN
# random_uniform dep: ROOT with tag: NN root.head.text: random_uniform POS: NOUN
# b = tf dep: ROOT with tag: NN root.head.text: tf POS: NOUN
# Variable dep: ROOT with tag: NNP root.head.text: Variable POS: PROPN
# ( tf dep: appos with tag: NN root.head.text: Variable POS: NOUN
# zeros dep: ROOT with tag: NNS root.head.text: zeros POS: NOUN
# y dep: ROOT with tag: NN root.head.text: y POS: NOUN
# = W dep: appos with tag: NN root.head.text: y POS: NOUN
# * x_data dep: ROOT with tag: NN root.head.text: x_data POS: NOUN
# the mean squared errors dep: dobj with tag: NNS root.head.text: Minimize POS: NOUN
# loss dep: ROOT with tag: NN root.head.text: loss POS: NOUN
# = tf dep: dobj with tag: NN root.head.text: loss POS: NOUN
# reduce_mean ( tf dep: ROOT with tag: NN root.head.text: tf POS: NOUN
# ( y - y_data dep: appos with tag: NNP root.head.text: square POS: PROPN
# ) optimizer dep: nsubj with tag: NN root.head.text: tf POS: NOUN
# train dep: ROOT with tag: NN root.head.text: train POS: NOUN
# GradientDescentOptimizer ( 0.5 ) train = optimizer dep: ROOT with tag: NN root.head.text: optimizer POS: NOUN
# loss dep: appos with tag: NN root.head.text: minimize POS: NOUN
# the variables dep: dobj with tag: NNS root.head.text: initialize POS: NOUN
# We dep: nsubj with tag: PRP root.head.text: run POS: PRON
# init dep: ROOT with tag: NN root.head.text: init POS: NOUN
# = tf dep: appos with tag: NN root.head.text: init POS: NOUN
# initialize_all_variables dep: ROOT with tag: NNP root.head.text: initialize_all_variables POS: PROPN
# the graph dep: dobj with tag: NN root.head.text: Launch POS: NOUN
# sess dep: ROOT with tag: NN root.head.text: sess POS: NOUN
# = tf dep: appos with tag: NN root.head.text: sess POS: NOUN
# Session dep: nsubj with tag: NN root.head.text: run POS: NOUN
# sess dep: appos with tag: NN root.head.text: Session POS: NOUN
# init dep: appos with tag: NN root.head.text: run POS: NOUN
# the line dep: dobj with tag: NN root.head.text: Fit POS: NOUN
# step dep: pobj with tag: NN root.head.text: for POS: NOUN
# xrange dep: pobj with tag: NNP root.head.text: in POS: PROPN
# sess dep: nsubj with tag: NN root.head.text: run POS: NOUN
# print ( step , sess dep: appos with tag: NN root.head.text: run POS: NOUN
# run dep: conj with tag: NN root.head.text: run POS: NOUN
# run dep: conj with tag: NN root.head.text: run POS: NOUN
# ( b dep: dobj with tag: NN root.head.text: run POS: NOUN
# W dep: attr with tag: NN root.head.text: is POS: NOUN
# this example dep: dobj with tag: NN root.head.text: Running POS: NOUN
# the following output dep: dobj with tag: NN root.head.text: prints POS: NOUN
# (0, array dep: conj with tag: NN root.head.text: prints POS: NOUN
# dtype dep: conj with tag: NN root.head.text: array POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# array dep: conj with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: array POS: NOUN
# array dep: conj with tag: NN root.head.text: 20 POS: NOUN
# =float32 dep: appos with tag: NN root.head.text: dtype POS: NOUN
# array dep: conj with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: array POS: NOUN
# array dep: conj with tag: NN root.head.text: 40 POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# array dep: conj with tag: NN root.head.text: array POS: NOUN
# [ 0.2941364 dep: appos with tag: NNP root.head.text: array POS: PROPN
# dtype=float32 dep: appos with tag: NN root.head.text: array POS: NOUN
# array dep: conj with tag: NN root.head.text: 60 POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# array dep: conj with tag: NN root.head.text: 60 POS: NOUN
# dtype dep: conj with tag: NN root.head.text: 60 POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# (80, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.1009799 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.1009799 POS: NOUN
# (100, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: conj with tag: NN root.head.text: 0.10028629 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.10028629 POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.2998538 POS: NOUN
# , array dep: appos with tag: NN root.head.text: 0.2998538 POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.10008363 POS: NOUN
# array dep: appos with tag: NN root.head.text: 0.10008363 POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# array dep: conj with tag: NN root.head.text: 140 POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.2998538 POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# (160, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.10000713 POS: NOUN
# array dep: appos with tag: NN root.head.text: 0.10000713 POS: NOUN
# =float32 dep: appos with tag: NN root.head.text: dtype POS: NOUN
# (180, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.10000207 POS: NOUN
# array dep: appos with tag: NN root.head.text: 0.10000207 POS: NOUN
# =float32 dep: appos with tag: NN root.head.text: dtype POS: NOUN
# (200, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.1000006 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.1000006 POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.1000006 POS: NOUN
# (0, array dep: appos with tag: NN root.head.text: 5 POS: NOUN
# dtype dep: ROOT with tag: NN root.head.text: dtype POS: NOUN
# =float32 dep: appos with tag: NN root.head.text: dtype POS: NOUN
# array dep: conj with tag: NN root.head.text: dtype POS: NOUN
# dtype dep: conj with tag: NN root.head.text: array POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# (20, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.13929555 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.13929555 POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.13929555 POS: NOUN
# (40, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# array dep: appos with tag: NN root.head.text: array POS: NOUN
# [ 0.2941364 dep: appos with tag: NNP root.head.text: array POS: PROPN
# dtype dep: conj with tag: NN root.head.text: array POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# (60, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.10335406 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.10335406 POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.29828694 POS: NOUN
# (80, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.1009799 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.1009799 POS: NOUN
# =float32 dep: appos with tag: NN root.head.text: dtype POS: NOUN
# (100, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: conj with tag: NN root.head.text: 0.10028629 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.10028629 POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.2998538 POS: NOUN
# (120, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: conj with tag: NN root.head.text: 0.10008363 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.10008363 POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# (140, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.10002445 POS: NOUN
# array dep: appos with tag: NN root.head.text: 0.10002445 POS: NOUN
# =float32 dep: dobj with tag: NN root.head.text: dtype POS: NOUN
# (160, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.10000713 POS: NOUN
# array dep: appos with tag: NN root.head.text: 0.10000713 POS: NOUN
# =float32 dep: appos with tag: NN root.head.text: dtype POS: NOUN
# (180, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: conj with tag: NN root.head.text: 0.10000207 POS: NOUN
# array dep: appos with tag: NN root.head.text: 0.10000207 POS: NOUN
# =float32 dep: appos with tag: NN root.head.text: dtype POS: NOUN
# (200, array dep: ROOT with tag: NN root.head.text: array POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.1000006 POS: NOUN
# array dep: conj with tag: NN root.head.text: 0.1000006 POS: NOUN
# dtype=float32 dep: appos with tag: NN root.head.text: 0.1000006 POS: NOUN
# You dep: nsubj with tag: PRP root.head.text: learn POS: PRON
# the mechanics dep: pobj with tag: NNS root.head.text: about POS: NOUN
# TensorFlow dep: pobj with tag: NNP root.head.text: of POS: PROPN
# the Basic Usage guide dep: pobj with tag: NN root.head.text: in POS: NOUN
# More Deep Learning Models dep: ROOT with tag: NNPS root.head.text: Models POS: PROPN
# Your TensorFlow installation dep: nsubj with tag: NN root.head.text: comes POS: NOUN
# a number dep: pobj with tag: NN root.head.text: with POS: NOUN
# Deep Learning models dep: pobj with tag: NNS root.head.text: of POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: use POS: PRON
# you dep: nsubj with tag: PRP root.head.text: need POS: PRON
# TensorFlow dep: nsubjpass with tag: NNP root.head.text: installed POS: PROPN
# your system dep: pobj with tag: NN root.head.text: on POS: NOUN
# example dep: pobj with tag: NN root.head.text: For POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: use POS: PRON
# the following Python script dep: dobj with tag: NN root.head.text: use POS: NOUN
# python -c 'import os dep: dobj with tag: NNS root.head.text: use POS: NOUN
# import inspect dep: conj with tag: NN root.head.text: use POS: NOUN
# import tensorflow dep: conj with tag: NN root.head.text: inspect POS: NOUN
# print(os.path.dirname(inspect.getfile(tensorflow dep: appos with tag: NN root.head.text: tensorflow POS: NOUN
# 1 python -c 'import os dep: ROOT with tag: NNS root.head.text: os POS: NOUN
# import inspect dep: conj with tag: NN root.head.text: os POS: NOUN
# import tensorflow dep: conj with tag: NN root.head.text: inspect POS: NOUN
# print(os.path.dirname(inspect.getfile(tensorflow dep: appos with tag: NN root.head.text: tensorflow POS: NOUN
# example dep: pobj with tag: NN root.head.text: For POS: NOUN
# /lib/python2.7/site-packages/tensorflow dep: conj with tag: NN root.head.text: be POS: NOUN
# 1 /usr/lib/python2.7/site-packages/tensorflow Change dep: dobj with tag: NN root.head.text: tensorflow POS: NOUN
# this directory dep: pobj with tag: NN root.head.text: to POS: NOUN
# note dep: dobj with tag: NN root.head.text: take POS: NOUN
# the models subdirectory dep: pobj with tag: NN root.head.text: of POS: NOUN
# a number dep: attr with tag: NN root.head.text: are POS: NOUN
# deep learning models dep: pobj with tag: NNS root.head.text: of POS: NOUN
# tutorial-like comments dep: pobj with tag: NNS root.head.text: with POS: NOUN
# Multi-threaded word2vec mini-batched skip-gram model dep: pobj with tag: NN root.head.text: as POS: NOUN
# Multi-threaded word2vec unbatched skip-gram model dep: ROOT with tag: NN root.head.text: model POS: NOUN
# CNN dep: ROOT with tag: NNP root.head.text: CNN POS: PROPN
# the The CIFAR-10 network dep: pobj with tag: NN root.head.text: for POS: NOUN
# end dep: pobj with tag: NN root.head.text: to POS: NOUN
# sequence dep: pobj with tag: NN root.head.text: to POS: NOUN
# an attention mechanism dep: pobj with tag: NN root.head.text: with POS: NOUN
# the examples dep: dobj with tag: NNS root.head.text: check POS: NOUN
# directory dep: dobj with tag: NN root.head.text: check POS: NOUN
# it dep: nsubj with tag: PRP root.head.text: contains POS: PRON
# an example dep: dobj with tag: NN root.head.text: contains POS: NOUN
# the MNIST dataset dep: dobj with tag: NN root.head.text: using POS: NOUN
# an excellent list dep: attr with tag: NN root.head.text: is POS: NOUN
# tutorials dep: pobj with tag: NNS root.head.text: of POS: NOUN
# the main TensorFlow website dep: pobj with tag: NN root.head.text: on POS: NOUN
# They dep: nsubj with tag: PRP root.head.text: show POS: PRON
# different network types dep: dobj with tag: NNS root.head.text: use POS: NOUN
# different datasets dep: conj with tag: NNS root.head.text: types POS: NOUN
# the framework dep: dobj with tag: NN root.head.text: use POS: NOUN
# various different ways dep: pobj with tag: NNS root.head.text: in POS: NOUN
# the TensorFlow playground dep: attr with tag: NN root.head.text: is POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: experiment POS: PRON
# small networks dep: pobj with tag: NNS root.head.text: with POS: NOUN
# your web browser dep: pobj with tag: NN root.head.text: in POS: NOUN
# help dep: dobj with tag: NN root.head.text: Need POS: NOUN
# Deep Learning dep: pobj with tag: NNP root.head.text: with POS: PROPN
# Python dep: pobj with tag: NNP root.head.text: in POS: PROPN
# my free 2-week email course dep: dobj with tag: NN root.head.text: Take POS: NOUN
# MLPs dep: dobj with tag: NNS root.head.text: discover POS: NOUN
# CNNs dep: conj with tag: NNPS root.head.text: MLPs POS: PROPN
# LSTMs dep: conj with tag: NNPS root.head.text: CNNs POS: PROPN
# sample code dep: pobj with tag: NN root.head.text: with POS: NOUN
# a free PDF Ebook version dep: dobj with tag: NN root.head.text: get POS: NOUN
# the course dep: pobj with tag: NN root.head.text: of POS: NOUN
# Your FREE Mini-Course dep: dobj with tag: NN root.head.text: Start POS: NOUN
# TensorFlow Resources TensorFlow Official Homepage TensforFlow Project dep: ROOT with tag: NNP root.head.text: Project POS: PROPN
# GitHub TensorFlow Tutorials dep: pobj with tag: NNS root.head.text: on POS: NOUN
# More Resources dep: ROOT with tag: NNP root.head.text: Resources POS: PROPN
# TensorFlow Course dep: appos with tag: NN root.head.text: Resources POS: NOUN
# Udacity TensorFlow dep: pobj with tag: NNP root.head.text: on POS: PROPN
# Large-Scale Machine Learning dep: ROOT with tag: NNP root.head.text: Learning POS: PROPN
# Heterogeneous Distributed Systems dep: pobj with tag: NNPS root.head.text: on POS: PROPN
# Summary dep: ROOT with tag: NNP root.head.text: Summary POS: PROPN
# this post dep: pobj with tag: NN root.head.text: In POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: discovered POS: PRON
# the TensorFlow Python library dep: dobj with tag: NN root.head.text: discovered POS: NOUN
# deep learning dep: pobj with tag: NN root.head.text: for POS: NOUN
# You dep: nsubj with tag: PRP root.head.text: learned POS: PRON
# it dep: nsubj with tag: PRP root.head.text: is POS: PRON
# a library dep: attr with tag: NN root.head.text: is POS: NOUN
# fast numerical computation dep: pobj with tag: NN root.head.text: for POS: NOUN
# the types dep: pobj with tag: NNS root.head.text: for POS: NOUN
# operations dep: pobj with tag: NNS root.head.text: of POS: NOUN
# the development dep: pobj with tag: NN root.head.text: in POS: NOUN
# evaluation dep: conj with tag: NN root.head.text: development POS: NOUN
# large deep learning models dep: pobj with tag: NNS root.head.text: of POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: have POS: PRON
# any questions dep: dobj with tag: NNS root.head.text: have POS: NOUN
# TensorFlow dep: pobj with tag: NNP root.head.text: about POS: PROPN
# this post dep: pobj with tag: NN root.head.text: about POS: NOUN
# your questions dep: dobj with tag: NNS root.head.text: Ask POS: NOUN
# the comments dep: pobj with tag: NNS root.head.text: in POS: NOUN
# I dep: nsubj with tag: PRP root.head.text: do POS: PRON
# them dep: dobj with tag: PRP root.head.text: answer POS: PRON
# Your Progress dep: pobj with tag: NNP root.head.text: With POS: PROPN
# Deep Learning dep: pobj with tag: NNP root.head.text: In POS: PROPN
# What dep: ROOT with tag: WP root.head.text: What POS: NOUN
# You dep: nsubj with tag: PRP root.head.text: Develop POS: PRON
# A Network dep: dobj with tag: NNP root.head.text: Develop POS: PROPN
# Minutes dep: pobj with tag: NNP root.head.text: in POS: PROPN
# just a few lines dep: pobj with tag: NNS root.head.text: with POS: NOUN
# Python Discover dep: pobj with tag: NNP root.head.text: of POS: PROPN
# my new Ebook dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Deep Learning dep: appos with tag: NNP root.head.text: Ebook POS: PROPN
# Python dep: pobj with tag: NNP root.head.text: With POS: PROPN
# It dep: nsubj with tag: PRP root.head.text: covers POS: PRON
# self-study tutorials dep: dobj with tag: NNS root.head.text: covers POS: NOUN
# end dep: pobj with tag: NN root.head.text: to POS: NOUN
# topics dep: pobj with tag: NNS root.head.text: on POS: NOUN
# Multilayer Perceptrons dep: appos with tag: NNPS root.head.text: covers POS: PROPN
# Convolutional Nets dep: conj with tag: NNPS root.head.text: Perceptrons POS: PROPN
# Recurrent Neural Nets dep: conj with tag: NNPS root.head.text: Nets POS: PROPN
# Deep Learning dep: dobj with tag: NNP root.head.text: Bring POS: PROPN
# Your Own Projects dep: pobj with tag: NNS root.head.text: To POS: NOUN
# the Academics dep: dobj with tag: NNPS root.head.text: Skip POS: PROPN
# Just Results dep: ROOT with tag: NNS root.head.text: Results POS: NOUN
# Twitter Tweet Share dep: pobj with tag: NNP root.head.text: on POS: PROPN
# Facebook Share Share dep: pobj with tag: NN root.head.text: on POS: NOUN
# LinkedIn Share Share dep: pobj with tag: NN root.head.text: on POS: NOUN
# Google Plus Share dep: pobj with tag: NNP root.head.text: on POS: PROPN
# Jason Brownlee Dr. Jason Brownlee dep: nsubj with tag: NNP root.head.text: is POS: PROPN
# a husband dep: attr with tag: NN root.head.text: is POS: NOUN
# proud father dep: appos with tag: NN root.head.text: husband POS: NOUN
# academic researcher dep: appos with tag: NN root.head.text: father POS: NOUN
# author dep: appos with tag: NN root.head.text: husband POS: NOUN
# professional developer dep: conj with tag: NN root.head.text: author POS: NOUN
# a machine learning practitioner dep: conj with tag: NN root.head.text: developer POS: NOUN
# He dep: nsubjpass with tag: PRP root.head.text: dedicated POS: PRON
# developers dep: nsubjpass with tag: NNS root.head.text: started POS: NOUN
# applied machine learning dep: pobj with tag: NN root.head.text: at POS: NOUN
# all posts dep: dobj with tag: NNS root.head.text: View POS: NOUN
# Jason Brownlee dep: pobj with tag: NNP root.head.text: by POS: PROPN
# → Crash Course dep: appos with tag: NN root.head.text: Brownlee POS: NOUN
# Python dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Machine Learning Developers Introduction dep: pobj with tag: NNP root.head.text: for POS: PROPN
# Machine Learning dep: pobj with tag: NNP root.head.text: to POS: PROPN
# scikit-learn 10 Responses dep: pobj with tag: NNS root.head.text: with POS: NOUN
# Introduction dep: pobj with tag: NNP root.head.text: to POS: PROPN
# the Python Deep Learning Library TensorFlow dep: pobj with tag: NNP root.head.text: to POS: PROPN
# Jatin dep: ROOT with tag: NNP root.head.text: Jatin POS: PROPN
# 7:33 pm dep: pobj with tag: NN root.head.text: at POS: NOUN
# # dep: ROOT with tag: NN root.head.text: # POS: NOUN
# great help dep: attr with tag: NN root.head.text: was POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: post POS: PRON
# some more tutorials dep: dobj with tag: NNS root.head.text: post POS: NOUN
# tensor-flow dep: dobj with tag: NN root.head.text: using POS: NOUN
# Thanks dep: ROOT with tag: NNS root.head.text: Thanks POS: NOUN
# Reply Jason Brownlee dep: nsubj with tag: NNP root.head.text: am POS: PROPN
# I dep: nsubj with tag: PRP root.head.text: intend POS: PRON
# Jatin dep: ROOT with tag: NNP root.head.text: Jatin POS: PROPN
# Reply Amit Kumar dep: nsubj with tag: NNP root.head.text: is POS: PROPN
# 9:58 pm dep: pobj with tag: NN root.head.text: at POS: NOUN
# # print sess.run(a+b dep: appos with tag: NNP root.head.text: pm POS: PROPN
# this line dep: nsubj with tag: NN root.head.text: is POS: NOUN
# print dep: nsubj with tag: NN root.head.text: is POS: NOUN
# a method dep: attr with tag: NN root.head.text: is POS: NOUN
# an opening and closing bracket dep: dobj with tag: NN root.head.text: have POS: NOUN
# Reply Jason Brownlee dep: nsubj with tag: NNP root.head.text: am POS: PROPN
# # Thanks Amit dep: attr with tag: NNP root.head.text: am POS: PROPN
# Reply Asesh April dep: ROOT with tag: NNP root.head.text: April POS: PROPN
# 5:49 pm dep: pobj with tag: NN root.head.text: at POS: NOUN
# What dep: ROOT with tag: WP root.head.text: What POS: NOUN
# it dep: nsubj with tag: PRP root.head.text: ’s POS: PRON
# Python dep: attr with tag: NNP root.head.text: ’s POS: PROPN
# the print statement dep: nsubj with tag: NN root.head.text: Is POS: NOUN
# bracket dep: pobj with tag: NN root.head.text: without POS: NOUN
# Reply Jason Brownlee dep: nsubj with tag: NNP root.head.text: am POS: PROPN
# The brackets dep: nsubjpass with tag: NNS root.head.text: ignored POS: NOUN
# nothing dep: dobj with tag: NN root.head.text: do POS: NOUN
# it dep: nsubj with tag: PRP root.head.text: makes POS: PRON
# the same code work dep: dobj with tag: NN root.head.text: makes POS: NOUN
# Python3 dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Reply Walid Ahmed dep: nsubj with tag: NNP root.head.text: am POS: PROPN
# I dep: nsubj with tag: PRP root.head.text: find POS: PRON
# my Tensorflow installation dep: pobj with tag: NN root.head.text: in POS: NOUN
# you dep: nsubj with tag: PRP root.head.text: help POS: PRON
# Reply Jason Brownlee dep: nsubj with tag: NNP root.head.text: am POS: PROPN
# I dep: nsubj with tag: PRP root.head.text: think POS: PRON
# they dep: nsubjpass with tag: PRP root.head.text: removed POS: PRON
# the most recent release dep: pobj with tag: NN root.head.text: from POS: NOUN
# Reply ale dep: ROOT with tag: NN root.head.text: ale POS: NOUN
# 6:19 pm dep: pobj with tag: NN root.head.text: at POS: NOUN
# # dep: ROOT with tag: NN root.head.text: # POS: NOUN
# Hi Jason dep: ROOT with tag: NNP root.head.text: Jason POS: PROPN
# this page dep: pobj with tag: NN root.head.text: In POS: NOUN
# it dep: nsubjpass with tag: PRP root.head.text: written POS: PRON
# use dep: dobj with tag: NN root.head.text: make POS: NOUN
# the GPU dep: pobj with tag: NNP root.head.text: of POS: PROPN
# only Linux dep: nsubjpass with tag: NNP root.head.text: supported POS: PROPN
# it dep: nsubj with tag: PRP root.head.text: requires POS: PRON
# the Cuda Toolkit dep: dobj with tag: NNP root.head.text: requires POS: PROPN
# ” dep: ROOT with tag: NN root.head.text: ” POS: NOUN
# I dep: nsubj with tag: PRP root.head.text: think POS: PRON
# Windows dep: nsubjpass with tag: NNP root.head.text: supported POS: PROPN
# Cuda toolkit dep: nsubjpass with tag: NN root.head.text: installed POS: NOUN
# it dep: nsubj with tag: PRP root.head.text: Is POS: PRON
# Thanks dep: ROOT with tag: NNS root.head.text: Thanks POS: NOUN
# Reply Jason Brownlee dep: ROOT with tag: NNP root.head.text: Brownlee POS: PROPN
# 12:00 pm dep: pobj with tag: NN root.head.text: at POS: NOUN
# It dep: nsubj with tag: PRP root.head.text: be POS: PRON
# it dep: nsubj with tag: PRP root.head.text: appear POS: PRON
# the case dep: attr with tag: NN root.head.text: be POS: NOUN
# the time dep: pobj with tag: NN root.head.text: at POS: NOUN
# writing dep: pobj with tag: NN root.head.text: of POS: NOUN
# Reply dep: nsubj with tag: NNP root.head.text: Leave POS: PROPN
# a Reply Click dep: dobj with tag: NN root.head.text: Leave POS: NOUN
# reply dep: dobj with tag: NN root.head.text: cancel POS: NOUN
# Comment Name dep: ROOT with tag: NN root.head.text: Name POS: NOUN
# Email dep: nsubjpass with tag: NN root.head.text: published POS: NOUN
# Website Welcome dep: ROOT with tag: NN root.head.text: Welcome POS: NOUN
# Machine Learning Mastery dep: pobj with tag: NNP root.head.text: to POS: PROPN
# I dep: nsubj with tag: PRP root.head.text: 'm POS: PRON
# Dr. Jason Brownlee dep: attr with tag: NNP root.head.text: 'm POS: PROPN
# My goal dep: nsubj with tag: NN root.head.text: is POS: NOUN
# practitioners dep: nsubj with tag: NNS root.head.text: like POS: NOUN
# YOU dep: nsubj with tag: PRP root.head.text: awesome POS: PRON
# applied machine learning dep: pobj with tag: NN root.head.text: at POS: NOUN
# Deep Learning Sick dep: pobj with tag: NNP root.head.text: With POS: PROPN
# the fancy math dep: pobj with tag: NN root.head.text: of POS: NOUN
# super computers dep: pobj with tag: NNS root.head.text: for POS: NOUN
# step dep: pobj with tag: NN root.head.text: by POS: NOUN
# end dep: pobj with tag: NN root.head.text: to POS: NOUN
# Deep Learning dep: pobj with tag: NNP root.head.text: With POS: PROPN
# Python Today dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Popular dep: ROOT with tag: NNP root.head.text: Popular POS: PROPN
# Your First Machine Learning Project dep: dobj with tag: NNP root.head.text: Popular POS: PROPN
# Python Step dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Step dep: pobj with tag: NNP root.head.text: By POS: PROPN
# Time Series Prediction dep: appos with tag: NNP root.head.text: Project POS: PROPN
# LSTM Recurrent Neural Networks dep: pobj with tag: NNPS root.head.text: with POS: PROPN
# Python dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Keras dep: pobj with tag: NNP root.head.text: with POS: PROPN
# 2016 Multivariate Time Series Forecasting dep: appos with tag: NNP root.head.text: July POS: PROPN
# LSTMs dep: pobj with tag: NNP root.head.text: with POS: PROPN
# Keras dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Your First Neural Network dep: dobj with tag: NNP root.head.text: Develop POS: PROPN
# Python dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Keras dep: pobj with tag: NNP root.head.text: With POS: PROPN
# Step dep: pobj with tag: NN root.head.text: By POS: NOUN
# a Python Environment dep: dobj with tag: NNP root.head.text: Setup POS: PROPN
# Machine Learning dep: pobj with tag: NNP root.head.text: for POS: PROPN
# Deep Learning dep: conj with tag: NNP root.head.text: Learning POS: PROPN
# Anaconda dep: pobj with tag: NNP root.head.text: with POS: PROPN
# , 2017 Sequence Classification dep: appos with tag: NNP root.head.text: Setup POS: PROPN
# LSTM Recurrent Neural Networks dep: pobj with tag: NNPS root.head.text: with POS: PROPN
# Python dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Keras dep: pobj with tag: NNP root.head.text: with POS: PROPN
# 2016 Time Series Forecasting dep: appos with tag: NNP root.head.text: July POS: PROPN
# the Long Short-Term Memory Network dep: pobj with tag: NNP root.head.text: with POS: PROPN
# Python April dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Multi-Class Classification Tutorial dep: ROOT with tag: NNP root.head.text: Tutorial POS: PROPN
# the Keras Deep Learning Library dep: pobj with tag: NNP root.head.text: with POS: PROPN
# Regression Tutorial dep: ROOT with tag: NN root.head.text: Tutorial POS: NOUN
# the Keras Deep Learning Library dep: pobj with tag: NNP root.head.text: with POS: PROPN
# Python dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Grid Search Hyperparameters dep: pobj with tag: NNPS root.head.text: to POS: PROPN
# Deep Learning Models dep: pobj with tag: NNPS root.head.text: for POS: PROPN
# Python dep: pobj with tag: NNP root.head.text: in POS: PROPN
# Keras dep: pobj with tag: NNP root.head.text: With POS: PROPN
# 2018 Machine Learning Mastery dep: appos with tag: NNP root.head.text: August POS: PROPN
# Privacy | Contact | dep: ROOT with tag: NNP root.head.text: | POS: PROPN

# %%
keywords
# Out:
# ['the Python Deep Learning Library TensorFlow - Machine Learning Mastery Navigation Machine Learning Mastery',
#  'Blog Books',
#  'Contact',
#  'Deep Learning',
#  'Content Introduction',
#  'the Python Deep Learning Library TensorFlow',
#  'Jason Brownlee',
#  'May',
#  'Deep Learning Share',
#  'Twitter Tweet Share',
#  'Google Plus Share TensorFlow',
#  'Google',
#  'TensorFlow',
#  'Deep Learning',
#  'the Python Deep Learning Library TensorFlow Photo',
#  'Nicolas Raymond',
#  'TensorFlow',
#  'TensorFlow',
#  'Google',
#  'Deep Learning',
#  'Theano',
#  'Install TensorFlow Installation',
#  'TensorFlow',
#  'TensorFlow',
#  'Python',
#  'Installation',
#  'the Download',
#  'the GPU',
#  'TensorFlow Computation',
#  'TensorFlow',
#  'tf',
#  'TensorFlow',
#  'TensorFlow',
#  'tf',
#  'np',
#  'NumPy',
#  'W',
#  'Tensorflow',
#  'xrange(201',
#  'NumPy',
#  'W',
#  'Tensorflow',
#  'xrange',
#  'TensorFlow',
#  'Deep Learning',
#  'Python',
#  'Udacity TensorFlow',
#  'TensorFlow',
#  'Your Progress',
#  'Deep Learning',
#  'Minutes',
#  'Python Discover',
#  'my new Ebook',
#  'Python',
#  'Twitter Tweet Share',
#  'Google Plus Share',
#  'Jason Brownlee Dr. Jason Brownlee',
#  'Jason Brownlee',
#  'Python',
#  'Machine Learning Developers Introduction',
#  'Machine Learning',
#  'Introduction',
#  'the Python Deep Learning Library TensorFlow',
#  'Reply Jason Brownlee',
#  'Reply Amit Kumar',
#  'Reply Jason Brownlee',
#  'Reply Jason Brownlee',
#  'Python3',
#  'Reply Walid Ahmed',
#  'Reply Jason Brownlee',
#  'the GPU',
#  'Reply',
#  'Machine Learning Mastery',
#  'Deep Learning Sick',
#  'Deep Learning',
#  'Python Today',
#  'Python Step',
#  'Step',
#  'Python',
#  'Keras',
#  'LSTMs',
#  'Keras',
#  'Python',
#  'Keras',
#  'Machine Learning',
#  'Anaconda',
#  'Python',
#  'Keras',
#  'the Long Short-Term Memory Network',
#  'Python April',
#  'the Keras Deep Learning Library',
#  'the Keras Deep Learning Library',
#  'Python',
#  'Python',
#  'Keras']
