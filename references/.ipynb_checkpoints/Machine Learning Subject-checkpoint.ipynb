# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Parse-RDF" data-toc-modified-id="Parse-RDF-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Parse RDF</a></span></li><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Helper-functions" data-toc-modified-id="Helper-functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Helper functions</a></span></li><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Start-getting-information" data-toc-modified-id="Start-getting-information-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Start getting information</a></span><ul class="toc-item"><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Get-concepts" data-toc-modified-id="Get-concepts-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Get concepts</a></span></li><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Things-being-used-in/related-to-ML" data-toc-modified-id="Things-being-used-in/related-to-ML-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Things being used in/related to ML</a></span></li><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Concepts-within-all-the-pages-within-machine-learning" data-toc-modified-id="Concepts-within-all-the-pages-within-machine-learning-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Concepts within all the pages within machine learning</a></span></li></ul></li><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Final-structure" data-toc-modified-id="Final-structure-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Final structure</a></span><ul class="toc-item"><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Get-concept-counts" data-toc-modified-id="Get-concept-counts-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Get concept counts</a></span></li><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Filter-concepts" data-toc-modified-id="Filter-concepts-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Filter concepts</a></span></li><li><span><a href="http://localhost:8889/notebooks/Machine%20Learning%20Subject.ipynb#Construct-final-structure" data-toc-modified-id="Construct-final-structure-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Construct final structure</a></span></li></ul></li></ul></div>

# %%
import re
from bz2 import BZ2File as bzopen
from tqdm import tqdm
import pickle
import json
import operator
from collections import Counter

# %% [markdown]
# ## Parse RDF

# %%
sample_lines = [
    '<http://dbpedia.org/resource/Timeline_of_machine_learning> <http://purl.org/dc/terms/subject> <http://dbpedia.org/resource/Category:Machine_learning> .\n',
    '<http://dbpedia.org/resource/Category:World_War_II> <http://www.w3.org/2000/01/rdf-schema#label> "World War II"@en <http://en.wikipedia.org/wiki/Category:World_War_II?oldid=729127213> .\n'
]

# %% [markdown]
# ## Helper functions

# %%
def search_file(filename, search_text):
    with bzopen(filename, 'r') as file:
        for line in tqdm(file):
            line = line.decode("utf-8")
            if search_text in line:
                yield line

# %% [markdown]
# ## Start getting information

# %%
topic = 'Machine_learning'

# %% [markdown]
# ### Get concepts

# %%
print(re.escape('<http://purl.org/dc/terms/subject>'))
# Out:
# \<http\:\/\/purl\.org\/dc\/terms\/subject\>

# %%
PARSE_CONCEPT_REGEX = r'^\<http\:\/\/dbpedia\.org\/resource\/([^>]+)\>'
PARSE_CONCEPT_TYPE_REGEX = r'\<http\:\/\/purl\.org\/dc\/terms\/([^>]+)\>'
def parse_concept(line):
    concept = re.findall(PARSE_CONCEPT_REGEX, line)[0]
    concept = concept.replace('_', ' ')
    
    concept_type = re.findall(PARSE_CONCEPT_TYPE_REGEX, line)[0]
    
    return (concept, concept_type)

parse_concept('<http://dbpedia.org/resource/Glossary_of_artificial_intelligence> <http://purl.org/dc/terms/subject> <http://dbpedia.org/resource/Category:Machine_learning> .\n')
# Out:
# ('Glossary of artificial intelligence', 'subject')

# %%
def get_concepts(topic):
    concepts = []
    
    for line in search_file('../article_categories_en.ttl.bz2', 'Category:{}>'.format(topic)):
        concepts.append(parse_concept(line))
        
    return concepts

# %%
# Total: 23990516
topic_concepts = get_concepts(topic)
# Out:
# 23990516it [03:02, 131245.09it/s]

# %%
topic_concepts
# Out:
# [('Supervised learning', 'subject'),
#  ('Pattern recognition', 'subject'),
#  ('Overfitting', 'subject'),
#  ('Inductive bias', 'subject'),
#  ('Binary classification', 'subject'),
#  ('Early stopping', 'subject'),
#  ('Machine learning', 'subject'),
#  ('Unsupervised learning', 'subject'),
#  ('Formal concept analysis', 'subject'),
#  ('Computational learning theory', 'subject'),
#  ("Solomonoff's theory of inductive inference", 'subject'),
#  ('Cross-validation (statistics)', 'subject'),
#  ('Instantaneously trained neural networks', 'subject'),
#  ('Linear separability', 'subject'),
#  ('Dimensionality reduction', 'subject'),
#  ('Curse of dimensionality', 'subject'),
#  ('Confusion matrix', 'subject'),
#  ('Mixture model', 'subject'),
#  ('Relational data mining', 'subject'),
#  ('Multi-task learning', 'subject'),
#  ('Transduction (machine learning)', 'subject'),
#  ('Savi Technology', 'subject'),
#  ('Granular computing', 'subject'),
#  ('Statistical learning theory', 'subject'),
#  ('Bongard problem', 'subject'),
#  ('Generative model', 'subject'),
#  ('Feature (machine learning)', 'subject'),
#  ('Document classification', 'subject'),
#  ('Developmental robotics', 'subject'),
#  ('Empirical risk minimization', 'subject'),
#  ('Test set', 'subject'),
#  ('Statistical classification', 'subject'),
#  ('Feature vector', 'subject'),
#  ('Kernel density estimation', 'subject'),
#  ('Predictive learning', 'subject'),
#  ('Orange (software)', 'subject'),
#  ('Semi-supervised learning', 'subject'),
#  ('Multi-armed bandit', 'subject'),
#  ('Cognitive robotics', 'subject'),
#  ('Concept drift', 'subject'),
#  ('Subclass reachability', 'subject'),
#  ('Learning automata', 'subject'),
#  ('Robot learning', 'subject'),
#  ('Accuracy paradox', 'subject'),
#  ('Inductive transfer', 'subject'),
#  ('Conditional random field', 'subject'),
#  ('Knowledge integration', 'subject'),
#  ('Grammar induction', 'subject'),
#  ('Meta learning (computer science)', 'subject'),
#  ('Inauthentic text', 'subject'),
#  ('Ugly duckling theorem', 'subject'),
#  ('Journal of Machine Learning Research', 'subject'),
#  ('Machine Learning (journal)', 'subject'),
#  ('Cross-entropy method', 'subject'),
#  ('Prior knowledge for pattern recognition', 'subject'),
#  ('Concept learning', 'subject'),
#  ('Nearest neighbor search', 'subject'),
#  ('Rule induction', 'subject'),
#  ('Version space learning', 'subject'),
#  ('Evolvability (computer science)', 'subject'),
#  ('Category utility', 'subject'),
#  ('Committee machine', 'subject'),
#  ('Probability matching', 'subject'),
#  ('Base rate', 'subject'),
#  ('Structural risk minimization', 'subject'),
#  ('Lazy learning', 'subject'),
#  ('Offline learning', 'subject'),
#  ('Eager learning', 'subject'),
#  ('Predictive state representation', 'subject'),
#  ('Discriminative model', 'subject'),
#  ('Ensembles of classifiers', 'subject'),
#  ('Matthews correlation coefficient', 'subject'),
#  ('Data pre-processing', 'subject'),
#  ('Elastic matching', 'subject'),
#  ('Bag-of-words model', 'subject'),
#  ('Multiple-instance learning', 'subject'),
#  ('Semantic analysis (machine learning)', 'subject'),
#  ('Rademacher complexity', 'subject'),
#  ('Expectation propagation', 'subject'),
#  ('CBCL (MIT)', 'subject'),
#  ('Multivariate adaptive regression splines', 'subject'),
#  ('Uncertain data', 'subject'),
#  ('Neural modeling fields', 'subject'),
#  ('Decision list', 'subject'),
#  ('Apprenticeship learning', 'subject'),
#  ('Statistical relational learning', 'subject'),
#  ('Algorithmic inference', 'subject'),
#  ('Explanation-based learning', 'subject'),
#  ('Proactive learning', 'subject'),
#  ('Instance-based learning', 'subject'),
#  ('CIML community portal', 'subject'),
#  ('Uniform convergence (combinatorics)', 'subject'),
#  ('Parity learning', 'subject'),
#  ('Learning with errors', 'subject'),
#  ('Product of experts', 'subject'),
#  ('Learning to rank', 'subject'),
#  ('Large margin nearest neighbor', 'subject'),
#  ('Constrained conditional model', 'subject'),
#  ('Cleverbot', 'subject'),
#  ('Active learning (machine learning)', 'subject'),
#  ('Sequence labeling', 'subject'),
#  ('AIXI', 'subject'),
#  ('Multilinear subspace learning', 'subject'),
#  ('Multilinear principal component analysis', 'subject'),
#  ('Ball tree', 'subject'),
#  ('Hyperparameter optimization', 'subject'),
#  ('Inferential theory of learning', 'subject'),
#  ('Stability (learning theory)', 'subject'),
#  ('Leave-one-out error', 'subject'),
#  ('Mountain Car', 'subject'),
#  ('Coupled pattern learner', 'subject'),
#  ('Feature scaling', 'subject'),
#  ('Preference learning', 'subject'),
#  ('Linear predictor function', 'subject'),
#  ('Bayesian interpretation of kernel regularization', 'subject'),
#  ('Representer theorem', 'subject'),
#  ('Feature hashing', 'subject'),
#  ('Random indexing', 'subject'),
#  ('Universal portfolio algorithm', 'subject'),
#  ('Similarity learning', 'subject'),
#  ('Feature learning', 'subject'),
#  ('Catastrophic interference', 'subject'),
#  ('Validation set', 'subject'),
#  ('Bias–variance tradeoff', 'subject'),
#  ('Pattern language (formal languages)', 'subject'),
#  ('Bayesian optimization', 'subject'),
#  ('Proximal gradient methods for learning', 'subject'),
#  ('Kernel embedding of distributions', 'subject'),
#  ('Inductive programming', 'subject'),
#  ('Inductive functional programming', 'subject'),
#  ('DeepMind', 'subject'),
#  ('Query level feature', 'subject'),
#  ('OpenNN', 'subject'),
#  ('Inductive probability', 'subject'),
#  ('Deeplearning4j', 'subject'),
#  ('Evaluation of binary classifiers', 'subject'),
#  ('Sample complexity', 'subject'),
#  ('Vanishing gradient problem', 'subject'),
#  ('Knowledge Vault', 'subject'),
#  ('Action model learning', 'subject'),
#  ('Random projection', 'subject'),
#  ('Quantum machine learning', 'subject'),
#  ('Bradley–Terry model', 'subject'),
#  ('Occam learning', 'subject'),
#  ('Matrix regularization', 'subject'),
#  ('M-Theory (learning framework)', 'subject'),
#  ('Adversarial machine learning', 'subject'),
#  ('Logic learning machine', 'subject'),
#  ('Domain adaptation', 'subject'),
#  ('Native-language identification', 'subject'),
#  ('Zeroth (software)', 'subject'),
#  ('Feature engineering', 'subject'),
#  ('Kernel random forest', 'subject'),
#  ('Local case-control sampling', 'subject'),
#  ('User behavior analytics', 'subject'),
#  ('Dropout (neural networks)', 'subject'),
#  ('Skymind', 'subject'),
#  ('Word2vec', 'subject'),
#  ('Trax Image Recognition', 'subject'),
#  ('Stochastic block model', 'subject'),
#  ('The Master Algorithm', 'subject'),
#  ('Deep feature synthesis', 'subject'),
#  ('Manifold regularization', 'subject'),
#  ('Sparse dictionary learning', 'subject'),
#  ('Learnable function class', 'subject'),
#  ('Error Tolerance (PAC learning)', 'subject'),
#  ('Multiple instance learning', 'subject'),
#  ('Structured sparsity regularization', 'subject'),
#  ('MysteryVibe', 'subject'),
#  ('Isotropic position', 'subject'),
#  ('List of datasets for machine learning research', 'subject'),
#  ('AlphaGo', 'subject'),
#  ('Holdout method', 'subject'),
#  ('Darkforest', 'subject'),
#  ('Movidius (company)', 'subject'),
#  ('Bayesian structural time series', 'subject'),
#  ('Semantic folding', 'subject'),
#  ('Spike-and-slab variable selection', 'subject'),
#  ('Glossary of artificial intelligence', 'subject'),
#  ('Bing Predicts', 'subject'),
#  ('Algorithm Selection', 'subject'),
#  ('Timeline of machine learning', 'subject'),
#  ('Dataiku', 'subject'),
#  ('Machine Teaching', 'subject')]

# %%
with open('machine-learning-topics.json', 'wt') as f:
    json.dump(topic_concepts, f, indent=4)

# %% [markdown]
# ### Things being used in/related to ML

# %% [markdown]
# ### Concepts within all the pages within machine learning

# %%
def get_search_concepts(concepts):
    # Generate search map
    search_concepts = {}
    for concept in concepts:
        name = concept[0]
        slug = name.replace(' ', '_')
        slug += '>'
        
        search_concepts[slug] = concept
        
    return search_concepts

# %%
search_concepts = get_search_concepts(topic_concepts)

search_concepts
# Out:
# {'AIXI>': ('AIXI', 'subject'),
#  'Accuracy_paradox>': ('Accuracy paradox', 'subject'),
#  'Action_model_learning>': ('Action model learning', 'subject'),
#  'Active_learning_(machine_learning)>': ('Active learning (machine learning)',
#   'subject'),
#  'Adversarial_machine_learning>': ('Adversarial machine learning', 'subject'),
#  'Algorithm_Selection>': ('Algorithm Selection', 'subject'),
#  'Algorithmic_inference>': ('Algorithmic inference', 'subject'),
#  'AlphaGo>': ('AlphaGo', 'subject'),
#  'Apprenticeship_learning>': ('Apprenticeship learning', 'subject'),
#  'Bag-of-words_model>': ('Bag-of-words model', 'subject'),
#  'Ball_tree>': ('Ball tree', 'subject'),
#  'Base_rate>': ('Base rate', 'subject'),
#  'Bayesian_interpretation_of_kernel_regularization>': ('Bayesian interpretation of kernel regularization',
#   'subject'),
#  'Bayesian_optimization>': ('Bayesian optimization', 'subject'),
#  'Bayesian_structural_time_series>': ('Bayesian structural time series',
#   'subject'),
#  'Bias–variance_tradeoff>': ('Bias–variance tradeoff', 'subject'),
#  'Binary_classification>': ('Binary classification', 'subject'),
#  'Bing_Predicts>': ('Bing Predicts', 'subject'),
#  'Bongard_problem>': ('Bongard problem', 'subject'),
#  'Bradley–Terry_model>': ('Bradley–Terry model', 'subject'),
#  'CBCL_(MIT)>': ('CBCL (MIT)', 'subject'),
#  'CIML_community_portal>': ('CIML community portal', 'subject'),
#  'Catastrophic_interference>': ('Catastrophic interference', 'subject'),
#  'Category_utility>': ('Category utility', 'subject'),
#  'Cleverbot>': ('Cleverbot', 'subject'),
#  'Cognitive_robotics>': ('Cognitive robotics', 'subject'),
#  'Committee_machine>': ('Committee machine', 'subject'),
#  'Computational_learning_theory>': ('Computational learning theory',
#   'subject'),
#  'Concept_drift>': ('Concept drift', 'subject'),
#  'Concept_learning>': ('Concept learning', 'subject'),
#  'Conditional_random_field>': ('Conditional random field', 'subject'),
#  'Confusion_matrix>': ('Confusion matrix', 'subject'),
#  'Constrained_conditional_model>': ('Constrained conditional model',
#   'subject'),
#  'Coupled_pattern_learner>': ('Coupled pattern learner', 'subject'),
#  'Cross-entropy_method>': ('Cross-entropy method', 'subject'),
#  'Cross-validation_(statistics)>': ('Cross-validation (statistics)',
#   'subject'),
#  'Curse_of_dimensionality>': ('Curse of dimensionality', 'subject'),
#  'Darkforest>': ('Darkforest', 'subject'),
#  'Data_pre-processing>': ('Data pre-processing', 'subject'),
#  'Dataiku>': ('Dataiku', 'subject'),
#  'Decision_list>': ('Decision list', 'subject'),
#  'DeepMind>': ('DeepMind', 'subject'),
#  'Deep_feature_synthesis>': ('Deep feature synthesis', 'subject'),
#  'Deeplearning4j>': ('Deeplearning4j', 'subject'),
#  'Developmental_robotics>': ('Developmental robotics', 'subject'),
#  'Dimensionality_reduction>': ('Dimensionality reduction', 'subject'),
#  'Discriminative_model>': ('Discriminative model', 'subject'),
#  'Document_classification>': ('Document classification', 'subject'),
#  'Domain_adaptation>': ('Domain adaptation', 'subject'),
#  'Dropout_(neural_networks)>': ('Dropout (neural networks)', 'subject'),
#  'Eager_learning>': ('Eager learning', 'subject'),
#  'Early_stopping>': ('Early stopping', 'subject'),
#  'Elastic_matching>': ('Elastic matching', 'subject'),
#  'Empirical_risk_minimization>': ('Empirical risk minimization', 'subject'),
#  'Ensembles_of_classifiers>': ('Ensembles of classifiers', 'subject'),
#  'Error_Tolerance_(PAC_learning)>': ('Error Tolerance (PAC learning)',
#   'subject'),
#  'Evaluation_of_binary_classifiers>': ('Evaluation of binary classifiers',
#   'subject'),
#  'Evolvability_(computer_science)>': ('Evolvability (computer science)',
#   'subject'),
#  'Expectation_propagation>': ('Expectation propagation', 'subject'),
#  'Explanation-based_learning>': ('Explanation-based learning', 'subject'),
#  'Feature_(machine_learning)>': ('Feature (machine learning)', 'subject'),
#  'Feature_engineering>': ('Feature engineering', 'subject'),
#  'Feature_hashing>': ('Feature hashing', 'subject'),
#  'Feature_learning>': ('Feature learning', 'subject'),
#  'Feature_scaling>': ('Feature scaling', 'subject'),
#  'Feature_vector>': ('Feature vector', 'subject'),
#  'Formal_concept_analysis>': ('Formal concept analysis', 'subject'),
#  'Generative_model>': ('Generative model', 'subject'),
#  'Glossary_of_artificial_intelligence>': ('Glossary of artificial intelligence',
#   'subject'),
#  'Grammar_induction>': ('Grammar induction', 'subject'),
#  'Granular_computing>': ('Granular computing', 'subject'),
#  'Holdout_method>': ('Holdout method', 'subject'),
#  'Hyperparameter_optimization>': ('Hyperparameter optimization', 'subject'),
#  'Inauthentic_text>': ('Inauthentic text', 'subject'),
#  'Inductive_bias>': ('Inductive bias', 'subject'),
#  'Inductive_functional_programming>': ('Inductive functional programming',
#   'subject'),
#  'Inductive_probability>': ('Inductive probability', 'subject'),
#  'Inductive_programming>': ('Inductive programming', 'subject'),
#  'Inductive_transfer>': ('Inductive transfer', 'subject'),
#  'Inferential_theory_of_learning>': ('Inferential theory of learning',
#   'subject'),
#  'Instance-based_learning>': ('Instance-based learning', 'subject'),
#  'Instantaneously_trained_neural_networks>': ('Instantaneously trained neural networks',
#   'subject'),
#  'Isotropic_position>': ('Isotropic position', 'subject'),
#  'Journal_of_Machine_Learning_Research>': ('Journal of Machine Learning Research',
#   'subject'),
#  'Kernel_density_estimation>': ('Kernel density estimation', 'subject'),
#  'Kernel_embedding_of_distributions>': ('Kernel embedding of distributions',
#   'subject'),
#  'Kernel_random_forest>': ('Kernel random forest', 'subject'),
#  'Knowledge_Vault>': ('Knowledge Vault', 'subject'),
#  'Knowledge_integration>': ('Knowledge integration', 'subject'),
#  'Large_margin_nearest_neighbor>': ('Large margin nearest neighbor',
#   'subject'),
#  'Lazy_learning>': ('Lazy learning', 'subject'),
#  'Learnable_function_class>': ('Learnable function class', 'subject'),
#  'Learning_automata>': ('Learning automata', 'subject'),
#  'Learning_to_rank>': ('Learning to rank', 'subject'),
#  'Learning_with_errors>': ('Learning with errors', 'subject'),
#  'Leave-one-out_error>': ('Leave-one-out error', 'subject'),
#  'Linear_predictor_function>': ('Linear predictor function', 'subject'),
#  'Linear_separability>': ('Linear separability', 'subject'),
#  'List_of_datasets_for_machine_learning_research>': ('List of datasets for machine learning research',
#   'subject'),
#  'Local_case-control_sampling>': ('Local case-control sampling', 'subject'),
#  'Logic_learning_machine>': ('Logic learning machine', 'subject'),
#  'M-Theory_(learning_framework)>': ('M-Theory (learning framework)',
#   'subject'),
#  'Machine_Learning_(journal)>': ('Machine Learning (journal)', 'subject'),
#  'Machine_Teaching>': ('Machine Teaching', 'subject'),
#  'Machine_learning>': ('Machine learning', 'subject'),
#  'Manifold_regularization>': ('Manifold regularization', 'subject'),
#  'Matrix_regularization>': ('Matrix regularization', 'subject'),
#  'Matthews_correlation_coefficient>': ('Matthews correlation coefficient',
#   'subject'),
#  'Meta_learning_(computer_science)>': ('Meta learning (computer science)',
#   'subject'),
#  'Mixture_model>': ('Mixture model', 'subject'),
#  'Mountain_Car>': ('Mountain Car', 'subject'),
#  'Movidius_(company)>': ('Movidius (company)', 'subject'),
#  'Multi-armed_bandit>': ('Multi-armed bandit', 'subject'),
#  'Multi-task_learning>': ('Multi-task learning', 'subject'),
#  'Multilinear_principal_component_analysis>': ('Multilinear principal component analysis',
#   'subject'),
#  'Multilinear_subspace_learning>': ('Multilinear subspace learning',
#   'subject'),
#  'Multiple-instance_learning>': ('Multiple-instance learning', 'subject'),
#  'Multiple_instance_learning>': ('Multiple instance learning', 'subject'),
#  'Multivariate_adaptive_regression_splines>': ('Multivariate adaptive regression splines',
#   'subject'),
#  'MysteryVibe>': ('MysteryVibe', 'subject'),
#  'Native-language_identification>': ('Native-language identification',
#   'subject'),
#  'Nearest_neighbor_search>': ('Nearest neighbor search', 'subject'),
#  'Neural_modeling_fields>': ('Neural modeling fields', 'subject'),
#  'Occam_learning>': ('Occam learning', 'subject'),
#  'Offline_learning>': ('Offline learning', 'subject'),
#  'OpenNN>': ('OpenNN', 'subject'),
#  'Orange_(software)>': ('Orange (software)', 'subject'),
#  'Overfitting>': ('Overfitting', 'subject'),
#  'Parity_learning>': ('Parity learning', 'subject'),
#  'Pattern_language_(formal_languages)>': ('Pattern language (formal languages)',
#   'subject'),
#  'Pattern_recognition>': ('Pattern recognition', 'subject'),
#  'Predictive_learning>': ('Predictive learning', 'subject'),
#  'Predictive_state_representation>': ('Predictive state representation',
#   'subject'),
#  'Preference_learning>': ('Preference learning', 'subject'),
#  'Prior_knowledge_for_pattern_recognition>': ('Prior knowledge for pattern recognition',
#   'subject'),
#  'Proactive_learning>': ('Proactive learning', 'subject'),
#  'Probability_matching>': ('Probability matching', 'subject'),
#  'Product_of_experts>': ('Product of experts', 'subject'),
#  'Proximal_gradient_methods_for_learning>': ('Proximal gradient methods for learning',
#   'subject'),
#  'Quantum_machine_learning>': ('Quantum machine learning', 'subject'),
#  'Query_level_feature>': ('Query level feature', 'subject'),
#  'Rademacher_complexity>': ('Rademacher complexity', 'subject'),
#  'Random_indexing>': ('Random indexing', 'subject'),
#  'Random_projection>': ('Random projection', 'subject'),
#  'Relational_data_mining>': ('Relational data mining', 'subject'),
#  'Representer_theorem>': ('Representer theorem', 'subject'),
#  'Robot_learning>': ('Robot learning', 'subject'),
#  'Rule_induction>': ('Rule induction', 'subject'),
#  'Sample_complexity>': ('Sample complexity', 'subject'),
#  'Savi_Technology>': ('Savi Technology', 'subject'),
#  'Semantic_analysis_(machine_learning)>': ('Semantic analysis (machine learning)',
#   'subject'),
#  'Semantic_folding>': ('Semantic folding', 'subject'),
#  'Semi-supervised_learning>': ('Semi-supervised learning', 'subject'),
#  'Sequence_labeling>': ('Sequence labeling', 'subject'),
#  'Similarity_learning>': ('Similarity learning', 'subject'),
#  'Skymind>': ('Skymind', 'subject'),
#  "Solomonoff's_theory_of_inductive_inference>": ("Solomonoff's theory of inductive inference",
#   'subject'),
#  'Sparse_dictionary_learning>': ('Sparse dictionary learning', 'subject'),
#  'Spike-and-slab_variable_selection>': ('Spike-and-slab variable selection',
#   'subject'),
#  'Stability_(learning_theory)>': ('Stability (learning theory)', 'subject'),
#  'Statistical_classification>': ('Statistical classification', 'subject'),
#  'Statistical_learning_theory>': ('Statistical learning theory', 'subject'),
#  'Statistical_relational_learning>': ('Statistical relational learning',
#   'subject'),
#  'Stochastic_block_model>': ('Stochastic block model', 'subject'),
#  'Structural_risk_minimization>': ('Structural risk minimization', 'subject'),
#  'Structured_sparsity_regularization>': ('Structured sparsity regularization',
#   'subject'),
#  'Subclass_reachability>': ('Subclass reachability', 'subject'),
#  'Supervised_learning>': ('Supervised learning', 'subject'),
#  'Test_set>': ('Test set', 'subject'),
#  'The_Master_Algorithm>': ('The Master Algorithm', 'subject'),
#  'Timeline_of_machine_learning>': ('Timeline of machine learning', 'subject'),
#  'Transduction_(machine_learning)>': ('Transduction (machine learning)',
#   'subject'),
#  'Trax_Image_Recognition>': ('Trax Image Recognition', 'subject'),
#  'Ugly_duckling_theorem>': ('Ugly duckling theorem', 'subject'),
#  'Uncertain_data>': ('Uncertain data', 'subject'),
#  'Uniform_convergence_(combinatorics)>': ('Uniform convergence (combinatorics)',
#   'subject'),
#  'Universal_portfolio_algorithm>': ('Universal portfolio algorithm',
#   'subject'),
#  'Unsupervised_learning>': ('Unsupervised learning', 'subject'),
#  'User_behavior_analytics>': ('User behavior analytics', 'subject'),
#  'Validation_set>': ('Validation set', 'subject'),
#  'Vanishing_gradient_problem>': ('Vanishing gradient problem', 'subject'),
#  'Version_space_learning>': ('Version space learning', 'subject'),
#  'Word2vec>': ('Word2vec', 'subject'),
#  'Zeroth_(software)>': ('Zeroth (software)', 'subject')}

# %%
def get_lines_with_concepts(search_concepts):    
    # Loop through each line and get relevant links
    lines = []
    with bzopen('../page_links_en.ttl.bz2', 'r') as file:
        for line in tqdm(file):
            line = line.decode('utf-8')
            for concept in search_concepts.keys():
                if concept in line:
                    lines.append(line)
                    break
                    
    return lines

# %%
concept_lines = get_lines_with_concepts(search_concepts)
# Out:
# 183605697it [1:53:52, 26871.83it/s]

# %%
len(concept_lines)
# Out:
# 9333

# %%
concept_lines[0]
# Out:
# '<http://dbpedia.org/resource/Algorithm> <http://dbpedia.org/ontology/wikiPageWikiLink> <http://dbpedia.org/resource/Machine_learning> .\n'

# %%
print(re.escape('<http://dbpedia.org/resource/Algorithm>'))
# Out:
# \<http\:\/\/dbpedia\.org\/resource\/Algorithm\>

# %%
with open('concept_lines.json', 'wt') as f:
    json.dump(concept_lines, f)

# %%
CONCEPT_LINE_FROM_REGEX = r'^\<http\:\/\/dbpedia\.org\/resource\/([^>]+)\>'
CONCEPT_LINE_TO_REGEX = r'\<http\:\/\/dbpedia\.org\/resource\/([^>]+)\> \.'
def parse_concept_line(concept_line):
    from_page = re.findall(CONCEPT_LINE_FROM_REGEX, concept_line)[0]
    from_page = from_page.replace('_', ' ')
    
    to_page = re.findall(CONCEPT_LINE_TO_REGEX, concept_line)[0]
    to_page = to_page.replace('_', ' ')
    
    return (from_page, to_page)
    
parse_concept_line(concept_lines[0])
# Out:
# ('Algorithm', 'Machine learning')

# %%
concept_links = []
for line in concept_lines:
    concept_links.append(parse_concept_line(line))

# %%
concept_links
# Out:
# [('Algorithm', 'Machine learning'),
#  ('Artificial intelligence', 'Machine learning'),
#  ('Artificial intelligence', 'AlphaGo'),
#  ('Artificial intelligence', 'Unsupervised learning'),
#  ('Artificial intelligence', 'Supervised learning'),
#  ('Artificial intelligence', 'Statistical classification'),
#  ('Artificial intelligence', 'Computational learning theory'),
#  ('Artificial intelligence', 'Developmental robotics'),
#  ('Artificial intelligence', 'Pattern recognition'),
#  ('Artificial intelligence', 'Vanishing gradient problem'),
#  ('Artificial intelligence', 'Deeplearning4j'),
#  ('Artificial intelligence', 'Google DeepMind'),
#  ('Artificial intelligence', 'Glossary of artificial intelligence'),
#  ('Artificial intelligence', 'AIXI'),
#  ('Artificial intelligence', 'Machine Learning (journal)'),
#  ('Kolmogorov complexity', "Solomonoff's theory of inductive inference"),
#  ('Kolmogorov complexity', 'Grammar induction'),
#  ('Aesthetics', 'Machine learning'),
#  ('List of artificial intelligence projects', 'AIXI'),
#  ('List of artificial intelligence projects', 'Machine learning'),
#  ('List of artificial intelligence projects', 'AlphaGo'),
#  ('List of artificial intelligence projects', 'Cleverbot'),
#  ('List of artificial intelligence projects', 'Deeplearning4j'),
#  ('List of artificial intelligence projects', 'OpenNN'),
#  ('Anthropic principle', "Solomonoff's theory of inductive inference"),
#  ('Association for Computing Machinery',
#   'Journal of Machine Learning Research'),
#  ('Bell Labs', 'Machine learning'),
#  ('Boltzmann distribution', 'Machine learning'),
#  ('Bioinformatics', 'Pattern recognition'),
#  ('Bioinformatics', 'Machine learning'),
#  ('Bioinformatics', 'Orange (software)'),
#  ('Binary search algorithm', 'Nearest neighbor search'),
#  ('Bilinear map', 'Multilinear subspace learning'),
#  ('Bayesian probability', 'Machine learning'),
#  ('Computer science', 'Machine learning'),
#  ('Computer science', 'Pattern recognition'),
#  ('Computational linguistics', 'Grammar induction'),
#  ('Cognitive science', 'Machine learning'),
#  ('Cognitive psychology', 'Concept learning'),
#  ('Cognitive psychology', 'Pattern recognition'),
#  ('Cognitive psychology', 'Cognitive robotics'),
#  ('Computational chemistry', 'Machine learning'),
#  ('Computer vision', 'Pattern recognition'),
#  ('List of computer scientists', 'Machine learning'),
#  ('List of computer scientists', 'Computational learning theory'),
#  ('List of computer scientists', 'Pattern recognition'),
#  ('Cyc', 'Machine learning'),
#  ('Computer music', 'Machine learning'),
#  ('Concept', 'Formal concept analysis'),
#  ('Concept', 'Concept learning'),
#  ('Control theory', 'Machine learning'),
#  ('Complexity', 'Machine learning'),
#  ('Complexity', 'Supervised learning'),
#  ('Complexity', 'Binary classification'),
#  ('Complexity', 'Meta learning (computer science)'),
#  ('Computer security', 'Machine learning'),
#  ('Collation', 'Document classification'),
#  ('Convolution', 'Kernel density estimation'),
#  ('Data warehouse', 'Pattern recognition'),
#  ('Data compression', 'Machine learning'),
#  ('Data compression', 'Pattern recognition'),
#  ('DNA', 'Machine learning'),
#  ('Dimension', 'Curse of dimensionality'),
#  ('Digital signal processing', 'Machine learning'),
#  ('Douglas Hofstadter', 'Bongard problem'),
#  ('Design of experiments', 'Multi-armed bandit'),
#  ('Expected value', 'Machine learning'),
#  ('Functional programming', 'Inductive functional programming'),
#  ('Functional decomposition', 'Machine learning'),
#  ('Genetic programming', 'Meta learning (computer science)'),
#  ('Genetic programming', 'Inductive programming'),
#  ('Histogram', 'Kernel density estimation'),
#  ('Hank Greenberg', 'Machine learning'),
#  ('HTTPS', 'Machine learning'),
#  ('Horse', 'Concept learning'),
#  ('Hash function', 'Nearest neighbor search'),
#  ('Harmonic mean', 'Machine learning'),
#  ('Information theory', 'Pattern recognition'),
#  ('Information theory', 'Machine learning'),
#  ('Information theory', 'Inductive probability'),
#  ('Isotropy', 'Isotropic position'),
#  ('Induction', 'Concept learning'),
#  ('Immune system', 'Machine learning'),
#  ('Information retrieval', 'Learning to rank'),
#  ('Information retrieval', 'Binary classification'),
#  ('Information retrieval', 'Confusion matrix'),
#  ('Koalang', 'Machine learning'),
#  ('Logic programming', 'Machine learning'),
#  ('Logic programming', 'Statistical relational learning'),
#  ('Lossless compression', 'Grammar induction'),
#  ('Library classification', 'Document classification'),
#  ('List of algorithms', 'Nearest neighbor search'),
#  ('List of algorithms', 'Cross-entropy method'),
#  ('List of algorithms', 'Machine learning'),
#  ('List of algorithms', 'Supervised learning'),
#  ('Language acquisition', 'Statistical learning theory'),
#  ('Mars (disambiguation)', 'Multivariate adaptive regression splines'),
#  ('ML', 'Machine learning'),
#  ('Mathematical model', 'Cross-validation (statistics)'),
#  ('Memex', 'Machine learning'),
#  ('Supervised learning', 'Machine learning'),
#  ('Supervised learning', 'Training set'),
#  ('Supervised learning', 'Inductive bias'),
#  ('Supervised learning', 'Concept learning'),
#  ('Supervised learning', 'Curse of dimensionality'),
#  ('Supervised learning', 'Support vector machine'),
#  ('Supervised learning', 'Decision tree learning'),
#  ('Supervised learning', 'Cross-validation (statistics)'),
#  ('Supervised learning', 'No free lunch in search and optimization'),
#  ('Supervised learning', 'Feature selection'),
#  ('Supervised learning', 'Dimensionality reduction'),
#  ('Supervised learning', 'Target variable'),
#  ('Supervised learning', 'Overfitting'),
#  ('Supervised learning', 'Deterministic noise'),
#  ('Supervised learning', 'Early stopping'),
#  ('Supervised learning', 'Anomaly detection'),
#  ('Supervised learning', 'Generalization error'),
#  ('Supervised learning', 'Statistical significance'),
#  ('Supervised learning', 'Support Vector Machines'),
#  ('Supervised learning', 'Linear regression'),
#  ('Supervised learning', 'Logistic regression'),
#  ('Supervised learning', 'Artificial neural network'),
#  ('Supervised learning', 'K-nearest neighbor algorithm'),
#  ('Supervised learning', 'Regularization (mathematics)'),
#  ('Supervised learning', 'Naive Bayes classifier'),
#  ('Supervised learning', 'Linear discriminant analysis'),
#  ('Supervised learning', 'Multilayer perceptron'),
#  ('Supervised learning', 'Feature vector'),
#  ('Supervised learning', 'Empirical risk minimization'),
#  ('Supervised learning', 'Structural risk minimization'),
#  ('Supervised learning',
#   'Independent and identically-distributed random variables'),
#  ('Supervised learning', 'Loss function'),
#  ('Supervised learning', 'Optimization (mathematics)'),
#  ('Supervised learning', 'Maximum likelihood'),
#  ('Supervised learning', "Occam's razor"),
#  ('Supervised learning', 'Euclidean norm'),
#  ('Supervised learning', 'Posterior probability'),
#  ('Supervised learning', 'Discriminative model'),
#  ('Supervised learning', 'Generative model'),
#  ('Supervised learning', 'Semi-supervised learning'),
#  ('Supervised learning', 'Active learning (machine learning)'),
#  ('Supervised learning', 'Structured prediction'),
#  ('Supervised learning', 'Learning to rank'),
#  ('Supervised learning', 'Analytical learning'),
#  ('Supervised learning', 'Backpropagation'),
#  ('Supervised learning', 'Boosting (meta-algorithm)'),
#  ('Supervised learning', 'Bayesian statistics'),
#  ('Supervised learning', 'Case-based reasoning'),
#  ('Supervised learning', 'Inductive logic programming'),
#  ('Supervised learning', 'Gaussian process regression'),
#  ('Supervised learning', 'Group method of data handling'),
#  ('Supervised learning', 'Variable kernel density estimation'),
#  ('Supervised learning', 'Learning Automata'),
#  ('Supervised learning', 'Learning classifier system'),
#  ('Supervised learning', 'Minimum message length'),
#  ('Supervised learning', 'Decision tree'),
#  ('Supervised learning', 'Multilinear subspace learning'),
#  ('Supervised learning', 'Naive bayes classifier'),
#  ('Supervised learning', 'Maximum entropy classifier'),
#  ('Supervised learning', 'Conditional random field'),
#  ('Supervised learning', 'Nearest neighbor (pattern recognition)'),
#  ('Supervised learning', 'Probably approximately correct learning'),
#  ('Supervised learning', 'Ripple down rules'),
#  ('Supervised learning', 'Symbolic machine learning'),
#  ('Supervised learning', 'Subsymbolic machine learning'),
#  ('Supervised learning', 'Random forest'),
#  ('Supervised learning', 'Ensembles of Classifiers'),
#  ('Supervised learning', 'Ordinal classification'),
#  ('Supervised learning', 'Data Pre-processing'),
#  ('Supervised learning', 'Handling imbalanced datasets'),
#  ('Supervised learning', 'Statistical relational learning'),
#  ('Supervised learning', 'Proaftn'),
#  ('Supervised learning', 'Bioinformatics'),
#  ('Supervised learning', 'Cheminformatics'),
#  ('Supervised learning', 'Quantitative structure–activity relationship'),
#  ('Supervised learning', 'Database marketing'),
#  ('Supervised learning', 'Handwriting recognition'),
#  ('Supervised learning', 'Information retrieval'),
#  ('Supervised learning', 'Information extraction'),
#  ('Supervised learning', 'Computer vision'),
#  ('Supervised learning', 'Optical character recognition'),
#  ('Supervised learning', 'Spamming'),
#  ('Supervised learning', 'Pattern recognition'),
#  ('Supervised learning', 'Speech recognition'),
#  ('Supervised learning', 'Downward causation'),
#  ('Supervised learning', 'Computational learning theory'),
#  ('Supervised learning', 'Overfitting (machine learning)'),
#  ('Supervised learning', 'Class membership probabilities'),
#  ('Supervised learning', 'Unsupervised learning'),
#  ('Supervised learning', 'Version space'),
#  ('Supervised learning', 'List of datasets for machine learning research'),
#  ('Supervised learning', 'Category:Machine learning'),
#  ('Nevanlinna Prize', 'Pattern recognition'),
#  ('Artificial neural network', 'Machine learning'),
#  ('Artificial neural network', 'Unsupervised learning'),
#  ('Artificial neural network', 'Pattern recognition'),
#  ('Artificial neural network', 'Supervised learning'),
#  ('Artificial neural network', 'Statistical classification'),
#  ('Artificial neural network', 'Google DeepMind'),
#  ('Artificial neural network', 'Cross-validation (statistics)'),
#  ('Artificial neural network', 'Vanishing gradient problem'),
#  ('Artificial neural network', 'Committee machine'),
#  ('Artificial neural network', 'Instantaneously trained neural networks'),
#  ('Artificial neural network', 'Catastrophic interference'),
#  ('Artificial neural network', 'Multilinear subspace learning'),
#  ('Natural language processing', 'Machine learning'),
#  ('Natural language processing', 'Unsupervised learning'),
#  ('Natural language processing', 'Semi-supervised learning'),
#  ('Natural language processing', 'Supervised learning'),
#  ('Natural language processing', 'Native-language identification'),
#  ('Natural language processing', 'Semantic folding'),
#  ('Natural language processing', 'Word2vec'),
#  ('B-spline', 'Overfitting'),
#  ('Orange', 'Orange (software)'),
#  ('Online algorithm', 'Offline learning'),
#  ('Probability', 'Machine learning'),
#  ('Qt (software)', 'Orange (software)'),
#  ('Random variable', 'Machine learning'),
#  ('Radar', 'Machine learning'),
#  ('Regular expression', 'Grammar induction'),
#  ('Regular expression', 'Computational learning theory'),
#  ('Robot', 'Developmental robotics'),
#  ('Robot', 'Cognitive robotics'),
#  ('Statistics', 'Machine learning'),
#  ('Statistics', 'Pattern recognition'),
#  ('Statistics', 'Statistical classification'),
#  ('Statistical inference', 'Statistical classification'),
#  ('Statistical inference', 'Algorithmic inference'),
#  ('Statistical population', 'Mixture model'),
#  ('Spreadsheet', 'Machine learning'),
#  ('Separability', 'Linear separability'),
#  ('Outline of statistics', 'Kernel density estimation'),
#  ('Stability', 'Stability (learning theory)'),
#  ('SSL', 'Semi-supervised learning'),
#  ('Semantics', 'Semantic analysis (machine learning)'),
#  ('Speech recognition', 'Vanishing gradient problem'),
#  ('Speech recognition', 'Mixture model'),
#  ('Speech recognition', 'Document classification'),
#  ('Speech recognition', 'Feature engineering'),
#  ('Tensor', 'Multilinear subspace learning'),
#  ('Tensor product', 'Multilinear subspace learning'),
#  ('Visual cortex', 'Pattern recognition'),
#  ('Web crawler', 'Machine learning'),
#  ('Wearable computer', 'Pattern recognition'),
#  ('WordNet', 'Document classification'),
#  ('WarGames', 'Machine learning'),
#  ("Occam's razor", "Solomonoff's theory of inductive inference"),
#  ("Occam's razor", 'Overfitting'),
#  ("Occam's razor", 'Test set'),
#  ("Occam's razor", 'Inductive probability'),
#  ('Philosophy of science', 'Overfitting'),
#  ('Similarity (geometry)', 'Nearest neighbor search'),
#  ('Genetic algorithm', 'Cross-entropy method'),
#  ('Convex hull', 'Pattern recognition'),
#  ('Coding', 'Statistical classification'),
#  ('Bias', 'Machine learning'),
#  ('Dropout', 'Dropout (neural networks)'),
#  ('Label (disambiguation)', 'Machine learning'),
#  ('Stanislaw Ulam', 'Pattern recognition'),
#  ('Minimum spanning tree', 'Conditional random field'),
#  ('Accuracy and precision', 'Binary classification'),
#  ('Group theory', 'Pattern recognition'),
#  ('Data mining', 'Machine learning'),
#  ('Data mining', 'Data pre-processing'),
#  ('Data mining', 'Statistical classification'),
#  ('Data mining', 'Overfitting'),
#  ('Data mining', 'Test set'),
#  ('Data mining', 'OpenNN'),
#  ('Data mining', 'Orange (software)'),
#  ('Data mining', 'Multilinear subspace learning'),
#  ('List of free and open-source software packages', 'OpenNN'),
#  ('List of free and open-source software packages', 'Orange (software)'),
#  ('Steven Pinker', 'Computational learning theory'),
#  ('Complete lattice', 'Formal concept analysis'),
#  ('Exponential distribution', 'Bias–variance tradeoff'),
#  ('Entropy encoding', 'Statistical classification'),
#  ('Vector quantization', 'Pattern recognition'),
#  ('Free will', 'Cognitive robotics'),
#  ('Autonomous robot', 'Cognitive robotics'),
#  ('Dopamine', 'Machine learning'),
#  ('Wolfram Mathematica', 'Supervised learning'),
#  ('Wolfram Mathematica', 'Unsupervised learning'),
#  ('Wolfram Mathematica', 'Machine learning'),
#  ('Optical character recognition', 'Pattern recognition'),
#  ('Optical character recognition', 'Machine learning'),
#  ('Fuzzy logic', 'Machine learning'),
#  ("Bayes' theorem", 'Inductive probability'),
#  ('Bayesian inference', 'Pattern recognition'),
#  ('Bayesian inference', 'Statistical classification'),
#  ('Bayesian inference', "Solomonoff's theory of inductive inference"),
#  ('Bayesian inference', 'Machine learning'),
#  ('Bayesian inference', 'Inductive probability'),
#  ('Ontology (information science)', 'Formal concept analysis'),
#  ("Prosecutor's fallacy", 'Binary classification'),
#  ('Multivariate normal distribution', 'Mixture model'),
#  ('Cerebellum', 'Supervised learning'),
#  ('Cerebellum', 'Unsupervised learning'),
#  ('Wavelet', 'Pattern recognition'),
#  ('University College London', 'DeepMind'),
#  ('Observational learning', 'Machine learning'),
#  ('John Goldsmith (linguist)', 'Unsupervised learning'),
#  ('Inductive logic programming', 'Machine learning'),
#  ('Inductive logic programming', 'Formal concept analysis'),
#  ('Inductive logic programming', 'Inductive programming'),
#  ('Inductive logic programming', 'Inductive probability'),
#  ('Inductive logic programming', 'Statistical relational learning'),
#  ('Inductive logic programming', 'Version space learning'),
#  ('Monte Carlo method', 'Curse of dimensionality'),
#  ('Linear subspace', 'Multilinear subspace learning'),
#  ('Abductive reasoning', 'Inductive probability'),
#  ('Markov chain', 'Pattern recognition'),
#  ('Financial economics', 'Mixture model'),
#  ('Go (game)', 'Google DeepMind'),
#  ('Go (game)', 'AlphaGo'),
#  ('Support vector machine', 'Machine learning'),
#  ('Support vector machine', 'Supervised learning'),
#  ('Support vector machine', 'Statistical classification'),
#  ('Support vector machine', 'Linear separability'),
#  ('Support vector machine', 'Empirical risk minimization'),
#  ('Support vector machine', 'Cross-validation (statistics)'),
#  ('Support vector machine', 'Bayesian optimization'),
#  ('Support vector machine', 'Binary classification'),
#  ('Support vector machine', 'Semi-supervised learning'),
#  ('Support vector machine', 'Transduction (machine learning)'),
#  ('Support vector machine', 'Category:Statistical classification'),
#  ('Operational definition', 'Pattern recognition'),
#  ('Hexose', 'Machine learning'),
#  ('Reinforcement learning', 'Machine learning'),
#  ('Reinforcement learning', 'Supervised learning'),
#  ('Reinforcement learning', 'Multi-armed bandit'),
#  ('Reinforcement learning', 'AlphaGo'),
#  ('Reinforcement learning', 'Cross-entropy method'),
#  ('Reinforcement learning', 'Orange (software)'),
#  ('Reinforcement learning', 'Apprenticeship learning'),
#  ('Word-sense disambiguation', 'Machine learning'),
#  ('Word-sense disambiguation', 'Supervised learning'),
#  ('Word-sense disambiguation', 'Semi-supervised learning'),
#  ('Word-sense disambiguation', 'Unsupervised learning'),
#  ('Word-sense disambiguation', 'Test set'),
#  ('Ulam spiral', 'Pattern recognition'),
#  ('Synonym', 'Machine learning'),
#  ('Pattern', 'Pattern recognition'),
#  ('Computer chess', 'Pattern recognition'),
#  ('Gestalt psychology', 'Pattern recognition'),
#  ('Butlerian Jihad', 'Cognitive robotics'),
#  ('Categorization', 'Unsupervised learning'),
#  ('Categorization', 'Supervised learning'),
#  ('Categorization', 'Concept learning'),
#  ('Categorization', 'Machine learning'),
#  ('Categorization', 'Pattern recognition'),
#  ('Principal component analysis', 'Dimensionality reduction'),
#  ('Principal component analysis', 'Overfitting'),
#  ('Principal component analysis', 'Pattern recognition'),
#  ('Principal component analysis', 'Multilinear subspace learning'),
#  ('Principal component analysis', 'Multilinear principal component analysis'),
#  ('Principal component analysis', 'Orange (software)'),
#  ('Self-organizing map', 'Unsupervised learning'),
#  ('Least squares', 'Proximal gradient methods for learning'),
#  ('Logistic function', 'Machine learning'),
#  ('Hapax legomenon', 'Machine learning'),
#  ('Naive Bayes classifier', 'Machine learning'),
#  ('Naive Bayes classifier', 'Feature vector'),
#  ('Naive Bayes classifier', 'Supervised learning'),
#  ('Naive Bayes classifier', 'Statistical classification'),
#  ('Naive Bayes classifier', 'Semi-supervised learning'),
#  ('Naive Bayes classifier', 'Mixture model'),
#  ('Naive Bayes classifier', 'Curse of dimensionality'),
#  ('Naive Bayes classifier', 'Document classification'),
#  ('Naive Bayes classifier', 'Machine Learning (journal)'),
#  ('Naive Bayes classifier', 'Orange (software)'),
#  ('Naive Bayes classifier', 'Category:Statistical classification'),
#  ('The Age of Spiritual Machines', 'Pattern recognition'),
#  ('Greedy algorithm', 'Multi-armed bandit'),
#  ("Arrow's impossibility theorem", 'Learning to rank'),
#  ('Information visualization', 'Machine learning'),
#  ('Information visualization', 'Statistical classification'),
#  ('Boosting (machine learning)', 'Supervised learning'),
#  ('Boosting (machine learning)', 'Machine learning'),
#  ('Boosting (machine learning)', 'Unsupervised learning'),
#  ('Boosting (machine learning)', 'Cross-validation (statistics)'),
#  ('Boosting (machine learning)',
#   'List of datasets for machine learning research'),
#  ('Boosting (machine learning)', 'Orange (software)'),
#  ('Digital image processing', 'Statistical classification'),
#  ('Digital image processing', 'Pattern recognition'),
#  ('Natural language understanding', 'Machine learning'),
#  ('Hidden Markov model', 'Mixture model'),
#  ('Hidden Markov model', 'Generative model'),
#  ('Hidden Markov model', 'Unsupervised learning'),
#  ('Hidden Markov model', 'Discriminative model'),
#  ('Hidden Markov model', 'Conditional random field'),
#  ('Linear classifier', 'Machine learning'),
#  ('Linear classifier', 'Statistical classification'),
#  ('Linear classifier', 'Feature vector'),
#  ('Linear classifier', 'Document classification'),
#  ('Linear classifier', 'Discriminative model'),
#  ('Linear classifier', 'Dimensionality reduction'),
#  ('Linear classifier', 'Supervised learning'),
#  ('Linear classifier', 'Unsupervised learning'),
#  ('Linear classifier', 'Overfitting'),
#  ('Linear classifier', 'Category:Statistical classification'),
#  ('Hyperplane', 'Machine learning'),
#  ('Douglas Lenat', 'Machine learning'),
#  ('Brute-force search', 'Curse of dimensionality'),
#  ("Student's t-distribution", 'Curse of dimensionality'),
#  ('Cognition', 'Pattern recognition'),
#  ('Intrusion detection system', 'Machine learning'),
#  ('Prevalence', 'Base rate'),
#  ('Pattern recognition', 'Machine learning'),
#  ('Pattern recognition', 'Data'),
#  ('Pattern recognition', 'Supervised learning'),
#  ('Pattern recognition', 'Unsupervised learning'),
#  ('Pattern recognition', 'Data mining'),
#  ('Pattern recognition', 'Knowledge discovery in databases'),
#  ('Pattern recognition', 'Artificial intelligence'),
#  ('Pattern recognition', 'Engineering'),
#  ('Pattern recognition', 'Computer vision'),
#  ('Pattern recognition',
#   'Conference on Computer Vision and Pattern Recognition'),
#  ('Pattern recognition', 'Linear discriminant analysis'),
#  ('Pattern recognition', 'Classification (machine learning)'),
#  ('Pattern recognition', 'Regression analysis'),
#  ('Pattern recognition', 'Sequence labeling'),
#  ('Pattern recognition', 'Part of speech tagging'),
#  ('Pattern recognition', 'Part of speech'),
#  ('Pattern recognition', 'Parsing'),
#  ('Pattern recognition', 'Parse tree'),
#  ('Pattern recognition', 'Syntactic structure'),
#  ('Pattern recognition', 'Pattern matching'),
#  ('Pattern recognition', 'Regular expression'),
#  ('Pattern recognition', 'Text editor'),
#  ('Pattern recognition', 'Word processor'),
#  ('Pattern recognition', 'Training set'),
#  ('Pattern recognition', "Occam's Razor"),
#  ('Pattern recognition', 'Semi-supervised learning'),
#  ('Pattern recognition', 'Data clustering'),
#  ('Pattern recognition', 'Distance'),
#  ('Pattern recognition', 'Vector space'),
#  ('Pattern recognition', 'Community ecology'),
#  ('Pattern recognition', 'Feature vector'),
#  ('Pattern recognition', 'Space (mathematics)'),
#  ('Pattern recognition', 'Dot product'),
#  ('Pattern recognition', 'Categorical data'),
#  ('Pattern recognition', 'Nominal data'),
#  ('Pattern recognition', 'Ordinal data'),
#  ('Pattern recognition', 'Integer'),
#  ('Pattern recognition', 'Real number'),
#  ('Pattern recognition', 'Statistical inference'),
#  ('Pattern recognition', 'Probability'),
#  ('Pattern recognition', 'Probability theory'),
#  ('Pattern recognition', 'Feature selection'),
#  ('Pattern recognition', 'Optimization problem'),
#  ('Pattern recognition', 'Powerset'),
#  ('Pattern recognition', 'Branch and bound'),
#  ('Pattern recognition', 'Feature extraction'),
#  ('Pattern recognition', 'Principal components analysis'),
#  ('Pattern recognition', 'Decision theory'),
#  ('Pattern recognition', 'Loss function'),
#  ('Pattern recognition', 'Expected value'),
#  ('Pattern recognition', 'Probability distribution'),
#  ('Pattern recognition', 'Zero-one loss function'),
#  ('Pattern recognition', 'Bayes error rate'),
#  ('Pattern recognition', 'Correctness (computer science)'),
#  ('Pattern recognition', 'Discriminative model'),
#  ('Pattern recognition', 'Generative model'),
#  ('Pattern recognition', 'Prior probability'),
#  ('Pattern recognition', "Bayes' rule"),
#  ('Pattern recognition', 'Continuous distribution'),
#  ('Pattern recognition', 'Integral'),
#  ('Pattern recognition', 'Maximum a posteriori'),
#  ('Pattern recognition', 'Maximum likelihood'),
#  ('Pattern recognition', 'Regularization (mathematics)'),
#  ('Pattern recognition', 'Bayesian inference'),
#  ('Pattern recognition', 'Posterior probability'),
#  ('Pattern recognition', 'Bayesian statistics'),
#  ('Pattern recognition', 'Fisher discriminant analysis'),
#  ('Pattern recognition', 'Frequentist inference'),
#  ('Pattern recognition', 'Covariance matrix'),
#  ('Pattern recognition', 'Bayes rule'),
#  ('Pattern recognition', 'A priori and a posteriori'),
#  ('Pattern recognition', 'Beta distribution'),
#  ('Pattern recognition', 'Conjugate prior distribution'),
#  ('Pattern recognition', 'Dirichlet distribution'),
#  ('Pattern recognition',
#   'File:800px-Cool Kids of Death Off Festival p 146-face selected.jpg'),
#  ('Pattern recognition', 'Computer-aided diagnosis'),
#  ('Pattern recognition',
#   'File:SRT Shape Recognition Technology Principles.png'),
#  ('Pattern recognition', 'Speech recognition'),
#  ('Pattern recognition', 'Document classification'),
#  ('Pattern recognition', 'Handwriting recognition'),
#  ('Pattern recognition', 'Image analysis'),
#  ('Pattern recognition', 'Artificial neural networks'),
#  ('Pattern recognition', 'Deep Learning'),
#  ('Pattern recognition', 'Pattern recognition (psychology)'),
#  ('Pattern recognition', 'Quadratic classifier'),
#  ('Pattern recognition', 'Maximum entropy classifier'),
#  ('Pattern recognition', 'Logistic regression'),
#  ('Pattern recognition', 'Multinomial logistic regression'),
#  ('Pattern recognition', 'Decision tree'),
#  ('Pattern recognition', 'Decision list'),
#  ('Pattern recognition', 'Variable kernel density estimation'),
#  ('Pattern recognition', 'K-nearest-neighbor'),
#  ('Pattern recognition', 'Naive Bayes classifier'),
#  ('Pattern recognition', 'Neural network'),
#  ('Pattern recognition', 'Perceptron'),
#  ('Pattern recognition', 'Support vector machine'),
#  ('Pattern recognition', 'Gene expression programming'),
#  ('Pattern recognition', 'Cluster analysis'),
#  ('Pattern recognition', 'Mixture model'),
#  ('Pattern recognition', 'Deep learning'),
#  ('Pattern recognition', 'Hierarchical clustering'),
#  ('Pattern recognition', 'K-means clustering'),
#  ('Pattern recognition', 'Correlation clustering'),
#  ('Pattern recognition', 'Kernel principal component analysis'),
#  ('Pattern recognition', 'Ensemble learning'),
#  ('Pattern recognition', 'Meta-algorithm'),
#  ('Pattern recognition', 'Boosting (meta-algorithm)'),
#  ('Pattern recognition', 'Bootstrap aggregating'),
#  ('Pattern recognition', 'Ensemble averaging'),
#  ('Pattern recognition', 'Mixture of experts'),
#  ('Pattern recognition', 'Hierarchical mixture of experts'),
#  ('Pattern recognition', 'Bayesian network'),
#  ('Pattern recognition', 'Markov random field'),
#  ('Pattern recognition', 'Multilinear subspace learning'),
#  ('Pattern recognition', 'Tensor'),
#  ('Pattern recognition', 'Multilinear principal component analysis'),
#  ('Pattern recognition', 'Kalman filter'),
#  ('Pattern recognition', 'Particle filter'),
#  ('Pattern recognition', 'Gaussian process regression'),
#  ('Pattern recognition', 'Linear regression'),
#  ('Pattern recognition', 'Independent component analysis'),
#  ('Pattern recognition', 'Conditional random field'),
#  ('Pattern recognition', 'Hidden Markov model'),
#  ('Pattern recognition', 'Maximum entropy Markov model'),
#  ('Pattern recognition', 'Recurrent neural networks'),
#  ('Pattern recognition', 'Adaptive resonance theory'),
#  ('Pattern recognition', 'Black box'),
#  ('Pattern recognition', 'Cache language model'),
#  ('Pattern recognition', 'Compound term processing'),
#  ('Pattern recognition', 'List of numerical analysis software'),
#  ('Pattern recognition', 'List of numerical libraries'),
#  ('Pattern recognition', 'Neocognitron'),
#  ('Pattern recognition', 'Perception'),
#  ('Pattern recognition', 'Perceptual learning'),
#  ('Pattern recognition', 'Predictive analytics'),
#  ('Pattern recognition', 'Prior knowledge for pattern recognition'),
#  ('Pattern recognition', 'Sequence mining'),
#  ('Pattern recognition', 'Template matching'),
#  ('Pattern recognition', 'Contextual image classification'),
#  ('Pattern recognition', 'List of datasets for machine learning research'),
#  ('Pattern recognition', 'Category:Machine learning'),
#  ('Pattern recognition', 'Category:Formal sciences'),
#  ('Pattern recognition', 'Category:Pattern recognition'),
#  ('List of statisticians', 'Machine learning'),
#  ('Singular value decomposition', 'Pattern recognition'),
#  ('Singular value decomposition', 'Multilinear principal component analysis'),
#  ('Singular value decomposition', 'Multilinear subspace learning'),
#  ('Singular value decomposition', 'Dimensionality reduction'),
#  ('Singular value decomposition', 'Curse of dimensionality'),
#  ('Singular value decomposition', 'Nearest neighbor search'),
#  ('Creativity', 'Computational learning theory'),
#  ('Creativity', 'Machine learning'),
#  ('Medical ultrasound', 'Pattern recognition'),
#  ("There ain't no such thing as a free lunch", 'Machine learning'),
#  ('CCM', 'Constrained conditional model'),
#  ('Polysemy', 'Machine learning'),
#  ('Training', 'Machine learning'),
#  ('Total Information Awareness', 'Pattern recognition'),
#  ('Tree decomposition', 'Machine learning'),
#  ("Goodhart's law", 'Overfitting'),
#  ('Interval estimation', 'Algorithmic inference'),
#  ('Point estimation', 'Algorithmic inference'),
#  ('Box plot', 'Kernel density estimation'),
#  ('Outlier', 'Mixture model'),
#  ('Index of cognitive science articles', 'Machine learning'),
#  ('Fokker–Planck equation', 'Mixture model'),
#  ('Human intelligence', 'Concept learning'),
#  ('Human intelligence', 'Pattern recognition'),
#  ('Membrane topology', 'Supervised learning'),
#  ('Membrane topology', 'Unsupervised learning'),
#  ('Outline of computer science', 'Machine learning'),
#  ('Numerical integration', 'Curse of dimensionality'),
#  ('Case-based reasoning', 'Rule induction'),
#  ('Case-based reasoning', 'Machine learning'),
#  ('Machine vision', 'Pattern recognition'),
#  ('Simulated annealing', 'Cross-entropy method'),
#  ('Perceptron', 'Machine learning'),
#  ('Perceptron', 'Binary classification'),
#  ('Perceptron', 'Linear predictor function'),
#  ('Perceptron', 'Feature vector'),
#  ('Perceptron', 'Offline learning'),
#  ('Perceptron', 'Overfitting'),
#  ('Ley line', 'Pattern recognition'),
#  ('Overfitting', 'File:Overfitted Data.png'),
#  ('Overfitting', 'Statistics'),
#  ('Overfitting', 'Machine learning'),
#  ('Overfitting', 'Training data'),
#  ('Overfitting', 'Statistical model'),
#  ('Overfitting', 'Random error'),
#  ('Overfitting', 'Parameter'),
#  ('Overfitting', 'Predictive inference'),
#  ('Overfitting', 'Model error'),
#  ('Overfitting', 'Coefficient of determination'),
#  ('Overfitting', 'Shrinkage (statistics)'),
#  ('Overfitting', 'Cross-validation (statistics)'),
#  ('Overfitting', 'Regularization (mathematics)'),
#  ('Overfitting', 'Early stopping'),
#  ('Overfitting', 'Pruning (algorithm)'),
#  ('Overfitting', 'Prior distribution'),
#  ('Overfitting', 'Bayesian model comparison'),
#  ('Overfitting', 'File:Overfitting svg.svg'),
#  ('Overfitting', 'Algorithm'),
#  ('Overfitting', "Occam's razor"),
#  ('Overfitting', 'Causal relation'),
#  ('Overfitting', 'Function approximation'),
#  ('Overfitting', 'Robustness (computer science)'),
#  ('Overfitting', 'Linear regression'),
#  ('Overfitting', 'Bias–variance tradeoff'),
#  ('Overfitting', 'Curve fitting'),
#  ('Overfitting', 'Data dredging'),
#  ('Overfitting', 'Model selection'),
#  ('Overfitting', 'VC dimension'),
#  ('Overfitting', 'Journal of Chemical Information and Modeling'),
#  ('Overfitting', 'Category:Statistical inference'),
#  ('Overfitting', 'Category:Regression analysis'),
#  ('Overfitting', 'Category:Machine learning'),
#  ('Automation', 'Pattern recognition'),
#  ('Inductive bias', 'Learning algorithm'),
#  ('Inductive bias', 'Machine learning'),
#  ('Inductive bias', "Occam's razor"),
#  ('Inductive bias', 'Mathematical logic'),
#  ('Inductive bias', 'Neural networks'),
#  ('Inductive bias', 'Conditional independence'),
#  ('Inductive bias', 'Bayesian inference'),
#  ('Inductive bias', 'Naive Bayes classifier'),
#  ('Inductive bias', 'Cross-validation (statistics)'),
#  ('Inductive bias', 'No free lunch in search and optimization'),
#  ('Inductive bias', 'Support vector machines'),
#  ('Inductive bias', 'Minimum description length'),
#  ('Inductive bias', 'Feature space'),
#  ('Inductive bias', 'Feature selection'),
#  ('Inductive bias', 'K-nearest neighbors algorithm'),
#  ('Inductive bias', 'Bias'),
#  ('Inductive bias', 'Cognitive bias'),
#  ('Inductive bias', 'Category:Bias'),
#  ('Inductive bias', 'Category:Machine learning'),
#  ('Robot control', 'Robot learning'),
#  ('Computational geometry', 'Nearest neighbor search'),
#  ('Problem of induction', "Solomonoff's theory of inductive inference"),
#  ('Voronoi diagram', 'Nearest neighbor search'),
#  ('Voronoi diagram', 'Machine learning'),
#  ('Kalman filter', 'Generative model'),
#  ('Learning', 'Machine learning'),
#  ('Learning', 'Inductive probability'),
#  ('Learning', "Solomonoff's theory of inductive inference"),
#  ('Description logic', 'Formal concept analysis'),
#  ('CRF', 'Conditional random field'),
#  ('Feature', 'Feature (machine learning)'),
#  ('DL', 'Machine learning'),
#  ('Classical conditioning', 'Machine learning'),
#  ('Coevolution', 'Machine learning'),
#  ('List of statistics articles', 'Accuracy paradox'),
#  ('List of statistics articles', 'Algorithmic inference'),
#  ('List of statistics articles', 'Base rate'),
#  ('List of statistics articles', 'Binary classification'),
#  ('List of statistics articles', 'Computational learning theory'),
#  ('List of statistics articles', 'Conditional random field'),
#  ('List of statistics articles', 'Cross-entropy method'),
#  ('List of statistics articles', 'Cross-validation (statistics)'),
#  ('List of statistics articles', 'Discriminative model'),
#  ('List of statistics articles', 'Expectation propagation'),
#  ('List of statistics articles', 'Generative model'),
#  ('List of statistics articles', 'Kernel density estimation'),
#  ('List of statistics articles', 'Machine learning'),
#  ('List of statistics articles', 'Matthews correlation coefficient'),
#  ('List of statistics articles', 'Mixture model'),
#  ('List of statistics articles', 'Multi-armed bandit'),
#  ('List of statistics articles', 'Multilinear principal component analysis'),
#  ('List of statistics articles', 'Multivariate adaptive regression splines'),
#  ('List of statistics articles', 'Overfitting'),
#  ('List of statistics articles', 'Pattern recognition'),
#  ('List of statistics articles', 'Prior knowledge for pattern recognition'),
#  ('List of statistics articles', 'Probability matching'),
#  ('List of statistics articles', 'Statistical classification'),
#  ('List of statistics articles', 'Statistical learning theory'),
#  ('List of statistics articles', 'Statistical relational learning'),
#  ('List of statistics articles', 'Test set'),
#  ('Concept lattice', 'Formal concept analysis'),
#  ('Artificial consciousness', 'Cognitive robotics'),
#  ('ILLIAC III', 'Pattern recognition'),
#  ('Statistical learning', 'Machine learning'),
#  ('Soft computing', 'Machine learning'),
#  ('Principle of maximum entropy', 'Machine learning'),
#  ('Inverse problem', 'Machine learning'),
#  ('Inverse problem', 'Overfitting'),
#  ('Bayesian network', 'Machine learning'),
#  ('Bayesian network', 'Statistical relational learning'),
#  ('Bayesian network', 'Document classification'),
#  ('Bayesian network', 'Mixture model'),
#  ('Binary classification', 'Statistical classification'),
#  ('Binary classification', 'Set (mathematics)'),
#  ('Binary classification', 'Classification rule'),
#  ('Binary classification', 'Qualitative property'),
#  ('Binary classification', 'Medical test'),
#  ('Binary classification', 'Test method'),
#  ('Binary classification', 'Quality control'),
#  ('Binary classification', 'Go/no go'),
#  ('Binary classification', 'Information retrieval'),
#  ('Binary classification', 'Result set'),
#  ('Binary classification', 'Discretization'),
#  ('Binary classification', 'Type I and type II errors'),
#  ('Binary classification', 'False positives and false negatives'),
#  ('Binary classification', 'Machine learning'),
#  ('Binary classification', 'Supervised learning'),
#  ('Binary classification', 'Decision tree learning'),
#  ('Binary classification', 'Random forests'),
#  ('Binary classification', 'Bayesian network'),
#  ('Binary classification', 'Support vector machine'),
#  ('Binary classification', 'Neural network'),
#  ('Binary classification', 'Logistic regression'),
#  ('Binary classification', 'Feature vector'),
#  ('Binary classification', 'File:Binary-classification-labeled.svg'),
#  ('Binary classification', 'Sensitivity and specificity'),
#  ('Binary classification', 'Precision and recall'),
#  ('Binary classification', 'Prevalence'),
#  ('Binary classification', 'True positive'),
#  ('Binary classification', 'True negative'),
#  ('Binary classification', 'False positive'),
#  ('Binary classification', 'False negative'),
#  ('Binary classification', 'Contingency table'),
#  ('Binary classification', 'True Positive Rate'),
#  ('Binary classification', 'Sensitivity (tests)'),
#  ('Binary classification', 'Recall (information retrieval)'),
#  ('Binary classification', 'False Negative Rate'),
#  ('Binary classification', 'True Negative Rate'),
#  ('Binary classification', 'Specificity (tests)'),
#  ('Binary classification', 'False Positive Rate'),
#  ('Binary classification', 'Positive Predictive Value'),
#  ('Binary classification', 'Precision (information retrieval)'),
#  ('Binary classification', 'False Discovery Rate'),
#  ('Binary classification', 'Negative Predictive Value'),
#  ('Binary classification', 'False Omission Rate'),
#  ('Binary classification', 'Likelihood ratio (disambiguation)'),
#  ('Binary classification', 'Likelihood ratios in diagnostic testing'),
#  ('Binary classification', 'Diagnostic odds ratio'),
#  ('Binary classification', 'Odds ratio'),
#  ('Binary classification', 'Accuracy and precision'),
#  ('Binary classification', 'F-score'),
#  ('Binary classification', 'F1 score'),
#  ('Binary classification', 'Regression coefficient'),
#  ('Binary classification', 'Markedness'),
#  ('Binary classification', 'Informedness'),
#  ('Binary classification', 'Geometric mean'),
#  ('Binary classification', 'Matthews correlation coefficient'),
#  ('Binary classification', "Youden's J statistic"),
#  ('Binary classification', 'Uncertainty coefficient'),
#  ('Binary classification', 'Blood values'),
#  ('Binary classification', 'Cutoff (reference value)'),
#  ('Binary classification', 'Positive or negative test'),
#  ('Binary classification', 'Positive predictive value'),
#  ('Binary classification', 'Negative predictive value'),
#  ('Binary classification', 'Predictive value'),
#  ('Binary classification', 'Human chorionic gonadotropin'),
#  ('Binary classification', 'Pregnancy test'),
#  ('Binary classification', 'Bayesian inference'),
#  ('Binary classification', 'Detection theory'),
#  ('Binary classification', 'Kernel methods'),
#  ('Binary classification', 'Multiclass classification'),
#  ('Binary classification', 'Multi-label classification'),
#  ('Binary classification', 'One-class classification'),
#  ('Binary classification', "Prosecutor's fallacy"),
#  ('Binary classification', 'Receiver operating characteristic'),
#  ('Binary classification', 'Thresholding (image processing)'),
#  ('Binary classification', 'Nello Cristianini'),
#  ('Binary classification', 'John Shawe-Taylor'),
#  ('Binary classification', 'Category:Statistical classification'),
#  ('Binary classification', 'Category:Machine learning'),
#  ('Vladimir Vapnik', 'Machine learning'),
#  ('Vladimir Vapnik', 'Statistical learning theory'),
#  ('Vladimir Vapnik', 'Structural risk minimization'),
#  ('Declarative programming', 'Inductive programming'),
#  ('Tom Ridge', 'Savi Technology'),
#  ('Early stopping', 'Machine learning'),
#  ('Early stopping', 'Regularization (mathematics)'),
#  ('Early stopping', 'Overfitting'),
#  ('Early stopping', 'Gradient descent'),
#  ('Early stopping', 'Generalization error'),
#  ('Early stopping', 'File:Overfitting on Training Set Data.pdf'),
#  ('Early stopping', 'Tikhonov regularization'),
#  ('Early stopping', 'Principal component regression'),
#  ('Early stopping', 'Spectral regularization'),
#  ('Early stopping', 'Statistical learning theory'),
#  ('Early stopping', 'Non-parametric regression'),
#  ('Early stopping', 'Reproducing kernel Hilbert space'),
#  ('Early stopping', 'Bias-variance dilemma'),
#  ('Early stopping', 'Boosting (machine learning)'),
#  ('Early stopping', 'AdaBoost'),
#  ('Early stopping', 'Consistency (statistics)'),
#  ('Early stopping', 'Validation set'),
#  ('Early stopping', 'Artificial neural network'),
#  ('Early stopping', 'Holdout method'),
#  ('Early stopping', 'Cross-validation (statistics)'),
#  ('Early stopping', 'Category:Machine learning'),
#  ('Early stopping', 'Category:Artificial neural networks'),
#  ('Self-modifying code', 'Machine learning'),
#  ('Rote learning', 'Machine learning'),
#  ('Multilinear map', 'Multilinear subspace learning'),
#  ('Adiós', 'Grammar induction'),
#  ('Nonparametric statistics', 'Kernel density estimation'),
#  ('Logistic regression', 'Conditional random field'),
#  ('Logistic regression', 'Linear predictor function'),
#  ('Logistic regression', 'Machine learning'),
#  ('Logistic regression', 'Local case-control sampling'),
#  ('Functional magnetic resonance imaging', 'Statistical classification'),
#  ('Computer Go', 'Pattern recognition'),
#  ('Computer Go', 'Machine learning'),
#  ('Computer Go', 'Google DeepMind'),
#  ('Computer Go', 'AlphaGo'),
#  ('Computer Go', 'Darkforest'),
#  ('Viterbi algorithm', 'Conditional random field'),
#  ('Earthquake prediction', 'Binary classification'),
#  ('Classification', 'Statistical classification'),
#  ('Classification', 'Document classification'),
#  ('Hypergraph', 'Machine learning'),
#  ('Hypergraph', 'Semi-supervised learning'),
#  ('Decision tree', 'Decision list'),
#  ('Machine learning', 'Computer science'),
#  ('Machine learning', 'Arthur Samuel'),
#  ('Machine learning', 'Pattern recognition'),
#  ('Machine learning', 'Computational learning theory'),
#  ('Machine learning', 'Artificial intelligence'),
#  ('Machine learning', 'Algorithm'),
#  ('Machine learning', 'Learning'),
#  ('Machine learning', 'Data'),
#  ('Machine learning', 'Computer program'),
#  ('Machine learning', 'Mathematical model'),
#  ('Machine learning', 'Spam filter'),
#  ('Machine learning', 'Optical character recognition'),
#  ('Machine learning', 'Learning to rank'),
#  ('Machine learning', 'Computer vision'),
#  ('Machine learning', 'Computational statistics'),
#  ('Machine learning', 'Mathematical optimization'),
#  ('Machine learning', 'Conflate'),
#  ('Machine learning', 'Data mining'),
#  ('Machine learning', 'Unsupervised learning'),
#  ('Machine learning', 'Data analytics'),
#  ('Machine learning', 'Predictive analytics'),
#  ('Machine learning', 'Data science'),
#  ('Machine learning', 'Tom M. Mitchell'),
#  ('Machine learning', 'Operational definition'),
#  ('Machine learning', 'Alan Turing'),
#  ('Machine learning', 'Computing Machinery and Intelligence'),
#  ('Machine learning', 'Supervised learning'),
#  ('Machine learning', 'Map (mathematics)'),
#  ('Machine learning', 'Feature learning'),
#  ('Machine learning', 'Reinforcement learning'),
#  ('Machine learning', 'Autonomous car'),
#  ('Machine learning', 'Semi-supervised learning'),
#  ('Machine learning', 'Transduction (machine learning)'),
#  ('Machine learning', 'File:Svm max sep hyperplane with margin.png'),
#  ('Machine learning', 'Meta learning (computer science)'),
#  ('Machine learning', 'Inductive bias'),
#  ('Machine learning', 'Developmental robotics'),
#  ('Machine learning', 'Robot learning'),
#  ('Machine learning', 'Statistical classification'),
#  ('Machine learning', 'Multi-label classification'),
#  ('Machine learning', 'Regression analysis'),
#  ('Machine learning', 'Cluster analysis'),
#  ('Machine learning', 'Density estimation'),
#  ('Machine learning', 'Probability distribution'),
#  ('Machine learning', 'Dimensionality reduction'),
#  ('Machine learning', 'Topic modeling'),
#  ('Machine learning', 'Natural language'),
#  ('Machine learning', 'Neural network'),
#  ('Machine learning', 'Perceptron'),
#  ('Machine learning', 'ADALINE'),
#  ('Machine learning', 'Generalized linear model'),
#  ('Machine learning', 'Probability theory'),
#  ('Machine learning', 'GOFAI'),
#  ('Machine learning', 'Expert system'),
#  ('Machine learning', 'Inductive logic programming'),
#  ('Machine learning', 'Information retrieval'),
#  ('Machine learning', 'Connectionism'),
#  ('Machine learning', 'John Hopfield'),
#  ('Machine learning', 'David Rumelhart'),
#  ('Machine learning', 'Geoff Hinton'),
#  ('Machine learning', 'Backpropagation'),
#  ('Machine learning', 'Internet'),
#  ('Machine learning', 'Discovery (observation)'),
#  ('Machine learning', 'Knowledge discovery'),
#  ('Machine learning', 'ECML PKDD'),
#  ('Machine learning', 'Loss function'),
#  ('Machine learning', 'Statistics'),
#  ('Machine learning', 'Michael I. Jordan'),
#  ('Machine learning', 'Leo Breiman'),
#  ('Machine learning', 'Random forest'),
#  ('Machine learning', 'Theoretical computer science'),
#  ('Machine learning', 'Bias–variance decomposition'),
#  ('Machine learning', 'Errors and residuals'),
#  ('Machine learning', 'Overfitting'),
#  ('Machine learning', 'Time complexity'),
#  ('Machine learning', 'Decision tree'),
#  ('Machine learning', 'Predictive modelling'),
#  ('Machine learning', 'Artificial neural network'),
#  ('Machine learning', 'Biological neural networks'),
#  ('Machine learning', 'Artificial neuron'),
#  ('Machine learning', 'Computation'),
#  ('Machine learning', 'Non-linear'),
#  ('Machine learning', 'Statistical'),
#  ('Machine learning', 'Data modeling'),
#  ('Machine learning', 'Joint probability distribution'),
#  ('Machine learning', 'GPU'),
#  ('Machine learning', 'Deep learning'),
#  ('Machine learning', 'Speech recognition'),
#  ('Machine learning', 'Logic programming'),
#  ('Machine learning', 'Entailment'),
#  ('Machine learning', 'Inductive programming'),
#  ('Machine learning', 'Functional programming'),
#  ('Machine learning', 'Data analysis'),
#  ('Machine learning', 'Graphical model'),
#  ('Machine learning', 'Random variables'),
#  ('Machine learning', 'Conditional independence'),
#  ('Machine learning', 'Directed acyclic graph'),
#  ('Machine learning', 'Inference'),
#  ('Machine learning', 'Principal components analysis'),
#  ('Machine learning', 'Manifold learning'),
#  ('Machine learning', 'Sparse coding'),
#  ('Machine learning', 'Multilinear subspace learning'),
#  ('Machine learning', 'Tensor'),
#  ('Machine learning', 'Recommendation systems'),
#  ('Machine learning', 'Basis function'),
#  ('Machine learning', 'Strongly NP-hard'),
#  ('Machine learning', 'K-SVD'),
#  ('Machine learning', 'Image de-noising'),
#  ('Machine learning', 'Search algorithm'),
#  ('Machine learning', 'Heuristic (computer science)'),
#  ('Machine learning', 'Natural selection'),
#  ('Machine learning', 'Mutation (genetic algorithm)'),
#  ('Machine learning', 'Crossover (genetic algorithm)'),
#  ('Machine learning', 'Chromosome (genetic algorithm)'),
#  ('Machine learning', 'Evolutionary algorithm'),
#  ('Machine learning', 'Adaptive website'),
#  ('Machine learning', 'Affective computing'),
#  ('Machine learning', 'Bioinformatics'),
#  ('Machine learning', 'Brain-machine interfaces'),
#  ('Machine learning', 'Cheminformatics'),
#  ('Machine learning', 'DNA sequence'),
#  ('Machine learning', 'Computational anatomy'),
#  ('Machine learning', 'Object recognition'),
#  ('Machine learning', 'Credit card fraud'),
#  ('Machine learning', 'Strategy game'),
#  ('Machine learning', 'Internet fraud'),
#  ('Machine learning', 'Marketing'),
#  ('Machine learning', 'Machine perception'),
#  ('Machine learning', 'Diagnosis (artificial intelligence)'),
#  ('Machine learning', 'Economics'),
#  ('Machine learning', 'Natural language processing'),
#  ('Machine learning', 'Natural language understanding'),
#  ('Machine learning', 'Metaheuristic'),
#  ('Machine learning', 'Online advertising'),
#  ('Machine learning', 'Recommender system'),
#  ('Machine learning', 'Robot locomotion'),
#  ('Machine learning', 'Search engines'),
#  ('Machine learning', 'Sentiment analysis'),
#  ('Machine learning', 'Sequence mining'),
#  ('Machine learning', 'Software engineering'),
#  ('Machine learning', 'Handwriting recognition'),
#  ('Machine learning', 'Stock market'),
#  ('Machine learning', 'Structural health monitoring'),
#  ('Machine learning', 'Syntactic pattern recognition'),
#  ('Machine learning', 'Netflix'),
#  ('Machine learning', 'Netflix Prize'),
#  ('Machine learning', 'AT&T Labs'),
#  ('Machine learning', 'Ensemble Averaging'),
#  ('Machine learning', 'Rebellion Research'),
#  ('Machine learning', 'Data collection'),
#  ('Machine learning', 'Machine ethics'),
#  ('Machine learning', 'Software suite'),
#  ('Machine learning', 'Dlib'),
#  ('Machine learning', 'ELKI'),
#  ('Machine learning', 'Encog'),
#  ('Machine learning', 'GNU Octave'),
#  ('Machine learning', 'H2o (Analytics tool)'),
#  ('Machine learning', 'Apache Mahout'),
#  ('Machine learning', 'Mallet (software project)'),
#  ('Machine learning', 'Mlpy'),
#  ('Machine learning', 'MLPACK (C++ library)'),
#  ('Machine learning', 'MOA (Massive Online Analysis)'),
#  ('Machine learning', 'ND4J'),
#  ('Machine learning', 'Deeplearning4j'),
#  ('Machine learning', 'Numenta'),
#  ('Machine learning', 'OpenAI'),
#  ('Machine learning', 'OpenCV'),
#  ('Machine learning', 'OpenNN'),
#  ('Machine learning', 'Orange (software)'),
#  ('Machine learning', 'R (programming language)'),
#  ('Machine learning', 'Scikit-learn'),
#  ('Machine learning', 'Scikit-image'),
#  ('Machine learning', 'Shogun (toolbox)'),
#  ('Machine learning', 'TensorFlow'),
#  ('Machine learning', 'Torch (machine learning)'),
#  ('Machine learning', 'Apache Spark'),
#  ('Machine learning', 'Yooreeka'),
#  ...]

# %%
def get_related_concepts(concept):
    related = []
    existing_concepts = list(map(operator.itemgetter(0), topic_concepts))
    
    for c in concept_links:
        if c[0] == concept and c[1] not in existing_concepts:
            related.append(c[1])
            
    return related

get_related_concepts('Document classification')
# Out:
# ['Library science',
#  'Information science',
#  'Computer science',
#  'Document',
#  'Class (philosophy)',
#  'Categorization',
#  'Algorithmically',
#  'Subject (documents)',
#  'Subject indexing',
#  'Frederick Wilfrid Lancaster',
#  'Thesaurus',
#  'Controlled vocabulary',
#  'Document clustering',
#  'Expectation maximization',
#  'Naive Bayes classifier',
#  'Tf–idf',
#  'Latent semantic indexing',
#  'Support vector machines',
#  'Artificial neural network',
#  'K-nearest neighbor algorithm',
#  'Decision tree learning',
#  'ID3 algorithm',
#  'C4.5 algorithm',
#  'Concept Mining',
#  'Rough set',
#  'Soft set',
#  'Natural language processing',
#  'Spam filter',
#  'E-mail spam',
#  'Routing',
#  'Language identification',
#  'Readability',
#  'Text simplification',
#  'Sentiment analysis',
#  'Classification (disambiguation)',
#  'Compound term processing',
#  'Concept-based image indexing',
#  'Content-based image retrieval',
#  'Document retrieval',
#  'Information retrieval',
#  'Knowledge organization',
#  'Knowledge Organization System',
#  'Library classification',
#  'Native Language Identification',
#  'String metrics',
#  'Text mining',
#  'Web mining',
#  'Concept mining',
#  'Category:Information science',
#  'Category:Natural language processing',
#  'Category:Knowledge representation',
#  'Category:Data mining',
#  'Category:Machine learning']

# %%
get_related_concepts('Text mining')
# Out:
# []

# %% [markdown]
# ## Final structure
#
# 1. Ignore "Machine learning" keyword everywhere
# 1. Ignore keywords starting with "Category:"
# 1. Topic concepts are the higher level concepts
#     1. For each higher level concept, there are linked concept
#     1. Linked concept can be present in the higher level concepts, or be absent
#     1. Give preference to absent ones for move visibility
#     1. The count of subtopics is useful. Should be stored for each topic concept
# 1. Count of links should be stored for each subtopic and topic. Since count of links is from topic to subtopic, it's not the "real" count

# %% [markdown]
# ### Get concept counts
#
# For each concept mentioned, get the counts of other concepts linking to it

# %%
f_concept_counts = Counter()

for concept_tuple in topic_concepts:
    concept = concept_tuple[0]
    
    related_concepts = get_related_concepts(concept)
    f_concept_counts.update(related_concepts)

# %%
f_concept_counts.most_common()
# Out:
# [('Category:Machine learning', 184),
#  ('Statistics', 23),
#  ('Regularization (mathematics)', 22),
#  ('Artificial intelligence', 22),
#  ('Support vector machine', 18),
#  ('Feature selection', 18),
#  ('Reinforcement learning', 18),
#  ('Artificial neural network', 17),
#  ('Algorithm', 17),
#  ('Cluster analysis', 16),
#  ('Data mining', 15),
#  ('Regression analysis', 15),
#  ('Natural language processing', 15),
#  ('Computer vision', 14),
#  ('Neural network', 14),
#  ('Deep learning', 14),
#  ('Logistic regression', 13),
#  ('Linear regression', 12),
#  ('Information retrieval', 12),
#  ('Probability distribution', 12),
#  ('Principal component analysis', 12),
#  ('Computer science', 11),
#  ('Category:Artificial intelligence', 11),
#  ('Google', 11),
#  ('K-nearest neighbor algorithm', 10),
#  ('Boosting (meta-algorithm)', 10),
#  ('Inductive logic programming', 10),
#  ('Classification (machine learning)', 10),
#  ('Support vector machines', 10),
#  ('Training set', 9),
#  ('Loss function', 9),
#  ('Speech recognition', 9),
#  ('Probability', 9),
#  ('Feature extraction', 9),
#  ('Bayesian inference', 9),
#  ('Perceptron', 9),
#  ('Tikhonov regularization', 9),
#  ('Category:Artificial neural networks', 9),
#  ('Category:Learning', 9),
#  ('Linear discriminant analysis', 8),
#  ('Statistical inference', 8),
#  ('Predictive analytics', 8),
#  ('Category:Statistical classification', 8),
#  ('Reproducing kernel Hilbert space', 8),
#  ('Category:Data mining', 8),
#  ('Decision tree learning', 7),
#  ('Backpropagation', 7),
#  ('Probably approximately correct learning', 7),
#  ('Dot product', 7),
#  ('Real number', 7),
#  ('Neural networks', 7),
#  ('R (programming language)', 7),
#  ('MATLAB', 7),
#  ('Big data', 7),
#  ('Vladimir Vapnik', 7),
#  ('Singular value decomposition', 7),
#  ('Artificial Intelligence', 7),
#  ('Online machine learning', 7),
#  ('Category:Theoretical computer science', 7),
#  ('Time series', 7),
#  ('Normal distribution', 7),
#  ('Inductive reasoning', 7),
#  ('No free lunch in search and optimization', 6),
#  ('Naive Bayes classifier', 6),
#  ('Maximum likelihood', 6),
#  ("Occam's razor", 6),
#  ('Decision tree', 6),
#  ('Random forest', 6),
#  ('Bioinformatics', 6),
#  ('Optical character recognition', 6),
#  ('Data', 6),
#  ('Expected value', 6),
#  ('Prior probability', 6),
#  ('K-means clustering', 6),
#  ('Tensor', 6),
#  ('Hidden Markov model', 6),
#  ('VC dimension', 6),
#  ('Multi-label classification', 6),
#  ('Boosting (machine learning)', 6),
#  ('Learning', 6),
#  ('Cognitive science', 6),
#  ("Bayes' theorem", 6),
#  ('Accuracy', 6),
#  ('Restricted Boltzmann machine', 6),
#  ('Stochastic gradient descent', 6),
#  ('Category:Natural language processing', 6),
#  ('C++', 6),
#  ('Optimization (mathematics)', 5),
#  ('Posterior probability', 5),
#  ('Minimum message length', 5),
#  ('Handwriting recognition', 5),
#  ('Vector space', 5),
#  ('Probability theory', 5),
#  ('Optimization problem', 5),
#  ('Artificial neural networks', 5),
#  ('Independent component analysis', 5),
#  ('Model selection', 5),
#  ('Minimum description length', 5),
#  ('Accuracy and precision', 5),
#  ('Kernel methods', 5),
#  ('Time complexity', 5),
#  ('Graphical model', 5),
#  ('Manifold learning', 5),
#  ('Basis function', 5),
#  ('Apache Spark', 5),
#  ('Weka (machine learning)', 5),
#  ('Andrew Ng', 5),
#  ('Category:Model selection', 5),
#  ('Category:Dimension reduction', 5),
#  ('Euclidean distance', 5),
#  ('Graph (discrete mathematics)', 5),
#  ('Dimension reduction', 5),
#  ('Latent variable', 5),
#  ('Category:Statistical models', 5),
#  ('Robotics', 5),
#  ('Joint distribution', 5),
#  ('New York City', 5),
#  ('Category:Classification algorithms', 5),
#  ('Java (programming language)', 5),
#  ('Python (programming language)', 5),
#  ('Category:Bayesian statistics', 5),
#  ('Vector space model', 5),
#  ('Kernel method', 5),
#  ('Recurrent neural network', 5),
#  ('Facebook', 5),
#  ('Convolutional neural network', 5),
#  ('Anomaly detection', 4),
#  ('Structured prediction', 4),
#  ('Variable kernel density estimation', 4),
#  ('Decision theory', 4),
#  ('Bootstrap aggregating', 4),
#  ('Bayesian network', 4),
#  ('Training data', 4),
#  ('Category:Statistical inference', 4),
#  ('Category:Regression analysis', 4),
#  ('Contingency table', 4),
#  ('Regression coefficient', 4),
#  ('Positive predictive value', 4),
#  ('Gradient descent', 4),
#  ('Spam filter', 4),
#  ('Data science', 4),
#  ('Generalized linear model', 4),
#  ('Joint probability distribution', 4),
#  ('Logic programming', 4),
#  ('Evolutionary algorithm', 4),
#  ('Recommender system', 4),
#  ('Sentiment analysis', 4),
#  ('Scikit-learn', 4),
#  ('TensorFlow', 4),
#  ('Torch (machine learning)', 4),
#  ('Stanford University', 4),
#  ('Mean', 4),
#  ('Factor analysis', 4),
#  ('Category:Computational learning theory', 4),
#  ('Category:Inductive reasoning', 4),
#  ('Category:Inference', 4),
#  ('Least squares', 4),
#  ('Linear classifier', 4),
#  ('Kernel trick', 4),
#  ('Neuroscience', 4),
#  ('Mutual information', 4),
#  ('MinHash', 4),
#  ('Latent semantic analysis', 4),
#  ('Database', 4),
#  ('Independent and identically distributed random variables', 4),
#  ('Markov chain', 4),
#  ('Spam filtering', 4),
#  ('Machine Learning', 4),
#  ('Conditional probability', 4),
#  ('Rough set', 4),
#  ('London', 4),
#  ('Facial recognition system', 4),
#  ('Random variable', 4),
#  ('Function (mathematics)', 4),
#  ('Fuzzy logic', 4),
#  ('Signal processing', 4),
#  ('C (programming language)', 4),
#  ('Manifold', 4),
#  ('Markov decision process', 4),
#  ('Greedy algorithm', 4),
#  ('Thompson sampling', 4),
#  ('Markov logic network', 4),
#  ('Scala (programming language)', 4),
#  ('N-gram', 4),
#  ('Brute-force search', 4),
#  ('Open source', 4),
#  ('Lasso (statistics)', 4),
#  ('Watson (computer)', 4),
#  ('Category:Applied machine learning', 4),
#  ('Microsoft', 4),
#  ('Generalization error', 3),
#  ('Multilayer perceptron', 3),
#  ('Bayesian statistics', 3),
#  ('Case-based reasoning', 3),
#  ('Maximum entropy classifier', 3),
#  ('Part of speech tagging', 3),
#  ('Part of speech', 3),
#  ('Parsing', 3),
#  ('Data clustering', 3),
#  ('Space (mathematics)', 3),
#  ('Categorical data', 3),
#  ('Integer', 3),
#  ('Ensemble learning', 3),
#  ('Maximum entropy Markov model', 3),
#  ('Compound term processing', 3),
#  ('Neocognitron', 3),
#  ('Sequence mining', 3),
#  ('Statistical model', 3),
#  ('Prior distribution', 3),
#  ('K-nearest neighbors algorithm', 3),
#  ('Classification rule', 3),
#  ('Discretization', 3),
#  ('Type I and type II errors', 3),
#  ('Sensitivity and specificity', 3),
#  ('Precision and recall', 3),
#  ('True positive', 3),
#  ('True negative', 3),
#  ('False positive', 3),
#  ('False negative', 3),
#  ('Recall (information retrieval)', 3),
#  ('Specificity (tests)', 3),
#  ('Precision (information retrieval)', 3),
#  ('F1 score', 3),
#  ('Markedness', 3),
#  ('Geometric mean', 3),
#  ("Youden's J statistic", 3),
#  ('Uncertainty coefficient', 3),
#  ('Negative predictive value', 3),
#  ('Receiver operating characteristic', 3),
#  ('Bias-variance dilemma', 3),
#  ('Mathematical model', 3),
#  ('Mathematical optimization', 3),
#  ('Density estimation', 3),
#  ('Connectionism', 3),
#  ('Geoff Hinton', 3),
#  ('Internet', 3),
#  ('Theoretical computer science', 3),
#  ('Predictive modelling', 3),
#  ('GPU', 3),
#  ('Functional programming', 3),
#  ('Data analysis', 3),
#  ('Directed acyclic graph', 3),
#  ('Inference', 3),
#  ('Sparse coding', 3),
#  ('Recommendation systems', 3),
#  ('Metaheuristic', 3),
#  ('Syntactic pattern recognition', 3),
#  ('International Conference on Machine Learning', 3),
#  ('Adaptive control', 3),
#  ('Computational intelligence', 3),
#  ('Computational neuroscience', 3),
#  ('Ethics of artificial intelligence', 3),
#  ('Ray Solomonoff', 3),
#  ('Latent variable model', 3),
#  ('Covariance', 3),
#  ('Radial basis function network', 3),
#  ('MIT Press', 3),
#  ('Information science', 3),
#  ('Text mining', 3),
#  ('Association rule learning', 3),
#  ('Bayesian probability', 3),
#  ('Leslie Valiant', 3),
#  ('Information theory', 3),
#  ('Algorithmic probability', 3),
#  ('Kolmogorov complexity', 3),
#  ('Language identification in the limit', 3),
#  ('Inductive inference', 3),
#  ('Variance', 3),
#  ('Independence (probability theory)', 3),
#  ('Mean squared error', 3),
#  ('Combinatorial optimization', 3),
#  ('High-dimensional space', 3),
#  ('Correlation and dependence', 3),
#  ('Semidefinite programming', 3),
#  ('Autoencoder', 3),
#  ('Canonical correlation analysis', 3),
#  ('Locality sensitive hashing', 3),
#  ('Data set', 3),
#  ('Categorical distribution', 3),
#  ('Gaussian distribution', 3),
#  ('Multivariate normal distribution', 3),
#  ('Bernoulli distribution', 3),
#  ('Topic model', 3),
#  ('Latent Dirichlet allocation', 3),
#  ('Pixel', 3),
#  ('Linear subspace', 3),
#  ('Support Vector Machine', 3),
#  ('United States', 3),
#  ('Category:Cognitive science', 3),
#  ('Probability density function', 3),
#  ('String (computer science)', 3),
#  ('Explanatory variable', 3),
#  ('Hashing trick', 3),
#  ('Tf–idf', 3),
#  ('Evolutionary robotics', 3),
#  ('Juergen Schmidhuber', 3),
#  ('IDSIA', 3),
#  ('Hinge loss', 3),
#  ('Genetic programming', 3),
#  ('Metric (mathematics)', 3),
#  ('Linear function', 3),
#  ('Fourier transform', 3),
#  ('Haskell (programming language)', 3),
#  ('Cross-platform', 3),
#  ('Polynomial regression', 3),
#  ('Category:Artificial intelligence applications', 3),
#  ('Category:Data mining and machine learning software', 3),
#  ('Category:Free science software', 3),
#  ('Decision boundary', 3),
#  ('Convex function', 3),
#  ('Laplacian matrix', 3),
#  ('Co-training', 3),
#  ('Mental representation', 3),
#  ('Intelligent agent', 3),
#  ('Concept class', 3),
#  ('Category:Computational linguistics', 3),
#  ('Learning algorithms', 3),
#  ('Hamming distance', 3),
#  ('Scientific journal', 3),
#  ('Concept', 3),
#  ('Collaborative filtering', 3),
#  ('Locality-sensitive hashing', 3),
#  ('Theory of computation', 3),
#  ('Linear model', 3),
#  ('Well-posed problem', 3),
#  ('Chess', 3),
#  ('Convex optimization', 3),
#  ('Android (operating system)', 3),
#  ('Artificial general intelligence', 3),
#  ('Hyper-heuristic', 3),
#  ('Q-learning', 3),
#  ('Radial basis function', 3),
#  ('Hilbert space', 3),
#  ('Proximal gradient method', 3),
#  ('Action language', 3),
#  ('IBM', 3),
#  ('Deep Blue (chess computer)', 3),
#  ('Computer Go', 3),
#  ('Fan Hui', 3),
#  ('Go ranks and ratings', 3),
#  ('Category:Deep learning', 3),
#  ('Application programming interface', 3),
#  ('Boolean algebra', 3),
#  ('Distributed computing', 3),
#  ('Apache Hadoop', 3),
#  ('Open-source software', 3),
#  ('Automated planning and scheduling', 3),
#  ('Matching pursuit', 3),
#  ('Vision processing unit', 3),
#  ('Monte Carlo tree search', 3),
#  ('Branching factor', 3),
#  ('Gaussian process regression', 2),
#  ('Learning classifier system', 2),
#  ('Cheminformatics', 2),
#  ('Class membership probabilities', 2),
#  ('Version space', 2),
#  ('Knowledge discovery in databases', 2),
#  ('Parse tree', 2),
#  ('Syntactic structure', 2),
#  ('Pattern matching', 2),
#  ('Distance', 2),
#  ('Community ecology', 2),
#  ('Ordinal data', 2),
#  ('Branch and bound', 2),
#  ('Principal components analysis', 2),
#  ("Bayes' rule", 2),
#  ('Frequentist inference', 2),
#  ('Covariance matrix', 2),
#  ('Dirichlet distribution', 2),
#  ('Quadratic classifier', 2),
#  ('Multinomial logistic regression', 2),
#  ('Hierarchical clustering', 2),
#  ('Kernel principal component analysis', 2),
#  ('Ensemble averaging', 2),
#  ('Mixture of experts', 2),
#  ('Hierarchical mixture of experts', 2),
#  ('Markov random field', 2),
#  ('Kalman filter', 2),
#  ('Recurrent neural networks', 2),
#  ('Adaptive resonance theory', 2),
#  ('Cache language model', 2),
#  ('Perception', 2),
#  ('Perceptual learning', 2),
#  ('Category:Pattern recognition', 2),
#  ('Parameter', 2),
#  ('Function approximation', 2),
#  ('Conditional independence', 2),
#  ('Feature space', 2),
#  ('Bias', 2),
#  ('Set (mathematics)', 2),
#  ('Random forests', 2),
#  ('File:Binary-classification-labeled.svg', 2),
#  ('Prevalence', 2),
#  ('True Positive Rate', 2),
#  ('Sensitivity (tests)', 2),
#  ('True Negative Rate', 2),
#  ('Diagnostic odds ratio', 2),
#  ('Odds ratio', 2),
#  ('F-score', 2),
#  ('Informedness', 2),
#  ('Human chorionic gonadotropin', 2),
#  ('Multiclass classification', 2),
#  ('Thresholding (image processing)', 2),
#  ('File:Overfitting on Training Set Data.pdf', 2),
#  ('Non-parametric regression', 2),
#  ('Consistency (statistics)', 2),
#  ('Arthur Samuel', 2),
#  ('Computer program', 2),
#  ('Computational statistics', 2),
#  ('Alan Turing', 2),
#  ('Autonomous car', 2),
#  ('Topic modeling', 2),
#  ('Natural language', 2),
#  ('John Hopfield', 2),
#  ('David Rumelhart', 2),
#  ('Knowledge discovery', 2),
#  ('ECML PKDD', 2),
#  ('Leo Breiman', 2),
#  ('Biological neural networks', 2),
#  ('Computation', 2),
#  ('Random variables', 2),
#  ('K-SVD', 2),
#  ('Search algorithm', 2),
#  ('Heuristic (computer science)', 2),
#  ('Mutation (genetic algorithm)', 2),
#  ('Crossover (genetic algorithm)', 2),
#  ('Affective computing', 2),
#  ('Marketing', 2),
#  ('Machine perception', 2),
#  ('Diagnosis (artificial intelligence)', 2),
#  ('Economics', 2),
#  ('Online advertising', 2),
#  ('Search engines', 2),
#  ('Software engineering', 2),
#  ('Netflix', 2),
#  ('Netflix Prize', 2),
#  ('ELKI', 2),
#  ('GNU Octave', 2),
#  ('Apache Mahout', 2),
#  ('MOA (Massive Online Analysis)', 2),
#  ('Numenta', 2),
#  ('OpenAI', 2),
#  ('RapidMiner', 2),
#  ('Mathematica', 2),
#  ('Neural Designer', 2),
#  ('SAS (software)', 2),
#  ('Splunk', 2),
#  ('Neural Computation (journal)', 2),
#  ('List of important publications in computer science', 2),
#  ('Soft computing', 2),
#  ('Jerome H. Friedman', 2),
#  ('Pedro Domingos', 2),
#  ('Richard O. Duda', 2),
#  ('Peter E. Hart', 2),
#  ('Dartmouth Conferences', 2),
#  ('Category:Cybernetics', 2),
#  ('Mixture models', 2),
#  ('Method of moments (statistics)', 2),
#  ('Donald Hebb', 2),
#  ('Geoffrey Hinton', 2),
#  ('Semantics', 2),
#  ('Linguistics', 2),
#  ('Partial order', 2),
#  ('Predicate (mathematical logic)', 2),
#  ('Power set', 2),
#  ('Graph traversal', 2),
#  ('Commonsense reasoning', 2),
#  ('Conceptual clustering', 2),
#  ('Concept mining', 2),
#  ('Description logic', 2),
#  ('Pattern theory', 2),
#  ('Dana Angluin', 2),
#  ('VC theory', 2),
#  ('Alexey Chervonenkis', 2),
#  ('E. Mark Gold', 2),
#  ('Occam Learning', 2),
#  ('Computable function', 2),
#  ('Universal artificial intelligence', 2),
#  ('Turing machine', 2),
#  ('Algorithmic information theory', 2),
#  ('Partition of a set', 2),
#  ('Statistical sample', 2),
#  ('Statistical population', 2),
#  ('Hyperplane', 2),
#  ('Bias (statistics)', 2),
#  ('Monte Carlo method', 2),
#  ('Kernel regression', 2),
#  ('Closed-form expression', 2),
#  ('Features (pattern recognition)', 2),
#  ('Validity (statistics)', 2),
#  ('Convex hull', 2),
#  ('Boolean function', 2),
#  ('Hypercube', 2),
#  ('Information gain in decision trees', 2),
#  ('Dimension', 2),
#  ('Nonlinear dimensionality reduction', 2),
#  ('Matrix (mathematics)', 2),
#  ('Multidimensional scaling', 2),
#  ('T-distributed stochastic neighbor embedding', 2),
#  ('Multilinear PCA', 2),
#  ('Category:Multivariate statistics', 2),
#  ('Sampling (statistics)', 2),
#  ('Combinatorial explosion', 2),
#  ('Hypersphere', 2),
#  ('Concentration of measure', 2),
#  ('Linear least squares (mathematics)', 2),
#  ('Wavelet', 2),
#  ('Category:Numerical analysis', 2),
#  ('Parametric family', 2),
#  ("Zipf's law", 2),
#  ('Expectation maximization', 2),
#  ('Mathematical proof', 2),
#  ('Hyperparameter', 2),
#  ('Independent identically distributed', 2),
#  ('Category:Probabilistic models', 2),
#  ('Association rule', 2),
#  ('Structure mining', 2),
#  ('Classifier (mathematics)', 2),
#  ('Decision trees', 2),
#  ('Evolutionary computation', 2),
#  ('Kernel methods for vector output', 2),
#  ('C Sharp (programming language)', 2),
#  ('.NET Framework', 2),
#  ('Reasoning', 2),
#  ('Akaike information criterion', 2),
#  ('Cambridge, MA', 2),
#  ('Amsterdam', 2),
#  ('Expected risk', 2),
#  ('Lp space', 2),
#  ('Reproducing kernel Hilbert spaces', 2),
#  ('Douglas Hofstadter', 2),
#  ('Maximum likelihood estimation', 2),
#  ('Character recognition', 2),
#  ('Covariate', 2),
#  ('Document clustering', 2),
#  ('Content-based image retrieval', 2),
#  ('Document retrieval', 2),
#  ('Category:Knowledge representation', 2),
#  ('Cumulative learning', 2),
#  ('Technical University of Munich', 2),
#  ('University of Massachusetts Amherst', 2),
#  ('Category:Robotics', 2),
#  ('Category:Robot control', 2),
#  ('Conditional distribution', 2),
#  ('NP-hard', 2),
#  ('Overfit', 2),
#  ('Category:Datasets in machine learning', 2),
#  ('Category:Data analysis', 2),
#  ('Blood type', 2),
#  ('Blood pressure', 2),
#  ('Independent variable', 2),
#  ('Dependent variable', 2),
#  ('Probabilistic classification', 2),
#  ('Mahalanobis distance', 2),
#  ('Markov chain Monte Carlo', 2),
#  ('Linear combination', 2),
#  ('Learning vector quantization', 2),
#  ('Medical imaging', 2),
#  ('Data warehouse', 2),
#  ('Characteristic function (probability theory)', 2),
#  ('Gaussian function', 2),
#  ('Algorithms', 2),
#  ('OS X', 2),
#  ('Microsoft Windows', 2),
#  ('Linux', 2),
#  ('ImageNet', 2),
#  ('Word embedding', 2),
#  ('Network theory', 2),
#  ('Category:Free statistical software', 2),
#  ('File:Example of unlabeled data in semisupervised learning.png', 2),
#  ('Margin (machine learning)', 2),
#  ('Distance metric', 2),
#  ('Germany', 2),
#  ('Softmax function', 2),
#  ('Bulletin of the American Mathematical Society', 2),
#  ('Category:Sequential methods', 2),
#  ('Category:Sequential experiments', 2),
#  ('Category:Stochastic optimization', 2),
#  ('Embodied cognitive science', 2),
#  ('ACT-R', 2),
#  ('Cybernetics', 2),
#  ('Intelligent control', 2),
#  ('Binary numeral system', 2),
#  ('Game theory', 2),
#  ('Carnegie Mellon University', 2),
#  ('Domain Adaptation', 2),
#  ('Likelihood function', 2),
#  ('Matlab', 2),
#  ('Lise Getoor', 2),
#  ('Category:Log-linear models', 2),
#  ('Information integration', 2),
#  ('University of California at Berkeley', 2),
#  ('Knowledge base', 2),
#  ('Lisp (programming language)', 2),
#  ('Category:Semantics', 2),
#  ('Bit array', 2),
#  ('No free lunch theorem', 2),
#  ('Category:Computer science journals', 2),
#  ('Global optimization', 2),
#  ('Kullback–Leibler divergence', 2),
#  ('Exponential family', 2),
#  ('Support (mathematics)', 2),
#  ('Simulated annealing', 2),
#  ('Genetic algorithms', 2),
#  ('Abstraction', 2),
#  ('Data compression', 2),
#  ('Convolution', 2),
#  ('Bregman divergence', 2),
#  ('Space partitioning', 2),
#  ('K-d tree', 2),
#  ('Euclidean space', 2),
#  ('Entropy estimation', 2),
#  ('Sparse distributed memory', 2),
#  ('Category:Mathematical optimization', 2),
#  ('Symbolic artificial intelligence', 2),
#  ('Cartesian product', 2),
#  ('William of Ockham', 2),
#  ('Likelihood', 2),
#  ('Vapnik–Chervonenkis theory', 2),
#  ('Partially observable Markov decision process', 2),
#  ('Richard S. Sutton', 2),
#  ('Dual (mathematics)', 2),
#  ('False alarm', 2),
#  ('Type I error', 2),
#  ('Type II error', 2),
#  ('Sensitivity (test)', 2),
#  ('Hit rate', 2),
#  ('False discovery rate', 2),
#  ('Harmonic mean', 2),
#  ('Document-term matrix', 2),
#  ('Linear algebra', 2),
#  ('National Science Foundation', 2),
#  ('MIT Computer Science and Artificial Intelligence Laboratory', 2),
#  ('Visual cortex', 2),
#  ('Dependent and independent variables', 2),
#  ('Rectifier (neural networks)', 2),
#  ('Errors and residuals in statistics', 2),
#  ('Regularization (machine learning)', 2),
#  ('Multicollinearity', 2),
#  ('Inverse problem', 2),
#  ('Sensor networks', 2),
#  ('University of California, Berkeley', 2),
#  ('Knowledge representation', 2),
#  ('First-order logic', 2),
#  ('Category:Computational statistics', 2),
#  ('Posterior distribution', 2),
#  ('Neuro-fuzzy', 2),
#  ('Uniform distribution (continuous)', 2),
#  ('Standard normal distribution', 2),
#  ('Active learning', 2),
#  ('Big O notation', 2),
#  ('Bag of words', 2),
#  ('Ordinal regression', 2),
#  ('Neural Information Processing Systems', 2),
#  ('Microsoft Research', 2),
#  ('Category:Information retrieval techniques', 2),
#  ('K-nearest neighbor', 2),
#  ('Chatterbot', 2),
#  ('Turing test', 2),
#  ('Marcus Hutter', 2),
#  ('M. Alex O. Vasilescu', 2),
#  ('Demetri Terzopoulos', 2),
#  ('Tucker decomposition', 2),
#  ('Binary tree', 2),
#  ('Category:Articles created via the Article Wizard', 2),
#  ('Dimensions', 2),
#  ('Classification in machine learning', 2),
#  ('Design matrix', 2),
#  ('Binary variable', 2),
#  ('Categorical variable', 2),
#  ('Gramian matrix', 2),
#  ('Gaussian process', 2),
#  ('Category:Probability theory', 2),
#  ('Bernhard Schölkopf', 2),
#  ('Sparse matrix', 2),
#  ('Inner product', 2),
#  ('Positive-definite matrix', 2),
#  ('Distributional semantics', 2),
#  ('Johnson–Lindenstrauss lemma', 2),
#  ('Dictionary learning', 2),
#  ('Named-entity recognition', 2),
#  ('Distributed representation', 2),
#  ('Neocortex', 2),
#  ('Bias of an estimator', 2),
#  ('Generalization', 2),
#  ('Formal language', 2),
#  ('NP-complete', 2),
#  ('Optimization', 2),
#  ('Differentiable function', 2),
#  ('Gradient', 2),
#  ('Projection (linear algebra)', 2),
#  ('L1-norm', 2),
#  ('Elastic net regularization', 2),
#  ('Convex analysis', 2),
#  ('Category:First order methods', 2),
#  ('Category:Convex optimization', 2),
#  ('Vector (mathematics and physics)', 2),
#  ('Identity matrix', 2),
#  ('Belief propagation', 2),
#  ('Declarative programming', 2),
#  ('Prolog', 2),
#  ('Constraint programming', 2),
#  ('Probabilistic programming language', 2),
#  ('Knowledge representation and reasoning', 2),
#  ('Abductive logic programming', 2),
#  ('Knowledge acquisition', 2),
#  ('Category:Programming paradigms', 2),
#  ('Demis Hassabis', 2),
#  ('Go (game)', 2),
#  ('Startup company', 2),
#  ('Systems neuroscience', 2),
#  ('Nature (journal)', 2),
#  ('Lee Sedol', 2),
#  ('AlphaGo versus Lee Sedol', 2),
#  ('Category:Artificial intelligence laboratories', 2),
#  ('Category:Game artificial intelligence', 2),
#  ('Category:Machine learning algorithms', 2),
#  ('Programming language', 2),
#  ('Lua (programming language)', 2),
#  ('Comparison of deep learning frameworks', 2),
#  ('Thomas Bayes', 2),
#  ('Quantifier (logic)', 2),
#  ('Huffman coding', 2),
#  ("Bayes' Theorem", 2),
#  ('Abductive reasoning', 2),
#  ('Machine vision', 2),
#  ('Computing', 2),
#  ('GloVe (machine learning)', 2),
#  ('Parallel computing', 2),
#  ('ND4J (software)', 2),
#  ('Central processing unit', 2),
#  ('Graphics processing unit', 2),
#  ('Category:Technology companies based in the San Francisco Bay Area', 2),
#  ('Category:Information technology companies of the United States', 2),
#  ('Sepp Hochreiter', 2),
#  ('Jürgen Schmidhuber', 2),
#  ('Long short term memory', 2),
#  ('Freebase', 2),
#  ('Wikipedia', 2),
#  ('STRIPS', 2),
#  ('Answer Set Programming', 2),
#  ('NASA', 2),
#  ('Search engine', 2),
#  ('Multiple kernel learning', 2),
#  ('Compressed sensing', 2),
#  ('Computer security', 2),
#  ('Category:Computer security', 2),
#  ('AI accelerator', 2),
#  ('Software', 2),
#  ('Category:AI accelerators', 2),
#  ('Kaggle', 2),
#  ('Privately held company', 2),
#  ('Category:Companies established in 2014', 2),
#  ('Cosine similarity', 2),
#  ('Duality (optimization)', 2),
#  ('Sparse approximation', 2),
#  ('Amazon.com', 2),
#  ('MNIST database', 2),
#  ('Google DeepMind', 2),
#  ('Tree traversal', 2),
#  ('Crazy Stone (software)', 2),
#  ('List of Go terms', 2),
#  ('Go and mathematics', 2),
#  ('TD-Gammon', 2),
#  ('Backgammon', 2),
#  ('Category:Computer Go', 2),
#  ('Category:Go software', 2),
#  ('Bayesian inference using Gibbs sampling', 2),
#  ('Rule-based system', 2),
#  ('Boolean satisfiability problem', 2),
#  ('Target variable', 1),
#  ('Deterministic noise', 1),
#  ('Statistical significance', 1),
#  ('Support Vector Machines', 1),
#  ('Independent and identically-distributed random variables', 1),
#  ('Euclidean norm', 1),
#  ('Analytical learning', 1),
#  ('Group method of data handling', 1),
#  ('Learning Automata', 1),
#  ('Naive bayes classifier', 1),
#  ('Nearest neighbor (pattern recognition)', 1),
#  ('Ripple down rules', 1),
#  ('Symbolic machine learning', 1),
#  ('Subsymbolic machine learning', 1),
#  ('Ensembles of Classifiers', 1),
#  ('Ordinal classification', 1),
#  ('Data Pre-processing', 1),
#  ('Handling imbalanced datasets', 1),
#  ('Proaftn', 1),
#  ('Quantitative structure–activity relationship', 1),
#  ('Database marketing', 1),
#  ('Information extraction', 1),
#  ('Spamming', 1),
#  ('Downward causation', 1),
#  ('Overfitting (machine learning)', 1),
#  ('Engineering', 1),
#  ('Conference on Computer Vision and Pattern Recognition', 1),
#  ('Regular expression', 1),
#  ('Text editor', 1),
#  ('Word processor', 1),
#  ("Occam's Razor", 1),
#  ('Nominal data', 1),
#  ('Powerset', 1),
#  ('Zero-one loss function', 1),
#  ('Bayes error rate', 1),
#  ('Correctness (computer science)', 1),
#  ('Continuous distribution', 1),
#  ('Integral', 1),
#  ('Maximum a posteriori', 1),
#  ('Fisher discriminant analysis', 1),
#  ('Bayes rule', 1),
#  ('A priori and a posteriori', 1),
#  ('Beta distribution', 1),
#  ('Conjugate prior distribution', 1),
#  ('File:800px-Cool Kids of Death Off Festival p 146-face selected.jpg', 1),
#  ('Computer-aided diagnosis', 1),
#  ('File:SRT Shape Recognition Technology Principles.png', 1),
#  ('Image analysis', 1),
#  ('Deep Learning', 1),
#  ('Pattern recognition (psychology)', 1),
#  ('K-nearest-neighbor', 1),
#  ('Gene expression programming', 1),
#  ('Correlation clustering', 1),
#  ('Meta-algorithm', 1),
#  ('Particle filter', 1),
#  ('Black box', 1),
#  ('List of numerical analysis software', 1),
#  ('List of numerical libraries', 1),
#  ('Template matching', 1),
#  ('Contextual image classification', 1),
#  ('Category:Formal sciences', 1),
#  ('File:Overfitted Data.png', 1),
#  ('Random error', 1),
#  ('Predictive inference', 1),
#  ('Model error', 1),
#  ('Coefficient of determination', 1),
#  ('Shrinkage (statistics)', 1),
#  ('Pruning (algorithm)', 1),
#  ('Bayesian model comparison', 1),
#  ('File:Overfitting svg.svg', 1),
#  ('Causal relation', 1),
#  ('Robustness (computer science)', 1),
#  ('Curve fitting', 1),
#  ('Data dredging', 1),
#  ('Journal of Chemical Information and Modeling', 1),
#  ('Learning algorithm', 1),
#  ('Mathematical logic', 1),
#  ('Cognitive bias', 1),
#  ('Category:Bias', 1),
#  ('Qualitative property', 1),
#  ('Medical test', 1),
#  ('Test method', 1),
#  ('Quality control', 1),
#  ('Go/no go', 1),
#  ('Result set', 1),
#  ('False positives and false negatives', 1),
#  ('False Negative Rate', 1),
#  ('False Positive Rate', 1),
#  ('Positive Predictive Value', 1),
#  ('False Discovery Rate', 1),
#  ('Negative Predictive Value', 1),
#  ('False Omission Rate', 1),
#  ('Likelihood ratio (disambiguation)', 1),
#  ('Likelihood ratios in diagnostic testing', 1),
#  ('Blood values', 1),
#  ('Cutoff (reference value)', 1),
#  ('Positive or negative test', 1),
#  ('Predictive value', 1),
#  ('Pregnancy test', 1),
#  ('Detection theory', 1),
#  ('One-class classification', 1),
#  ("Prosecutor's fallacy", 1),
#  ('Nello Cristianini', 1),
#  ('John Shawe-Taylor', 1),
#  ('Principal component regression', 1),
#  ('Spectral regularization', 1),
#  ('AdaBoost', 1),
#  ('Conflate', 1),
#  ('Data analytics', 1),
#  ('Tom M. Mitchell', 1),
#  ('Operational definition', 1),
#  ('Computing Machinery and Intelligence', 1),
#  ('Map (mathematics)', 1),
#  ('File:Svm max sep hyperplane with margin.png', 1),
#  ('ADALINE', 1),
#  ('GOFAI', 1),
#  ('Expert system', 1),
#  ('Discovery (observation)', 1),
#  ('Michael I. Jordan', 1),
#  ('Bias–variance decomposition', 1),
#  ('Errors and residuals', 1),
#  ('Artificial neuron', 1),
#  ('Non-linear', 1),
#  ('Statistical', 1),
#  ('Data modeling', 1),
#  ('Entailment', 1),
#  ('Strongly NP-hard', 1),
#  ('Image de-noising', 1),
#  ('Natural selection', 1),
#  ('Chromosome (genetic algorithm)', 1),
#  ('Adaptive website', 1),
#  ('Brain-machine interfaces', 1),
#  ('DNA sequence', 1),
#  ('Computational anatomy', 1),
#  ('Object recognition', 1),
#  ('Credit card fraud', 1),
#  ('Strategy game', 1),
#  ('Internet fraud', 1),
#  ('Natural language understanding', 1),
#  ('Robot locomotion', 1),
#  ('Stock market', 1),
#  ('Structural health monitoring', 1),
#  ('AT&T Labs', 1),
#  ('Ensemble Averaging', 1),
#  ('Rebellion Research', 1),
#  ('Data collection', 1),
#  ('Machine ethics', 1),
#  ('Software suite', 1),
#  ('Dlib', 1),
#  ('Encog', 1),
#  ('H2o (Analytics tool)', 1),
#  ('Mallet (software project)', 1),
#  ('Mlpy', 1),
#  ('MLPACK (C++ library)', 1),
#  ('ND4J', 1),
#  ('OpenCV', 1),
#  ('Scikit-image', 1),
#  ('Shogun (toolbox)', 1),
#  ('Yooreeka', 1),
#  ('KNIME', 1),
#  ('Amazon Machine Learning', 1),
#  ('Angoss', 1),
#  ('Ayasdi', 1),
#  ('Databricks', 1),
#  ('Google APIs', 1),
#  ('SPSS Modeler', 1),
#  ('KXEN Inc.', 1),
#  ('LIONsolver', 1),
#  ('Azure machine learning studio', 1),
#  ('NeuroSolutions', 1),
#  ('Oracle Data Mining', 1),
#  ('RCASE', 1),
#  ('STATISTICA', 1),
#  ('International Journal of Machine Learning and Cybernetics', 1),
#  ('Conference on Neural Information Processing Systems', 1),
#  ('Automatic reasoning', 1),
#  ('Cognitive model', 1),
#  ('Existential risk from advanced artificial intelligence', 1),
#  ('List of machine learning algorithms', 1),
#  ('Trevor Hastie', 1),
#  ('Robert Tibshirani', 1),
#  ('Mehryar Mohri', 1),
#  ('David J. C. MacKay', 1),
#  ('Christopher Bishop', 1),
#  ('K-means', 1),
#  ('Hebbian Learning', 1),
#  ('Expectation–maximization algorithm', 1),
#  ('Blind signal separation', 1),
#  ('Non-negative matrix factorization', 1),
#  ('Hebbian learning', 1),
#  ('Spike-timing-dependent plasticity', 1),
#  ('Self-organizing map', 1),
#  ('Vigilance parameter', 1),
#  ('Automatic target recognition', 1),
#  ('Tensors', 1),
#  ('Generative topographic map', 1),
#  ('Multivariate analysis', 1),
#  ('Hebbian Theory', 1),
#  ('Pattern classification', 1),
#  ('Terrence J. Sejnowski', 1),
#  ('Principle', 1),
#  ('Concept hierarchy', 1),
#  ('Ontology (computer science)', 1),
#  ('Mathematical object', 1),
#  ('Property (philosophy)', 1),
#  ('Subset', 1),
#  ('Rudolf Wille', 1),
#  ('Lattice theory', 1),
#  ('Order theory', 1),
#  ('Garrett Birkhoff', 1),
#  ('Knowledge management', 1),
#  ('Semantic web', 1),
#  ('Software development', 1),
#  ('Chemistry', 1),
#  ('Biology', 1),
#  ('Lattice (order)', 1),
#  ('Binary relations', 1),
#  ('Dual (math)', 1),
#  ('Extension (semantics)', 1),
#  ('Intension', 1),
#  ('Partially ordered set', 1),
#  ('Galois connection', 1),
#  ('Peter Burmeister', 1),
#  ('Technische Universität Darmstadt', 1),
#  ('Charles S. Peirce', 1),
#  ('Hartmut von Hentig', 1),
#  ('Formal logic', 1),
#  ('Model theory', 1),
#  ('Predicate (logic)', 1),
#  ('Pragmatic maxim', 1),
#  ...]

# %% [markdown]
# ### Filter concepts
#
# Filter out concepts that start with "Category:"

# %%
def filter_concept(concept):
    if concept.startswith('Category:'):
        return False
    
    if concept == 'Machine learning':
        return False
    
    return True

print(filter_concept('Hello'))
print(filter_concept('Category:Hello'))
# Out:
# True
# False

# %% [markdown]
# ### Construct final structure

# %%
# It's an array of concepts
f_concepts = []
f_concepts_cache = []

# Copy over everything from top-level concepts, filtering them
for data in topic_concepts:
    concept = data[0]
    if not filter_concept(concept):
        continue
        
    f_concepts.append({'label': concept, 'concepts': []})
    f_concepts_cache.append(concept)
    
# For each higher level concept, get more related concepts
# and counts
for concept in f_concepts:
    label = concept['label']
    
    # Get related concept and filter it first
    related_concepts = get_related_concepts(label)
    related_concepts = list(filter(filter_concept, related_concepts))
    
    # For each related concept, append it with the count
    for related_concept in related_concepts:
        multiplier = 1
        if related_concept not in f_concepts_cache:
            multiplier = 10
        
        concept['concepts'].append({'label': related_concept,
                                    'linked_to_count': f_concept_counts[related_concept] * multiplier})
        
    # Sort the related concepts by the linked_to_count in descending order
    concept['concepts'].sort(key=operator.itemgetter('linked_to_count'), reverse=True)

# %%
f_concepts
# Out:
# [{'concepts': [{'label': 'Regularization (mathematics)',
#     'linked_to_count': 220},
#    {'label': 'Support vector machine', 'linked_to_count': 180},
#    {'label': 'Feature selection', 'linked_to_count': 180},
#    {'label': 'Artificial neural network', 'linked_to_count': 170},
#    {'label': 'Computer vision', 'linked_to_count': 140},
#    {'label': 'Logistic regression', 'linked_to_count': 130},
#    {'label': 'Linear regression', 'linked_to_count': 120},
#    {'label': 'Information retrieval', 'linked_to_count': 120},
#    {'label': 'K-nearest neighbor algorithm', 'linked_to_count': 100},
#    {'label': 'Boosting (meta-algorithm)', 'linked_to_count': 100},
#    {'label': 'Inductive logic programming', 'linked_to_count': 100},
#    {'label': 'Training set', 'linked_to_count': 90},
#    {'label': 'Loss function', 'linked_to_count': 90},
#    {'label': 'Speech recognition', 'linked_to_count': 90},
#    {'label': 'Linear discriminant analysis', 'linked_to_count': 80},
#    {'label': 'Decision tree learning', 'linked_to_count': 70},
#    {'label': 'Backpropagation', 'linked_to_count': 70},
#    {'label': 'Probably approximately correct learning', 'linked_to_count': 70},
#    {'label': 'No free lunch in search and optimization',
#     'linked_to_count': 60},
#    {'label': 'Naive Bayes classifier', 'linked_to_count': 60},
#    {'label': 'Maximum likelihood', 'linked_to_count': 60},
#    {'label': "Occam's razor", 'linked_to_count': 60},
#    {'label': 'Decision tree', 'linked_to_count': 60},
#    {'label': 'Random forest', 'linked_to_count': 60},
#    {'label': 'Bioinformatics', 'linked_to_count': 60},
#    {'label': 'Optical character recognition', 'linked_to_count': 60},
#    {'label': 'Optimization (mathematics)', 'linked_to_count': 50},
#    {'label': 'Posterior probability', 'linked_to_count': 50},
#    {'label': 'Minimum message length', 'linked_to_count': 50},
#    {'label': 'Handwriting recognition', 'linked_to_count': 50},
#    {'label': 'Anomaly detection', 'linked_to_count': 40},
#    {'label': 'Structured prediction', 'linked_to_count': 40},
#    {'label': 'Variable kernel density estimation', 'linked_to_count': 40},
#    {'label': 'Generalization error', 'linked_to_count': 30},
#    {'label': 'Multilayer perceptron', 'linked_to_count': 30},
#    {'label': 'Bayesian statistics', 'linked_to_count': 30},
#    {'label': 'Case-based reasoning', 'linked_to_count': 30},
#    {'label': 'Maximum entropy classifier', 'linked_to_count': 30},
#    {'label': 'Gaussian process regression', 'linked_to_count': 20},
#    {'label': 'Learning classifier system', 'linked_to_count': 20},
#    {'label': 'Cheminformatics', 'linked_to_count': 20},
#    {'label': 'Class membership probabilities', 'linked_to_count': 20},
#    {'label': 'Version space', 'linked_to_count': 20},
#    {'label': 'Target variable', 'linked_to_count': 10},
#    {'label': 'Deterministic noise', 'linked_to_count': 10},
#    {'label': 'Statistical significance', 'linked_to_count': 10},
#    {'label': 'Support Vector Machines', 'linked_to_count': 10},
#    {'label': 'Independent and identically-distributed random variables',
#     'linked_to_count': 10},
#    {'label': 'Euclidean norm', 'linked_to_count': 10},
#    {'label': 'Analytical learning', 'linked_to_count': 10},
#    {'label': 'Group method of data handling', 'linked_to_count': 10},
#    {'label': 'Learning Automata', 'linked_to_count': 10},
#    {'label': 'Naive bayes classifier', 'linked_to_count': 10},
#    {'label': 'Nearest neighbor (pattern recognition)', 'linked_to_count': 10},
#    {'label': 'Ripple down rules', 'linked_to_count': 10},
#    {'label': 'Symbolic machine learning', 'linked_to_count': 10},
#    {'label': 'Subsymbolic machine learning', 'linked_to_count': 10},
#    {'label': 'Ensembles of Classifiers', 'linked_to_count': 10},
#    {'label': 'Ordinal classification', 'linked_to_count': 10},
#    {'label': 'Data Pre-processing', 'linked_to_count': 10},
#    {'label': 'Handling imbalanced datasets', 'linked_to_count': 10},
#    {'label': 'Proaftn', 'linked_to_count': 10},
#    {'label': 'Quantitative structure–activity relationship',
#     'linked_to_count': 10},
#    {'label': 'Database marketing', 'linked_to_count': 10},
#    {'label': 'Information extraction', 'linked_to_count': 10},
#    {'label': 'Spamming', 'linked_to_count': 10},
#    {'label': 'Downward causation', 'linked_to_count': 10},
#    {'label': 'Overfitting (machine learning)', 'linked_to_count': 10}],
#   'label': 'Supervised learning'},
#  {'concepts': [{'label': 'Artificial intelligence', 'linked_to_count': 220},
#    {'label': 'Regularization (mathematics)', 'linked_to_count': 220},
#    {'label': 'Feature selection', 'linked_to_count': 180},
#    {'label': 'Support vector machine', 'linked_to_count': 180},
#    {'label': 'Cluster analysis', 'linked_to_count': 160},
#    {'label': 'Data mining', 'linked_to_count': 150},
#    {'label': 'Regression analysis', 'linked_to_count': 150},
#    {'label': 'Computer vision', 'linked_to_count': 140},
#    {'label': 'Neural network', 'linked_to_count': 140},
#    {'label': 'Deep learning', 'linked_to_count': 140},
#    {'label': 'Logistic regression', 'linked_to_count': 130},
#    {'label': 'Probability distribution', 'linked_to_count': 120},
#    {'label': 'Linear regression', 'linked_to_count': 120},
#    {'label': 'Classification (machine learning)', 'linked_to_count': 100},
#    {'label': 'Boosting (meta-algorithm)', 'linked_to_count': 100},
#    {'label': 'Training set', 'linked_to_count': 90},
#    {'label': 'Probability', 'linked_to_count': 90},
#    {'label': 'Feature extraction', 'linked_to_count': 90},
#    {'label': 'Loss function', 'linked_to_count': 90},
#    {'label': 'Bayesian inference', 'linked_to_count': 90},
#    {'label': 'Speech recognition', 'linked_to_count': 90},
#    {'label': 'Perceptron', 'linked_to_count': 90},
#    {'label': 'Linear discriminant analysis', 'linked_to_count': 80},
#    {'label': 'Statistical inference', 'linked_to_count': 80},
#    {'label': 'Predictive analytics', 'linked_to_count': 80},
#    {'label': 'Dot product', 'linked_to_count': 70},
#    {'label': 'Real number', 'linked_to_count': 70},
#    {'label': 'Data', 'linked_to_count': 60},
#    {'label': 'Expected value', 'linked_to_count': 60},
#    {'label': 'Prior probability', 'linked_to_count': 60},
#    {'label': 'Maximum likelihood', 'linked_to_count': 60},
#    {'label': 'Decision tree', 'linked_to_count': 60},
#    {'label': 'Naive Bayes classifier', 'linked_to_count': 60},
#    {'label': 'K-means clustering', 'linked_to_count': 60},
#    {'label': 'Tensor', 'linked_to_count': 60},
#    {'label': 'Hidden Markov model', 'linked_to_count': 60},
#    {'label': 'Vector space', 'linked_to_count': 50},
#    {'label': 'Probability theory', 'linked_to_count': 50},
#    {'label': 'Optimization problem', 'linked_to_count': 50},
#    {'label': 'Posterior probability', 'linked_to_count': 50},
#    {'label': 'Handwriting recognition', 'linked_to_count': 50},
#    {'label': 'Artificial neural networks', 'linked_to_count': 50},
#    {'label': 'Independent component analysis', 'linked_to_count': 50},
#    {'label': 'Decision theory', 'linked_to_count': 40},
#    {'label': 'Variable kernel density estimation', 'linked_to_count': 40},
#    {'label': 'Bootstrap aggregating', 'linked_to_count': 40},
#    {'label': 'Bayesian network', 'linked_to_count': 40},
#    {'label': 'Part of speech tagging', 'linked_to_count': 30},
#    {'label': 'Part of speech', 'linked_to_count': 30},
#    {'label': 'Parsing', 'linked_to_count': 30},
#    {'label': 'Data clustering', 'linked_to_count': 30},
#    {'label': 'Space (mathematics)', 'linked_to_count': 30},
#    {'label': 'Categorical data', 'linked_to_count': 30},
#    {'label': 'Integer', 'linked_to_count': 30},
#    {'label': 'Bayesian statistics', 'linked_to_count': 30},
#    {'label': 'Maximum entropy classifier', 'linked_to_count': 30},
#    {'label': 'Ensemble learning', 'linked_to_count': 30},
#    {'label': 'Maximum entropy Markov model', 'linked_to_count': 30},
#    {'label': 'Compound term processing', 'linked_to_count': 30},
#    {'label': 'Neocognitron', 'linked_to_count': 30},
#    {'label': 'Sequence mining', 'linked_to_count': 30},
#    {'label': 'Knowledge discovery in databases', 'linked_to_count': 20},
#    {'label': 'Parse tree', 'linked_to_count': 20},
#    {'label': 'Syntactic structure', 'linked_to_count': 20},
#    {'label': 'Pattern matching', 'linked_to_count': 20},
#    {'label': 'Distance', 'linked_to_count': 20},
#    {'label': 'Community ecology', 'linked_to_count': 20},
#    {'label': 'Ordinal data', 'linked_to_count': 20},
#    {'label': 'Branch and bound', 'linked_to_count': 20},
#    {'label': 'Principal components analysis', 'linked_to_count': 20},
#    {'label': "Bayes' rule", 'linked_to_count': 20},
#    {'label': 'Frequentist inference', 'linked_to_count': 20},
#    {'label': 'Covariance matrix', 'linked_to_count': 20},
#    {'label': 'Dirichlet distribution', 'linked_to_count': 20},
#    {'label': 'Quadratic classifier', 'linked_to_count': 20},
#    {'label': 'Multinomial logistic regression', 'linked_to_count': 20},
#    {'label': 'Hierarchical clustering', 'linked_to_count': 20},
#    {'label': 'Kernel principal component analysis', 'linked_to_count': 20},
#    {'label': 'Ensemble averaging', 'linked_to_count': 20},
#    {'label': 'Mixture of experts', 'linked_to_count': 20},
#    {'label': 'Hierarchical mixture of experts', 'linked_to_count': 20},
#    {'label': 'Markov random field', 'linked_to_count': 20},
#    {'label': 'Kalman filter', 'linked_to_count': 20},
#    {'label': 'Gaussian process regression', 'linked_to_count': 20},
#    {'label': 'Recurrent neural networks', 'linked_to_count': 20},
#    {'label': 'Adaptive resonance theory', 'linked_to_count': 20},
#    {'label': 'Cache language model', 'linked_to_count': 20},
#    {'label': 'Perception', 'linked_to_count': 20},
#    {'label': 'Perceptual learning', 'linked_to_count': 20},
#    {'label': 'Engineering', 'linked_to_count': 10},
#    {'label': 'Conference on Computer Vision and Pattern Recognition',
#     'linked_to_count': 10},
#    {'label': 'Regular expression', 'linked_to_count': 10},
#    {'label': 'Text editor', 'linked_to_count': 10},
#    {'label': 'Word processor', 'linked_to_count': 10},
#    {'label': "Occam's Razor", 'linked_to_count': 10},
#    {'label': 'Nominal data', 'linked_to_count': 10},
#    {'label': 'Powerset', 'linked_to_count': 10},
#    {'label': 'Zero-one loss function', 'linked_to_count': 10},
#    {'label': 'Bayes error rate', 'linked_to_count': 10},
#    {'label': 'Correctness (computer science)', 'linked_to_count': 10},
#    {'label': 'Continuous distribution', 'linked_to_count': 10},
#    {'label': 'Integral', 'linked_to_count': 10},
#    {'label': 'Maximum a posteriori', 'linked_to_count': 10},
#    {'label': 'Fisher discriminant analysis', 'linked_to_count': 10},
#    {'label': 'Bayes rule', 'linked_to_count': 10},
#    {'label': 'A priori and a posteriori', 'linked_to_count': 10},
#    {'label': 'Beta distribution', 'linked_to_count': 10},
#    {'label': 'Conjugate prior distribution', 'linked_to_count': 10},
#    {'label': 'File:800px-Cool Kids of Death Off Festival p 146-face selected.jpg',
#     'linked_to_count': 10},
#    {'label': 'Computer-aided diagnosis', 'linked_to_count': 10},
#    {'label': 'File:SRT Shape Recognition Technology Principles.png',
#     'linked_to_count': 10},
#    {'label': 'Image analysis', 'linked_to_count': 10},
#    {'label': 'Deep Learning', 'linked_to_count': 10},
#    {'label': 'Pattern recognition (psychology)', 'linked_to_count': 10},
#    {'label': 'K-nearest-neighbor', 'linked_to_count': 10},
#    {'label': 'Gene expression programming', 'linked_to_count': 10},
#    {'label': 'Correlation clustering', 'linked_to_count': 10},
#    {'label': 'Meta-algorithm', 'linked_to_count': 10},
#    {'label': 'Particle filter', 'linked_to_count': 10},
#    {'label': 'Black box', 'linked_to_count': 10},
#    {'label': 'List of numerical analysis software', 'linked_to_count': 10},
#    {'label': 'List of numerical libraries', 'linked_to_count': 10},
#    {'label': 'Template matching', 'linked_to_count': 10},
#    {'label': 'Contextual image classification', 'linked_to_count': 10}],
#   'label': 'Pattern recognition'},
#  {'concepts': [{'label': 'Statistics', 'linked_to_count': 230},
#    {'label': 'Regularization (mathematics)', 'linked_to_count': 220},
#    {'label': 'Algorithm', 'linked_to_count': 170},
#    {'label': 'Linear regression', 'linked_to_count': 120},
#    {'label': "Occam's razor", 'linked_to_count': 60},
#    {'label': 'VC dimension', 'linked_to_count': 60},
#    {'label': 'Model selection', 'linked_to_count': 50},
#    {'label': 'Training data', 'linked_to_count': 40},
#    {'label': 'Statistical model', 'linked_to_count': 30},
#    {'label': 'Prior distribution', 'linked_to_count': 30},
#    {'label': 'Parameter', 'linked_to_count': 20},
#    {'label': 'Function approximation', 'linked_to_count': 20},
#    {'label': 'File:Overfitted Data.png', 'linked_to_count': 10},
#    {'label': 'Random error', 'linked_to_count': 10},
#    {'label': 'Predictive inference', 'linked_to_count': 10},
#    {'label': 'Model error', 'linked_to_count': 10},
#    {'label': 'Coefficient of determination', 'linked_to_count': 10},
#    {'label': 'Shrinkage (statistics)', 'linked_to_count': 10},
#    {'label': 'Pruning (algorithm)', 'linked_to_count': 10},
#    {'label': 'Bayesian model comparison', 'linked_to_count': 10},
#    {'label': 'File:Overfitting svg.svg', 'linked_to_count': 10},
#    {'label': 'Causal relation', 'linked_to_count': 10},
#    {'label': 'Robustness (computer science)', 'linked_to_count': 10},
#    {'label': 'Curve fitting', 'linked_to_count': 10},
#    {'label': 'Data dredging', 'linked_to_count': 10},
#    {'label': 'Journal of Chemical Information and Modeling',
#     'linked_to_count': 10}],
#   'label': 'Overfitting'},
#  {'concepts': [{'label': 'Feature selection', 'linked_to_count': 180},
#    {'label': 'Support vector machines', 'linked_to_count': 100},
#    {'label': 'Bayesian inference', 'linked_to_count': 90},
#    {'label': 'Neural networks', 'linked_to_count': 70},
#    {'label': "Occam's razor", 'linked_to_count': 60},
#    {'label': 'Naive Bayes classifier', 'linked_to_count': 60},
#    {'label': 'No free lunch in search and optimization',
#     'linked_to_count': 60},
#    {'label': 'Minimum description length', 'linked_to_count': 50},
#    {'label': 'K-nearest neighbors algorithm', 'linked_to_count': 30},
#    {'label': 'Conditional independence', 'linked_to_count': 20},
#    {'label': 'Feature space', 'linked_to_count': 20},
#    {'label': 'Bias', 'linked_to_count': 20},
#    {'label': 'Learning algorithm', 'linked_to_count': 10},
#    {'label': 'Mathematical logic', 'linked_to_count': 10},
#    {'label': 'Cognitive bias', 'linked_to_count': 10}],
#   'label': 'Inductive bias'},
#  {'concepts': [{'label': 'Support vector machine', 'linked_to_count': 180},
#    {'label': 'Neural network', 'linked_to_count': 140},
#    {'label': 'Logistic regression', 'linked_to_count': 130},
#    {'label': 'Information retrieval', 'linked_to_count': 120},
#    {'label': 'Bayesian inference', 'linked_to_count': 90},
#    {'label': 'Decision tree learning', 'linked_to_count': 70},
#    {'label': 'Multi-label classification', 'linked_to_count': 60},
#    {'label': 'Accuracy and precision', 'linked_to_count': 50},
#    {'label': 'Kernel methods', 'linked_to_count': 50},
#    {'label': 'Bayesian network', 'linked_to_count': 40},
#    {'label': 'Contingency table', 'linked_to_count': 40},
#    {'label': 'Regression coefficient', 'linked_to_count': 40},
#    {'label': 'Positive predictive value', 'linked_to_count': 40},
#    {'label': 'Classification rule', 'linked_to_count': 30},
#    {'label': 'Discretization', 'linked_to_count': 30},
#    {'label': 'Type I and type II errors', 'linked_to_count': 30},
#    {'label': 'Sensitivity and specificity', 'linked_to_count': 30},
#    {'label': 'Precision and recall', 'linked_to_count': 30},
#    {'label': 'True positive', 'linked_to_count': 30},
#    {'label': 'True negative', 'linked_to_count': 30},
#    {'label': 'False positive', 'linked_to_count': 30},
#    {'label': 'False negative', 'linked_to_count': 30},
#    {'label': 'Recall (information retrieval)', 'linked_to_count': 30},
#    {'label': 'Specificity (tests)', 'linked_to_count': 30},
#    {'label': 'Precision (information retrieval)', 'linked_to_count': 30},
#    {'label': 'F1 score', 'linked_to_count': 30},
#    {'label': 'Markedness', 'linked_to_count': 30},
#    {'label': 'Geometric mean', 'linked_to_count': 30},
#    {'label': "Youden's J statistic", 'linked_to_count': 30},
#    {'label': 'Uncertainty coefficient', 'linked_to_count': 30},
#    {'label': 'Negative predictive value', 'linked_to_count': 30},
#    {'label': 'Receiver operating characteristic', 'linked_to_count': 30},
#    {'label': 'Set (mathematics)', 'linked_to_count': 20},
#    {'label': 'Random forests', 'linked_to_count': 20},
#    {'label': 'File:Binary-classification-labeled.svg', 'linked_to_count': 20},
#    {'label': 'Prevalence', 'linked_to_count': 20},
#    {'label': 'True Positive Rate', 'linked_to_count': 20},
#    {'label': 'Sensitivity (tests)', 'linked_to_count': 20},
#    {'label': 'True Negative Rate', 'linked_to_count': 20},
#    {'label': 'Diagnostic odds ratio', 'linked_to_count': 20},
#    {'label': 'Odds ratio', 'linked_to_count': 20},
#    {'label': 'F-score', 'linked_to_count': 20},
#    {'label': 'Informedness', 'linked_to_count': 20},
#    {'label': 'Human chorionic gonadotropin', 'linked_to_count': 20},
#    {'label': 'Multiclass classification', 'linked_to_count': 20},
#    {'label': 'Thresholding (image processing)', 'linked_to_count': 20},
#    {'label': 'Qualitative property', 'linked_to_count': 10},
#    {'label': 'Medical test', 'linked_to_count': 10},
#    {'label': 'Test method', 'linked_to_count': 10},
#    {'label': 'Quality control', 'linked_to_count': 10},
#    {'label': 'Go/no go', 'linked_to_count': 10},
#    {'label': 'Result set', 'linked_to_count': 10},
#    {'label': 'False positives and false negatives', 'linked_to_count': 10},
#    {'label': 'False Negative Rate', 'linked_to_count': 10},
#    {'label': 'False Positive Rate', 'linked_to_count': 10},
#    {'label': 'Positive Predictive Value', 'linked_to_count': 10},
#    {'label': 'False Discovery Rate', 'linked_to_count': 10},
#    {'label': 'Negative Predictive Value', 'linked_to_count': 10},
#    {'label': 'False Omission Rate', 'linked_to_count': 10},
#    {'label': 'Likelihood ratio (disambiguation)', 'linked_to_count': 10},
#    {'label': 'Likelihood ratios in diagnostic testing', 'linked_to_count': 10},
#    {'label': 'Blood values', 'linked_to_count': 10},
#    {'label': 'Cutoff (reference value)', 'linked_to_count': 10},
#    {'label': 'Positive or negative test', 'linked_to_count': 10},
#    {'label': 'Predictive value', 'linked_to_count': 10},
#    {'label': 'Pregnancy test', 'linked_to_count': 10},
#    {'label': 'Detection theory', 'linked_to_count': 10},
#    {'label': 'One-class classification', 'linked_to_count': 10},
#    {'label': "Prosecutor's fallacy", 'linked_to_count': 10},
#    {'label': 'Nello Cristianini', 'linked_to_count': 10},
#    {'label': 'John Shawe-Taylor', 'linked_to_count': 10}],
#   'label': 'Binary classification'},
#  {'concepts': [{'label': 'Regularization (mathematics)',
#     'linked_to_count': 220},
#    {'label': 'Artificial neural network', 'linked_to_count': 170},
#    {'label': 'Tikhonov regularization', 'linked_to_count': 90},
#    {'label': 'Reproducing kernel Hilbert space', 'linked_to_count': 80},
#    {'label': 'Boosting (machine learning)', 'linked_to_count': 60},
#    {'label': 'Gradient descent', 'linked_to_count': 40},
#    {'label': 'Generalization error', 'linked_to_count': 30},
#    {'label': 'Bias-variance dilemma', 'linked_to_count': 30},
#    {'label': 'File:Overfitting on Training Set Data.pdf',
#     'linked_to_count': 20},
#    {'label': 'Non-parametric regression', 'linked_to_count': 20},
#    {'label': 'Consistency (statistics)', 'linked_to_count': 20},
#    {'label': 'Principal component regression', 'linked_to_count': 10},
#    {'label': 'Spectral regularization', 'linked_to_count': 10},
#    {'label': 'AdaBoost', 'linked_to_count': 10}],
#   'label': 'Early stopping'},
#  {'concepts': [{'label': 'Statistics', 'linked_to_count': 230},
#    {'label': 'Reinforcement learning', 'linked_to_count': 180},
#    {'label': 'Artificial neural network', 'linked_to_count': 170},
#    {'label': 'Cluster analysis', 'linked_to_count': 160},
#    {'label': 'Neural network', 'linked_to_count': 140},
#    {'label': 'Principal component analysis', 'linked_to_count': 120},
#    {'label': 'Singular value decomposition', 'linked_to_count': 70},
#    {'label': 'Independent component analysis', 'linked_to_count': 50},
#    {'label': 'Anomaly detection', 'linked_to_count': 40},
#    {'label': 'Mean', 'linked_to_count': 40},
#    {'label': 'Density estimation', 'linked_to_count': 30},
#    {'label': 'Data clustering', 'linked_to_count': 30},
#    {'label': 'Latent variable model', 'linked_to_count': 30},
#    {'label': 'Covariance', 'linked_to_count': 30},
#    {'label': 'Radial basis function network', 'linked_to_count': 30},
#    {'label': 'MIT Press', 'linked_to_count': 30},
#    {'label': 'Mixture models', 'linked_to_count': 20},
#    {'label': 'Hierarchical clustering', 'linked_to_count': 20},
#    {'label': 'Method of moments (statistics)', 'linked_to_count': 20},
#    {'label': 'Donald Hebb', 'linked_to_count': 20},
#    {'label': 'Adaptive resonance theory', 'linked_to_count': 20},
#    {'label': 'Topic modeling', 'linked_to_count': 20},
#    {'label': 'Richard O. Duda', 'linked_to_count': 20},
#    {'label': 'Peter E. Hart', 'linked_to_count': 20},
#    {'label': 'Geoffrey Hinton', 'linked_to_count': 20},
#    {'label': 'K-means', 'linked_to_count': 10},
#    {'label': 'Hebbian Learning', 'linked_to_count': 10},
#    {'label': 'Expectation–maximization algorithm', 'linked_to_count': 10},
#    {'label': 'Blind signal separation', 'linked_to_count': 10},
#    {'label': 'Non-negative matrix factorization', 'linked_to_count': 10},
#    {'label': 'Hebbian learning', 'linked_to_count': 10},
#    {'label': 'Spike-timing-dependent plasticity', 'linked_to_count': 10},
#    {'label': 'Self-organizing map', 'linked_to_count': 10},
#    {'label': 'Vigilance parameter', 'linked_to_count': 10},
#    {'label': 'Automatic target recognition', 'linked_to_count': 10},
#    {'label': 'Tensors', 'linked_to_count': 10},
#    {'label': 'Generative topographic map', 'linked_to_count': 10},
#    {'label': 'Multivariate analysis', 'linked_to_count': 10},
#    {'label': 'Hebbian Theory', 'linked_to_count': 10},
#    {'label': 'Pattern classification', 'linked_to_count': 10},
#    {'label': 'Terrence J. Sejnowski', 'linked_to_count': 10}],
#   'label': 'Unsupervised learning'},
#  {'concepts': [{'label': 'Cluster analysis', 'linked_to_count': 160},
#    {'label': 'Data mining', 'linked_to_count': 150},
#    {'label': 'Inductive logic programming', 'linked_to_count': 100},
#    {'label': 'Time complexity', 'linked_to_count': 50},
#    {'label': 'Graphical model', 'linked_to_count': 50},
#    {'label': 'Factor analysis', 'linked_to_count': 40},
#    {'label': 'Information science', 'linked_to_count': 30},
#    {'label': 'Text mining', 'linked_to_count': 30},
#    {'label': 'Association rule learning', 'linked_to_count': 30},
#    {'label': 'Semantics', 'linked_to_count': 20},
#    {'label': 'Linguistics', 'linked_to_count': 20},
#    {'label': 'Partial order', 'linked_to_count': 20},
#    {'label': 'Predicate (mathematical logic)', 'linked_to_count': 20},
#    {'label': 'Power set', 'linked_to_count': 20},
#    {'label': 'Graph traversal', 'linked_to_count': 20},
#    {'label': 'Commonsense reasoning', 'linked_to_count': 20},
#    {'label': 'Conceptual clustering', 'linked_to_count': 20},
#    {'label': 'Concept mining', 'linked_to_count': 20},
#    {'label': 'Description logic', 'linked_to_count': 20},
#    {'label': 'Pattern theory', 'linked_to_count': 20},
#    {'label': 'Principle', 'linked_to_count': 10},
#    {'label': 'Concept hierarchy', 'linked_to_count': 10},
#    {'label': 'Ontology (computer science)', 'linked_to_count': 10},
#    {'label': 'Mathematical object', 'linked_to_count': 10},
#    {'label': 'Property (philosophy)', 'linked_to_count': 10},
#    {'label': 'Subset', 'linked_to_count': 10},
#    {'label': 'Rudolf Wille', 'linked_to_count': 10},
#    {'label': 'Lattice theory', 'linked_to_count': 10},
#    {'label': 'Order theory', 'linked_to_count': 10},
#    {'label': 'Garrett Birkhoff', 'linked_to_count': 10},
#    {'label': 'Knowledge management', 'linked_to_count': 10},
#    {'label': 'Semantic web', 'linked_to_count': 10},
#    {'label': 'Software development', 'linked_to_count': 10},
#    {'label': 'Chemistry', 'linked_to_count': 10},
#    {'label': 'Biology', 'linked_to_count': 10},
#    {'label': 'Lattice (order)', 'linked_to_count': 10},
#    {'label': 'Binary relations', 'linked_to_count': 10},
#    {'label': 'Dual (math)', 'linked_to_count': 10},
#    {'label': 'Extension (semantics)', 'linked_to_count': 10},
#    {'label': 'Intension', 'linked_to_count': 10},
#    {'label': 'Partially ordered set', 'linked_to_count': 10},
#    {'label': 'Galois connection', 'linked_to_count': 10},
#    {'label': 'Peter Burmeister', 'linked_to_count': 10},
#    {'label': 'Technische Universität Darmstadt', 'linked_to_count': 10},
#    {'label': 'Charles S. Peirce', 'linked_to_count': 10},
#    {'label': 'Hartmut von Hentig', 'linked_to_count': 10},
#    {'label': 'Formal logic', 'linked_to_count': 10},
#    {'label': 'Model theory', 'linked_to_count': 10},
#    {'label': 'Predicate (logic)', 'linked_to_count': 10},
#    {'label': 'Pragmatic maxim', 'linked_to_count': 10},
#    {'label': 'Minor premise', 'linked_to_count': 10},
#    {'label': 'Reality', 'linked_to_count': 10},
#    {'label': 'Judgement', 'linked_to_count': 10},
#    {'label': 'Consequent', 'linked_to_count': 10},
#    {'label': 'Logical possibility', 'linked_to_count': 10},
#    {'label': 'Communication', 'linked_to_count': 10},
#    {'label': 'Bipartite graph', 'linked_to_count': 10},
#    {'label': 'Poset height', 'linked_to_count': 10},
#    {'label': 'Idempotent', 'linked_to_count': 10},
#    {'label': 'Increasing', 'linked_to_count': 10},
#    {'label': 'Closure operator', 'linked_to_count': 10},
#    {'label': 'Matrix (math)', 'linked_to_count': 10},
#    {'label': 'Boolean value', 'linked_to_count': 10},
#    {'label': 'Maximal element', 'linked_to_count': 10},
#    {'label': 'Composite number', 'linked_to_count': 10},
#    {'label': 'Even number', 'linked_to_count': 10},
#    {'label': 'Odd number', 'linked_to_count': 10},
#    {'label': 'Prime number', 'linked_to_count': 10},
#    {'label': 'Square number', 'linked_to_count': 10},
#    {'label': 'Join and meet', 'linked_to_count': 10},
#    {'label': 'Complete lattice', 'linked_to_count': 10},
#    {'label': 'Dedekind–MacNeille completion', 'linked_to_count': 10},
#    {'label': 'File:Concept lattice.svg', 'linked_to_count': 10},
#    {'label': 'Injective function', 'linked_to_count': 10},
#    {'label': 'Order-reversing', 'linked_to_count': 10},
#    {'label': 'Orthocomplemented lattice', 'linked_to_count': 10},
#    {'label': 'Boolean algebra (structure)', 'linked_to_count': 10},
#    {'label': 'Hasse diagram', 'linked_to_count': 10},
#    {'label': 'Monotonic', 'linked_to_count': 10},
#    {'label': 'Armstrong axioms', 'linked_to_count': 10},
#    {'label': 'Polynomial delay', 'linked_to_count': 10},
#    {'label': 'Lattice Miner', 'linked_to_count': 10},
#    {'label': 'Biclustering', 'linked_to_count': 10},
#    {'label': 'Correspondence analysis', 'linked_to_count': 10},
#    {'label': 'Grounded theory', 'linked_to_count': 10},
#    {'label': 'Cambridge University Press', 'linked_to_count': 10}],
#   'label': 'Formal concept analysis'},
#  {'concepts': [{'label': 'Support vector machine', 'linked_to_count': 180},
#    {'label': 'Computer science', 'linked_to_count': 110},
#    {'label': 'Boosting (meta-algorithm)', 'linked_to_count': 100},
#    {'label': 'Probability', 'linked_to_count': 90},
#    {'label': 'Bayesian inference', 'linked_to_count': 90},
#    {'label': 'Artificial Intelligence', 'linked_to_count': 70},
#    {'label': 'Probably approximately correct learning', 'linked_to_count': 70},
#    {'label': 'Vladimir Vapnik', 'linked_to_count': 70},
#    {'label': 'Online machine learning', 'linked_to_count': 70},
#    {'label': 'VC dimension', 'linked_to_count': 60},
#    {'label': 'Boosting (machine learning)', 'linked_to_count': 60},
#    {'label': 'Inference', 'linked_to_count': 30},
#    {'label': 'Bayesian probability', 'linked_to_count': 30},
#    {'label': 'Leslie Valiant', 'linked_to_count': 30},
#    {'label': 'Information theory', 'linked_to_count': 30},
#    {'label': 'Dana Angluin', 'linked_to_count': 20},
#    {'label': 'VC theory', 'linked_to_count': 20},
#    {'label': 'Alexey Chervonenkis', 'linked_to_count': 20},
#    {'label': 'E. Mark Gold', 'linked_to_count': 20},
#    {'label': 'Occam Learning', 'linked_to_count': 20},
#    {'label': 'List of important publications in computer science',
#     'linked_to_count': 20},
#    {'label': 'Polynomial time', 'linked_to_count': 10},
#    {'label': 'P versus NP problem', 'linked_to_count': 10},
#    {'label': 'Cryptography', 'linked_to_count': 10},
#    {'label': 'One-way function', 'linked_to_count': 10},
#    {'label': 'Frequency probability', 'linked_to_count': 10},
#    {'label': 'Exact learning', 'linked_to_count': 10},
#    {'label': 'Algorithmic learning theory', 'linked_to_count': 10},
#    {'label': 'Belief networks', 'linked_to_count': 10},
#    {'label': 'Judea Pearl', 'linked_to_count': 10},
#    {'label': 'Oded Goldreich', 'linked_to_count': 10},
#    {'label': 'Dana Ron', 'linked_to_count': 10},
#    {'label': 'Manfred K. Warmuth', 'linked_to_count': 10},
#    {'label': 'Distribution learning theory', 'linked_to_count': 10}],
#   'label': 'Computational learning theory'},
#  {'concepts': [{'label': 'Algorithm', 'linked_to_count': 170},
#    {'label': 'Probability distribution', 'linked_to_count': 120},
#    {'label': 'Probability', 'linked_to_count': 90},
#    {'label': 'Bayesian inference', 'linked_to_count': 90},
#    {'label': "Occam's razor", 'linked_to_count': 60},
#    {'label': 'Expected value', 'linked_to_count': 60},
#    {'label': 'Prior probability', 'linked_to_count': 60},
#    {'label': "Bayes' theorem", 'linked_to_count': 60},
#    {'label': 'Minimum description length', 'linked_to_count': 50},
#    {'label': 'Minimum message length', 'linked_to_count': 50},
#    {'label': 'Ray Solomonoff', 'linked_to_count': 30},
#    {'label': 'Algorithmic probability', 'linked_to_count': 30},
#    {'label': 'Kolmogorov complexity', 'linked_to_count': 30},
#    {'label': 'Language identification in the limit', 'linked_to_count': 30},
#    {'label': 'Inductive inference', 'linked_to_count': 30},
#    {'label': 'MIT Press', 'linked_to_count': 30},
#    {'label': 'Computable function', 'linked_to_count': 20},
#    {'label': 'Universal artificial intelligence', 'linked_to_count': 20},
#    {'label': 'E. Mark Gold', 'linked_to_count': 20},
#    {'label': 'Turing machine', 'linked_to_count': 20},
#    {'label': 'Algorithmic information theory', 'linked_to_count': 20},
#    {'label': 'Principle of Multiple Explanations', 'linked_to_count': 10},
#    {'label': 'Universal prior', 'linked_to_count': 10},
#    {'label': 'Zero probability', 'linked_to_count': 10},
#    {'label': 'Computable', 'linked_to_count': 10},
#    {'label': 'Denumerable', 'linked_to_count': 10},
#    {'label': 'Universal computer', 'linked_to_count': 10},
#    {'label': 'Limit (math)', 'linked_to_count': 10},
#    {'label': 'Super-recursive algorithm', 'linked_to_count': 10},
#    {'label': 'Event loop', 'linked_to_count': 10},
#    {'label': "Mill's methods", 'linked_to_count': 10},
#    {'label': 'Turing Machine', 'linked_to_count': 10},
#    {'label': 'Problem of induction', 'linked_to_count': 10},
#    {'label': 'New riddle of induction', 'linked_to_count': 10},
#    {'label': 'Martin Davis', 'linked_to_count': 10},
#    {'label': 'William Gasarch', 'linked_to_count': 10},
#    {'label': 'Carl Herbert Smith', 'linked_to_count': 10}],
#   'label': "Solomonoff's theory of inductive inference"},
#  {'concepts': [{'label': 'Statistics', 'linked_to_count': 230},
#    {'label': 'Feature selection', 'linked_to_count': 180},
#    {'label': 'Logistic regression', 'linked_to_count': 130},
#    {'label': 'Linear regression', 'linked_to_count': 120},
#    {'label': 'Support vector machines', 'linked_to_count': 100},
#    {'label': 'Real number', 'linked_to_count': 70},
#    {'label': 'Accuracy', 'linked_to_count': 60},
#    {'label': 'Data', 'linked_to_count': 60},
#    {'label': 'Expected value', 'linked_to_count': 60},
#    {'label': 'Optical character recognition', 'linked_to_count': 60},
#    {'label': 'Boosting (machine learning)', 'linked_to_count': 60},
#    {'label': 'Optimization (mathematics)', 'linked_to_count': 50},
#    {'label': 'Model selection', 'linked_to_count': 50},
#    {'label': 'Least squares', 'linked_to_count': 40},
#    {'label': 'Positive predictive value', 'linked_to_count': 40},
#    {'label': 'Bootstrap aggregating', 'linked_to_count': 40},
#    {'label': 'Variance', 'linked_to_count': 30},
#    {'label': 'Statistical model', 'linked_to_count': 30},
#    {'label': 'Independence (probability theory)', 'linked_to_count': 30},
#    {'label': 'Mean squared error', 'linked_to_count': 30},
#    {'label': 'Partition of a set', 'linked_to_count': 20},
#    {'label': 'Statistical sample', 'linked_to_count': 20},
#    {'label': 'Statistical population', 'linked_to_count': 20},
#    {'label': 'Hyperplane', 'linked_to_count': 20},
#    {'label': 'Bias (statistics)', 'linked_to_count': 20},
#    {'label': 'Monte Carlo method', 'linked_to_count': 20},
#    {'label': 'Kernel regression', 'linked_to_count': 20},
#    {'label': 'Closed-form expression', 'linked_to_count': 20},
#    {'label': 'Features (pattern recognition)', 'linked_to_count': 20},
#    {'label': 'Validity (statistics)', 'linked_to_count': 20},
#    {'label': 'File:K-fold cross validation EN.jpg', 'linked_to_count': 10},
#    {'label': 'Model validation', 'linked_to_count': 10},
#    {'label': 'Complement (set theory)', 'linked_to_count': 10},
#    {'label': 'Parameters', 'linked_to_count': 10},
#    {'label': 'Euclidean vector', 'linked_to_count': 10},
#    {'label': 'Binomial coefficient', 'linked_to_count': 10},
#    {'label': 'Jackknife resampling', 'linked_to_count': 10},
#    {'label': 'Dichotomous', 'linked_to_count': 10},
#    {'label': 'Root mean squared error', 'linked_to_count': 10},
#    {'label': 'Median absolute deviation', 'linked_to_count': 10},
#    {'label': 'K nearest neighbors', 'linked_to_count': 10},
#    {'label': 'Gene expression', 'linked_to_count': 10},
#    {'label': 'Proteins', 'linked_to_count': 10},
#    {'label': 'Cancer', 'linked_to_count': 10},
#    {'label': 'Drug', 'linked_to_count': 10},
#    {'label': 'Sherman–Morrison formula', 'linked_to_count': 10},
#    {'label': 'PRESS statistic', 'linked_to_count': 10},
#    {'label': 'Stock market prediction', 'linked_to_count': 10},
#    {'label': 'Medical diagnosis', 'linked_to_count': 10},
#    {'label': 'Bootstrapping (statistics)', 'linked_to_count': 10},
#    {'label': 'Resampling (statistics)', 'linked_to_count': 10}],
#   'label': 'Cross-validation (statistics)'},
#  {'concepts': [{'label': 'Learning', 'linked_to_count': 60},
#    {'label': 'Artificial neural networks', 'linked_to_count': 50},
#    {'label': 'Unary coding', 'linked_to_count': 10},
#    {'label': 'Web search', 'linked_to_count': 10},
#    {'label': 'Time series prediction', 'linked_to_count': 10},
#    {'label': 'Hamming weight', 'linked_to_count': 10},
#    {'label': 'Hopfield network', 'linked_to_count': 10}],
#   'label': 'Instantaneously trained neural networks'},
#  {'concepts': [{'label': 'Statistics', 'linked_to_count': 230},
#    {'label': 'Support vector machine', 'linked_to_count': 180},
#    {'label': 'Perceptron', 'linked_to_count': 90},
#    {'label': 'Real number', 'linked_to_count': 70},
#    {'label': 'Dot product', 'linked_to_count': 70},
#    {'label': 'Linear classifier', 'linked_to_count': 40},
#    {'label': 'Hyperplane', 'linked_to_count': 20},
#    {'label': 'Convex hull', 'linked_to_count': 20},
#    {'label': 'Boolean function', 'linked_to_count': 20},
#    {'label': 'Hypercube', 'linked_to_count': 20},
#    {'label': 'Euclidean geometry', 'linked_to_count': 10},
#    {'label': 'Point (geometry)', 'linked_to_count': 10},
#    {'label': 'Euclidean plane', 'linked_to_count': 10},
#    {'label': 'Line (geometry)', 'linked_to_count': 10},
#    {'label': 'Disjoint sets', 'linked_to_count': 10},
#    {'label': 'Collinear', 'linked_to_count': 10},
#    {'label': 'File:VC1.svg', 'linked_to_count': 10},
#    {'label': 'File:VC2.svg', 'linked_to_count': 10},
#    {'label': 'File:VC3.svg', 'linked_to_count': 10},
#    {'label': 'File:VC4.svg', 'linked_to_count': 10},
#    {'label': 'File:Svm separating hyperplanes (SVG).svg',
#     'linked_to_count': 10},
#    {'label': 'Maximum-margin hyperplane', 'linked_to_count': 10},
#    {'label': 'Margin classifier', 'linked_to_count': 10},
#    {'label': 'Normal (geometry)', 'linked_to_count': 10},
#    {'label': 'Vapnik–Chervonenkis dimension', 'linked_to_count': 10}],
#   'label': 'Linear separability'},
#  {'concepts': [{'label': 'Statistics', 'linked_to_count': 230},
#    {'label': 'Feature selection', 'linked_to_count': 180},
#    {'label': 'Regression analysis', 'linked_to_count': 150},
#    {'label': 'Neural network', 'linked_to_count': 140},
#    {'label': 'Principal component analysis', 'linked_to_count': 120},
#    {'label': 'Feature extraction', 'linked_to_count': 90},
#    {'label': 'Linear discriminant analysis', 'linked_to_count': 80},
#    {'label': 'Backpropagation', 'linked_to_count': 70},
#    {'label': 'Time series', 'linked_to_count': 70},
#    {'label': 'Singular value decomposition', 'linked_to_count': 70},
#    {'label': 'Tensor', 'linked_to_count': 60},
#    {'label': 'Restricted Boltzmann machine', 'linked_to_count': 60},
#    {'label': 'Manifold learning', 'linked_to_count': 50},
#    {'label': 'Kernel trick', 'linked_to_count': 40},
#    {'label': 'Neuroscience', 'linked_to_count': 40},
#    {'label': 'Mutual information', 'linked_to_count': 40},
#    {'label': 'MinHash', 'linked_to_count': 40},
#    {'label': 'Latent semantic analysis', 'linked_to_count': 40},
#    {'label': 'Combinatorial optimization', 'linked_to_count': 30},
#    {'label': 'Data analysis', 'linked_to_count': 30},
#    {'label': 'High-dimensional space', 'linked_to_count': 30},
#    {'label': 'Space (mathematics)', 'linked_to_count': 30},
#    {'label': 'Covariance', 'linked_to_count': 30},
#    {'label': 'Correlation and dependence', 'linked_to_count': 30},
#    {'label': 'Semidefinite programming', 'linked_to_count': 30},
#    {'label': 'Autoencoder', 'linked_to_count': 30},
#    {'label': 'K-nearest neighbors algorithm', 'linked_to_count': 30},
#    {'label': 'Canonical correlation analysis', 'linked_to_count': 30},
#    {'label': 'Locality sensitive hashing', 'linked_to_count': 30},
#    {'label': 'Information gain in decision trees', 'linked_to_count': 20},
#    {'label': 'Dimension', 'linked_to_count': 20},
#    {'label': 'Nonlinear dimensionality reduction', 'linked_to_count': 20},
#    {'label': 'Matrix (mathematics)', 'linked_to_count': 20},
#    {'label': 'Multidimensional scaling', 'linked_to_count': 20},
#    {'label': 'T-distributed stochastic neighbor embedding',
#     'linked_to_count': 20},
#    {'label': 'Multilinear PCA', 'linked_to_count': 20},
#    {'label': 'Eigenvalue, eigenvector and eigenspace', 'linked_to_count': 10},
#    {'label': 'Kernel PCA', 'linked_to_count': 10},
#    {'label': 'Isomap', 'linked_to_count': 10},
#    {'label': 'Locally linear embedding', 'linked_to_count': 10},
#    {'label': 'Local tangent space alignment', 'linked_to_count': 10},
#    {'label': 'Maximum variance unfolding', 'linked_to_count': 10},
#    {'label': 'Diffusion map', 'linked_to_count': 10},
#    {'label': 'Hidden layer', 'linked_to_count': 10},
#    {'label': 'Embedding', 'linked_to_count': 10},
#    {'label': 'VLDB', 'linked_to_count': 10},
#    {'label': 'Maximally informative dimensions', 'linked_to_count': 10},
#    {'label': 'Semidefinite embedding', 'linked_to_count': 10},
#    {'label': 'Multifactor dimensionality reduction', 'linked_to_count': 10},
#    {'label': 'Semantic mapping (statistics)', 'linked_to_count': 10},
#    {'label': 'Topological data analysis', 'linked_to_count': 10},
#    {'label': 'Sufficient dimension reduction', 'linked_to_count': 10},
#    {'label': 'Data transformation (statistics)', 'linked_to_count': 10},
#    {'label': 'Weighted correlation network analysis', 'linked_to_count': 10}],
#   'label': 'Dimensionality reduction'},
#  {'concepts': [{'label': 'Feature selection', 'linked_to_count': 180},
#    {'label': 'Cluster analysis', 'linked_to_count': 160},
#    {'label': 'Data mining', 'linked_to_count': 150},
#    {'label': 'Information retrieval', 'linked_to_count': 120},
#    {'label': 'Principal component analysis', 'linked_to_count': 120},
#    {'label': 'Classification (machine learning)', 'linked_to_count': 100},
#    {'label': 'K-nearest neighbor algorithm', 'linked_to_count': 100},
#    {'label': 'Real number', 'linked_to_count': 70},
#    {'label': 'Singular value decomposition', 'linked_to_count': 70},
#    {'label': 'Time series', 'linked_to_count': 70},
#    {'label': 'Optimization (mathematics)', 'linked_to_count': 50},
#    {'label': 'Euclidean distance', 'linked_to_count': 50},
#    {'label': 'Graph (discrete mathematics)', 'linked_to_count': 50},
#    {'label': 'Dimension reduction', 'linked_to_count': 50},
#    {'label': 'Database', 'linked_to_count': 40},
#    {'label': 'Independent and identically distributed random variables',
#     'linked_to_count': 40},
#    {'label': 'Anomaly detection', 'linked_to_count': 40},
#    {'label': 'High-dimensional space', 'linked_to_count': 30},
#    {'label': 'Space (mathematics)', 'linked_to_count': 30},
#    {'label': 'Data set', 'linked_to_count': 30},
#    {'label': 'Sampling (statistics)', 'linked_to_count': 20},
#    {'label': 'Combinatorial explosion', 'linked_to_count': 20},
#    {'label': 'Feature space', 'linked_to_count': 20},
#    {'label': 'Hypersphere', 'linked_to_count': 20},
#    {'label': 'Hypercube', 'linked_to_count': 20},
#    {'label': 'Concentration of measure', 'linked_to_count': 20},
#    {'label': 'Linear least squares (mathematics)', 'linked_to_count': 20},
#    {'label': 'Wavelet', 'linked_to_count': 20},
#    {'label': 'Three-dimensional space', 'linked_to_count': 10},
#    {'label': 'Physical space', 'linked_to_count': 10},
#    {'label': 'Richard E. Bellman', 'linked_to_count': 10},
#    {'label': 'Dynamic optimization', 'linked_to_count': 10},
#    {'label': 'Numerical analysis', 'linked_to_count': 10},
#    {'label': 'Combinatorics', 'linked_to_count': 10},
#    {'label': 'Volume', 'linked_to_count': 10},
#    {'label': 'Unit interval', 'linked_to_count': 10},
#    {'label': 'Unit hypercube', 'linked_to_count': 10},
#    {'label': 'Backward induction', 'linked_to_count': 10},
#    {'label': 'Gamma function', 'linked_to_count': 10},
#    {'label': 'Chi-squared distribution', 'linked_to_count': 10},
#    {'label': 'Signal-to-noise ratio', 'linked_to_count': 10},
#    {'label': 'Time series analysis', 'linked_to_count': 10},
#    {'label': 'Indegree', 'linked_to_count': 10},
#    {'label': 'Directed graph', 'linked_to_count': 10},
#    {'label': 'Skewness', 'linked_to_count': 10},
#    {'label': 'Data snooping', 'linked_to_count': 10},
#    {'label': 'Bellman equation', 'linked_to_count': 10},
#    {'label': 'Backwards induction', 'linked_to_count': 10},
#    {'label': 'Clustering high-dimensional data', 'linked_to_count': 10},
#    {'label': 'Model Order Reduction', 'linked_to_count': 10},
#    {'label': 'Dynamic programming', 'linked_to_count': 10},
#    {'label': 'Fourier-related transforms', 'linked_to_count': 10},
#    {'label': 'Quasi-random', 'linked_to_count': 10},
#    {'label': 'Stereology', 'linked_to_count': 10}],
#   'label': 'Curse of dimensionality'},
#  {'concepts': [{'label': 'Predictive analytics', 'linked_to_count': 80},
#    {'label': 'Contingency table', 'linked_to_count': 40}],
#   'label': 'Confusion matrix'},
#  {'concepts': [{'label': 'Statistics', 'linked_to_count': 230},
#    {'label': 'Cluster analysis', 'linked_to_count': 160},
#    {'label': 'Probability distribution', 'linked_to_count': 120},
#    {'label': 'Bayesian inference', 'linked_to_count': 90},
#    {'label': 'Statistical inference', 'linked_to_count': 80},
#    {'label': 'Normal distribution', 'linked_to_count': 70},
#    {'label': 'K-means clustering', 'linked_to_count': 60},
#    {'label': 'Hidden Markov model', 'linked_to_count': 60},
#    {'label': 'Maximum likelihood', 'linked_to_count': 60},
#    {'label': "Bayes' theorem", 'linked_to_count': 60},
#    {'label': 'Latent variable', 'linked_to_count': 50},
#    {'label': 'Posterior probability', 'linked_to_count': 50},
#    {'label': 'Minimum message length', 'linked_to_count': 50},
#    {'label': 'Graphical model', 'linked_to_count': 50},
#    {'label': 'Mean', 'linked_to_count': 40},
#    {'label': 'Markov chain', 'linked_to_count': 40},
#    {'label': 'Categorical distribution', 'linked_to_count': 30},
#    {'label': 'Gaussian distribution', 'linked_to_count': 30},
#    {'label': 'Variance', 'linked_to_count': 30},
#    {'label': 'Prior distribution', 'linked_to_count': 30},
#    {'label': 'Multivariate normal distribution', 'linked_to_count': 30},
#    {'label': 'Bernoulli distribution', 'linked_to_count': 30},
#    {'label': 'Topic model', 'linked_to_count': 30},
#    {'label': 'Latent Dirichlet allocation', 'linked_to_count': 30},
#    {'label': 'Pixel', 'linked_to_count': 30},
#    {'label': 'Linear subspace', 'linked_to_count': 30},
#    {'label': 'Parametric family', 'linked_to_count': 20},
#    {'label': "Zipf's law", 'linked_to_count': 20},
#    {'label': 'Dirichlet distribution', 'linked_to_count': 20},
#    {'label': 'Expectation maximization', 'linked_to_count': 20},
#    {'label': 'Convex hull', 'linked_to_count': 20},
#    {'label': 'Method of moments (statistics)', 'linked_to_count': 20},
#    {'label': 'Mathematical proof', 'linked_to_count': 20},
#    {'label': 'Hyperparameter', 'linked_to_count': 20},
#    {'label': 'Independent identically distributed', 'linked_to_count': 20},
#    {'label': 'Probabilistic model', 'linked_to_count': 10},
#    {'label': 'Subpopulation', 'linked_to_count': 10},
#    {'label': 'Mixture distribution', 'linked_to_count': 10},
#    {'label': 'Compositional data', 'linked_to_count': 10},
#    {'label': 'Measure (mathematics)', 'linked_to_count': 10},
#    {'label': 'Hierarchical Bayes model', 'linked_to_count': 10},
#    {'label': 'Conjugate prior', 'linked_to_count': 10},
#    {'label': 'Binomial distribution', 'linked_to_count': 10},
#    {'label': 'Multinomial distribution', 'linked_to_count': 10},
#    {'label': 'Negative binomial distribution', 'linked_to_count': 10},
#    {'label': 'Poisson distribution', 'linked_to_count': 10},
#    {'label': 'Exponential distribution', 'linked_to_count': 10},
#    {'label': 'Log-normal distribution', 'linked_to_count': 10},
#    {'label': 'Multivariate Gaussian distribution', 'linked_to_count': 10},
#    {'label': 'File:Nonbayesian-gaussian-mixture.svg', 'linked_to_count': 10},
#    {'label': 'File:Bayesian-gaussian-mixture.svg', 'linked_to_count': 10},
#    {'label': 'Expectation-maximization algorithm', 'linked_to_count': 10},
#    {'label': 'File:Nonbayesian-categorical-mixture.svg',
#     'linked_to_count': 10},
#    {'label': 'File:Bayesian-categorical-mixture.svg', 'linked_to_count': 10},
#    {'label': 'File:Normal distribution pdf.png', 'linked_to_count': 10},
#    {'label': 'Jump-diffusion model', 'linked_to_count': 10},
#    {'label': 'Financial economics', 'linked_to_count': 10},
#    {'label': 'Exponential growth', 'linked_to_count': 10},
#    {'label': 'Concentration parameter', 'linked_to_count': 10},
#    {'label': 'Christopher M. Bishop', 'linked_to_count': 10},
#    {'label': 'Circular error probable', 'linked_to_count': 10},
#    {'label': 'Mode (statistics)', 'linked_to_count': 10},
#    {'label': 'Dynamical consistency', 'linked_to_count': 10},
#    {'label': 'Financial derivatives', 'linked_to_count': 10},
#    {'label': 'Volatility smile', 'linked_to_count': 10},
#    {'label': 'Local volatility', 'linked_to_count': 10},
#    {'label': 'Image segmentation', 'linked_to_count': 10},
#    {'label': 'Iterative algorithm', 'linked_to_count': 10},
#    {'label': 'SOCR', 'linked_to_count': 10},
#    {'label': 'Expectation value', 'linked_to_count': 10},
#    {'label': 'Plug-in estimates', 'linked_to_count': 10},
#    {'label': 'Arithmetic mean', 'linked_to_count': 10},
# ...
#    {'label': 'Backward chaining', 'linked_to_count': 10},
#    {'label': 'Batch normalisation', 'linked_to_count': 10},
#    {'label': 'Bayesian programming', 'linked_to_count': 10},
#    {'label': 'Bees algorithm', 'linked_to_count': 10},
#    {'label': 'Behavior informatics', 'linked_to_count': 10},
#    {'label': 'Behavior tree (artificial intelligence, robotics and control)',
#     'linked_to_count': 10},
#    {'label': 'Belief-desire-intention software model', 'linked_to_count': 10},
#    {'label': 'Bio-inspired computing', 'linked_to_count': 10},
#    {'label': 'Blackboard system', 'linked_to_count': 10},
#    {'label': 'Brain technology', 'linked_to_count': 10},
#    {'label': 'Cloud robotics', 'linked_to_count': 10},
#    {'label': 'Cobweb (clustering)', 'linked_to_count': 10},
#    {'label': 'Cognitive architecture', 'linked_to_count': 10},
#    {'label': 'Cognitive computing', 'linked_to_count': 10},
#    {'label': 'Commonsense knowledge (artificial intelligence)',
#     'linked_to_count': 10},
#    {'label': 'Computational chemistry', 'linked_to_count': 10},
#    {'label': 'Computational complexity theory', 'linked_to_count': 10},
#    {'label': 'Computational creativity', 'linked_to_count': 10},
#    {'label': 'Computational humor', 'linked_to_count': 10},
#    {'label': 'Computational linguistics', 'linked_to_count': 10},
#    {'label': 'Computational mathematics', 'linked_to_count': 10},
#    {'label': 'Science', 'linked_to_count': 10},
#    {'label': 'Computational number theory', 'linked_to_count': 10},
#    {'label': 'Number theory', 'linked_to_count': 10},
#    {'label': 'Computations', 'linked_to_count': 10},
#    {'label': 'Computational problem', 'linked_to_count': 10},
#    {'label': 'Computational vision', 'linked_to_count': 10},
#    {'label': 'Computer-automated design', 'linked_to_count': 10},
#    {'label': 'Consistent heuristic', 'linked_to_count': 10},
#    {'label': 'Constraint logic programming', 'linked_to_count': 10},
#    {'label': 'Constructed language', 'linked_to_count': 10},
#    {'label': 'Control theory', 'linked_to_count': 10},
#    {'label': 'Data fusion', 'linked_to_count': 10},
#    {'label': 'Data integration', 'linked_to_count': 10},
#    {'label': 'Datalog', 'linked_to_count': 10},
#    {'label': 'Decision support system', 'linked_to_count': 10},
#    {'label': 'Deductive classifier', 'linked_to_count': 10},
#    {'label': 'Default logic', 'linked_to_count': 10},
#    {'label': 'Dialog system', 'linked_to_count': 10},
#    {'label': 'Discrete system', 'linked_to_count': 10},
#    {'label': 'Distributed artificial intelligence', 'linked_to_count': 10},
#    {'label': 'Dynamic epistemic logic', 'linked_to_count': 10},
#    {'label': 'Embodied agent', 'linked_to_count': 10},
#    {'label': 'Ensemble averaging (machine learning)', 'linked_to_count': 10},
#    {'label': 'Evolving classification function', 'linked_to_count': 10},
#    {'label': 'Existential risk from artificial general intelligence',
#     'linked_to_count': 10},
#    {'label': 'Expert systems', 'linked_to_count': 10},
#    {'label': 'Fluent (artificial intelligence)', 'linked_to_count': 10},
#    {'label': 'Forward chaining', 'linked_to_count': 10},
#    {'label': 'Frame (artificial intelligence)', 'linked_to_count': 10},
#    {'label': 'Frame language', 'linked_to_count': 10},
#    {'label': 'Frame problem', 'linked_to_count': 10},
#    {'label': 'Friendly artificial intelligence', 'linked_to_count': 10},
#    {'label': 'Futures studies', 'linked_to_count': 10},
#    {'label': 'Fuzzy control system', 'linked_to_count': 10},
#    {'label': 'Fuzzy set', 'linked_to_count': 10},
#    {'label': 'Genetic algorithm', 'linked_to_count': 10},
#    {'label': 'Genetic operator', 'linked_to_count': 10},
#    {'label': 'Glowworm swarm optimization', 'linked_to_count': 10},
#    {'label': 'Graph (abstract data type)', 'linked_to_count': 10},
#    {'label': 'Graph database', 'linked_to_count': 10},
#    {'label': 'Graph theory', 'linked_to_count': 10},
#    {'label': 'IEEE Computational Intelligence Society', 'linked_to_count': 10},
#    {'label': 'Inference engine', 'linked_to_count': 10},
#    {'label': 'Information Processing Language', 'linked_to_count': 10},
#    {'label': 'Intelligence amplification', 'linked_to_count': 10},
#    {'label': 'Intelligence explosion', 'linked_to_count': 10},
#    {'label': 'Intelligent personal assistant', 'linked_to_count': 10},
#    {'label': 'Interpretation (logic)', 'linked_to_count': 10},
#    {'label': 'Issue trees', 'linked_to_count': 10},
#    {'label': 'KL-ONE', 'linked_to_count': 10},
#    {'label': 'Knowledge-based systems', 'linked_to_count': 10},
#    {'label': 'Knowledge engineering', 'linked_to_count': 10},
#    {'label': 'Knowledge extraction', 'linked_to_count': 10},
#    {'label': 'Knowledge Interchange Format', 'linked_to_count': 10},
#    {'label': 'Linked data', 'linked_to_count': 10},
#    {'label': 'Lisp', 'linked_to_count': 10},
#    {'label': 'Machine listening', 'linked_to_count': 10},
#    {'label': 'Mechanism design', 'linked_to_count': 10},
#    {'label': 'Mechatronics', 'linked_to_count': 10},
#    {'label': 'Metabolic network modelling', 'linked_to_count': 10},
#    {'label': 'Model checking', 'linked_to_count': 10},
#    {'label': 'Modus ponens', 'linked_to_count': 10},
#    {'label': 'Modus tollens', 'linked_to_count': 10},
#    {'label': 'Multi-agent system', 'linked_to_count': 10},
#    {'label': 'Multi-swarm optimization', 'linked_to_count': 10},
#    {'label': 'Mycin', 'linked_to_count': 10},
#    {'label': 'Name binding', 'linked_to_count': 10},
#    {'label': 'Named graph', 'linked_to_count': 10},
#    {'label': 'Natural language programming', 'linked_to_count': 10},
#    {'label': 'Network motif', 'linked_to_count': 10},
#    {'label': 'Neurocybernetics', 'linked_to_count': 10},
#    {'label': 'Node (computer science)', 'linked_to_count': 10},
#    {'label': 'Nondeterministic algorithm', 'linked_to_count': 10},
#    {'label': 'Nouvelle AI', 'linked_to_count': 10},
#    {'label': 'NP (complexity)', 'linked_to_count': 10},
#    {'label': 'NP-completeness', 'linked_to_count': 10},
#    {'label': 'NP-hardness', 'linked_to_count': 10},
#    {'label': 'Ontology engineering', 'linked_to_count': 10},
#    {'label': 'Ontology learning', 'linked_to_count': 10},
#    {'label': 'OpenCog', 'linked_to_count': 10},
#    {'label': 'Pathfinding', 'linked_to_count': 10},
#    {'label': 'Partial order reduction', 'linked_to_count': 10},
#    {'label': 'Particle swarm optimization', 'linked_to_count': 10},
#    {'label': 'Planner (programming language)', 'linked_to_count': 10},
#    {'label': 'Predicate logic', 'linked_to_count': 10},
#    {'label': 'Principle of rationality', 'linked_to_count': 10},
#    {'label': 'Production Rule Representation', 'linked_to_count': 10},
#    {'label': 'Production system (computer science)', 'linked_to_count': 10},
#    {'label': 'Propositional calculus', 'linked_to_count': 10},
#    {'label': 'Qualification problem', 'linked_to_count': 10},
#    {'label': 'Query language', 'linked_to_count': 10},
#    {'label': 'Reasoning system', 'linked_to_count': 10},
#    {'label': 'Region connection calculus', 'linked_to_count': 10},
#    {'label': 'Resource Description Framework', 'linked_to_count': 10},
#    {'label': 'Rete algorithm', 'linked_to_count': 10},
#    {'label': 'Satisfiability', 'linked_to_count': 10},
#    {'label': 'Selection (genetic algorithm)', 'linked_to_count': 10},
#    {'label': 'Self-management (computer science)', 'linked_to_count': 10},
#    {'label': 'Semantic network', 'linked_to_count': 10},
#    {'label': 'Semantic reasoner', 'linked_to_count': 10},
#    {'label': 'Semantic query', 'linked_to_count': 10},
#    {'label': 'Semantics (computer science)', 'linked_to_count': 10},
#    {'label': 'Sensor fusion', 'linked_to_count': 10},
#    {'label': 'Separation logic', 'linked_to_count': 10},
#    {'label': 'Artificial intelligence, situated approach',
#     'linked_to_count': 10},
#    {'label': 'Situation calculus', 'linked_to_count': 10},
#    {'label': 'SLD resolution', 'linked_to_count': 10},
#    {'label': 'Spatial-temporal reasoning', 'linked_to_count': 10},
#    {'label': 'SPARQL', 'linked_to_count': 10},
#    {'label': 'Spiking neural network', 'linked_to_count': 10},
#    {'label': 'State (computer science)', 'linked_to_count': 10},
#    {'label': 'Stochastic optimization', 'linked_to_count': 10},
#    {'label': 'Stochastic semantic analysis', 'linked_to_count': 10},
#    {'label': 'Subject-matter expert', 'linked_to_count': 10},
#    {'label': 'Superintelligence', 'linked_to_count': 10},
#    {'label': 'Swarm intelligence', 'linked_to_count': 10},
#    {'label': 'Synthetic intelligence', 'linked_to_count': 10},
#    {'label': 'Technological singularity', 'linked_to_count': 10},
#    {'label': 'Temporal difference learning', 'linked_to_count': 10},
#    {'label': 'Tensor network theory', 'linked_to_count': 10},
#    {'label': 'Transhumanism', 'linked_to_count': 10},
#    {'label': 'Transition system', 'linked_to_count': 10},
#    {'label': 'True quantified Boolean formula', 'linked_to_count': 10},
#    {'label': 'Type system', 'linked_to_count': 10},
#    {'label': 'Weak AI', 'linked_to_count': 10},
#    {'label': 'World Wide Web Consortium', 'linked_to_count': 10},
#    {'label': 'Glossary of areas of mathematics', 'linked_to_count': 10}],
#   'label': 'Glossary of artificial intelligence'},
#  {'concepts': [{'label': 'Microsoft', 'linked_to_count': 40},
#    {'label': 'Social media', 'linked_to_count': 10},
#    {'label': 'Market sentiment', 'linked_to_count': 10},
#    {'label': 'Bing', 'linked_to_count': 10},
#    {'label': 'Election', 'linked_to_count': 10},
#    {'label': 'Reality show', 'linked_to_count': 10},
#    {'label': 'Sporting event', 'linked_to_count': 10},
#    {'label': 'Weather forecast', 'linked_to_count': 10},
#    {'label': 'The Voice (U.S. TV series)', 'linked_to_count': 10},
#    {'label': 'American Idol', 'linked_to_count': 10},
#    {'label': 'Dancing with the Stars', 'linked_to_count': 10},
#    {'label': 'United States Senate elections, 2014', 'linked_to_count': 10},
#    {'label': 'United States House of Representatives elections, 2014',
#     'linked_to_count': 10},
#    {'label': 'United States gubernatorial elections, 2014',
#     'linked_to_count': 10}],
#   'label': 'Bing Predicts'},
#  {'concepts': [{'label': 'Automated planning and scheduling',
#     'linked_to_count': 30},
#    {'label': 'Hyper-heuristic', 'linked_to_count': 30},
#    {'label': 'Answer Set Programming', 'linked_to_count': 20},
#    {'label': 'Boolean satisfiability problem', 'linked_to_count': 20},
#    {'label': 'Linear programming', 'linked_to_count': 10},
#    {'label': 'Constraint satisfaction problem', 'linked_to_count': 10},
#    {'label': 'Travelling salesman problem', 'linked_to_count': 10},
#    {'label': 'MAXSAT', 'linked_to_count': 10},
#    {'label': 'QBF', 'linked_to_count': 10},
#    {'label': 'File:Portfolio correlation as.png', 'linked_to_count': 10},
#    {'label': 'File:Shapley Values on SAT12-INDU ASlib Scenario.png',
#     'linked_to_count': 10}],
#   'label': 'Algorithm Selection'},
#  {'concepts': [{'label': 'Reinforcement learning', 'linked_to_count': 180},
#    {'label': 'Artificial neural network', 'linked_to_count': 170},
#    {'label': 'Natural language processing', 'linked_to_count': 150},
#    {'label': 'Google', 'linked_to_count': 110},
#    {'label': 'Support vector machines', 'linked_to_count': 100},
#    {'label': 'Perceptron', 'linked_to_count': 90},
#    {'label': 'Backpropagation', 'linked_to_count': 70},
#    {'label': 'Vladimir Vapnik', 'linked_to_count': 70},
#    {'label': 'Random forest', 'linked_to_count': 60},
#    {'label': 'Recurrent neural network', 'linked_to_count': 50},
#    {'label': 'Andrew Ng', 'linked_to_count': 50},
#    {'label': 'Facebook', 'linked_to_count': 50},
#    {'label': 'Least squares', 'linked_to_count': 40},
#    {'label': 'Torch (machine learning)', 'linked_to_count': 40},
#    {'label': 'Watson (computer)', 'linked_to_count': 40},
#    {'label': 'TensorFlow', 'linked_to_count': 40},
#    {'label': 'Neocognitron', 'linked_to_count': 30},
#    {'label': 'Geoff Hinton', 'linked_to_count': 30},
#    {'label': 'Q-learning', 'linked_to_count': 30},
#    {'label': 'IBM', 'linked_to_count': 30},
#    {'label': 'Computer Go', 'linked_to_count': 30},
#    {'label': 'Recurrent neural networks', 'linked_to_count': 20},
#    {'label': 'Thomas Bayes', 'linked_to_count': 20},
#    {'label': "Bayes' Theorem", 'linked_to_count': 20},
#    {'label': 'Alan Turing', 'linked_to_count': 20},
#    {'label': 'Genetic algorithms', 'linked_to_count': 20},
#    {'label': 'Arthur Samuel', 'linked_to_count': 20},
#    {'label': 'John Hopfield', 'linked_to_count': 20},
#    {'label': 'David Rumelhart', 'linked_to_count': 20},
#    {'label': 'TD-Gammon', 'linked_to_count': 20},
#    {'label': 'Backgammon', 'linked_to_count': 20},
#    {'label': 'Sepp Hochreiter', 'linked_to_count': 20},
#    {'label': 'Jürgen Schmidhuber', 'linked_to_count': 20},
#    {'label': 'MNIST database', 'linked_to_count': 20},
#    {'label': 'Netflix Prize', 'linked_to_count': 20},
#    {'label': 'Netflix', 'linked_to_count': 20},
#    {'label': 'Kaggle', 'linked_to_count': 20},
#    {'label': 'AI Winter', 'linked_to_count': 10},
#    {'label': 'File:A simple neural network with two input units and one output unit.png',
#     'linked_to_count': 10},
#    {'label': 'File:OS2 TD-Gammon Screenshot.png', 'linked_to_count': 10},
#    {'label': 'An Essay towards solving a Problem in the Doctrine of Chances',
#     'linked_to_count': 10},
#    {'label': 'Richard Price', 'linked_to_count': 10},
#    {'label': 'Bayes theorem', 'linked_to_count': 10},
#    {'label': 'Adrien-Marie Legendre', 'linked_to_count': 10},
#    {'label': 'Data fitting', 'linked_to_count': 10},
#    {'label': 'Pierre-Simon Laplace', 'linked_to_count': 10},
#    {'label': 'Andrey Markov', 'linked_to_count': 10},
#    {'label': 'Markov chains', 'linked_to_count': 10},
#    {'label': 'Marvin Minsky', 'linked_to_count': 10},
#    {'label': 'Stochastic neural analog reinforcement calculator',
#     'linked_to_count': 10},
#    {'label': 'Frank Rosenblatt', 'linked_to_count': 10},
#    {'label': 'Cornell Aeronautical Laboratory', 'linked_to_count': 10},
#    {'label': 'Seymour Papert', 'linked_to_count': 10},
#    {'label': 'Perceptrons (book)', 'linked_to_count': 10},
#    {'label': 'Seppo Linnainmaa', 'linked_to_count': 10},
#    {'label': 'Kunihiko Fukushima', 'linked_to_count': 10},
#    {'label': 'Convolutional neural networks', 'linked_to_count': 10},
#    {'label': 'Hopfield networks', 'linked_to_count': 10},
#    {'label': 'Content-addressable memory', 'linked_to_count': 10},
#    {'label': 'Ronald J. Williams', 'linked_to_count': 10},
#    {'label': 'Evolver (software)', 'linked_to_count': 10},
#    {'label': 'Temporal-difference learning', 'linked_to_count': 10},
#    {'label': 'Corinna Cortes', 'linked_to_count': 10},
#    {'label': 'Yann LeCun', 'linked_to_count': 10},
#    {'label': 'American Census Bureau', 'linked_to_count': 10},
#    {'label': 'Jeopardy!', 'linked_to_count': 10},
#    {'label': 'Google Brain', 'linked_to_count': 10},
#    {'label': 'Jeff Dean', 'linked_to_count': 10},
#    {'label': 'YouTube', 'linked_to_count': 10},
#    {'label': 'DeepFace', 'linked_to_count': 10},
#    {'label': 'History of artificial intelligence', 'linked_to_count': 10},
#    {'label': 'Timeline of artificial intelligence', 'linked_to_count': 10},
#    {'label': 'Timeline of machine translation', 'linked_to_count': 10}],
#   'label': 'Timeline of machine learning'},
#  {'concepts': [{'label': 'Big data', 'linked_to_count': 70},
#    {'label': 'New York City', 'linked_to_count': 50},
#    {'label': 'Data science', 'linked_to_count': 40},
#    {'label': 'Predictive modelling', 'linked_to_count': 30},
#    {'label': 'Privately held company', 'linked_to_count': 20},
#    {'label': 'Germany', 'linked_to_count': 20},
#    {'label': 'Search engine', 'linked_to_count': 20},
#    {'label': 'Paris', 'linked_to_count': 10},
#    {'label': 'France', 'linked_to_count': 10},
#    {'label': 'U.S.', 'linked_to_count': 10},
#    {'label': 'U.K.', 'linked_to_count': 10},
#    {'label': 'Computer software', 'linked_to_count': 10},
#    {'label': 'Exalead', 'linked_to_count': 10}],
#   'label': 'Dataiku'},
#  {'concepts': [], 'label': 'Machine Teaching'}]

# %%
with open('machine-learning-full.json', 'wt') as f:
    json.dump(f_concepts, f)
